# %%
import json
import pandas as pd
import numpy as np
import re

# %%
file_dir = "data/"
with open(f'{file_dir}wikipedia-movies.json', mode='r') as file:
    wiki_movies_raw = json.load(file)
kaggle_metadata = pd.read_csv(f'{file_dir}movies_metadata.csv')
ratings = pd.read_csv('data/ratings.csv')
# Out:
# C:\Users\tabit\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
len(wiki_movies_raw)
# Out:
# 7311

# %%
# first 5 records
wiki_movies_raw[:5]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/The_Adventures_of_Ford_Fairlane',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098987/',
#   'title': 'The Adventures of Ford Fairlane',
#   'Directed by': 'Renny Harlin',
#   'Produced by': ['Steve Perry', 'Joel Silver'],
#   'Screenplay by': ['David Arnott', 'James Cappe', 'Daniel Waters'],
#   'Story by': ['David Arnott', 'James Cappe'],
#   'Based on': ['Characters', 'by Rex Weiner'],
#   'Starring': ['Andrew Dice Clay',
#    'Wayne Newton',
#    'Priscilla Presley',
#    'Lauren Holly',
#    'Morris Day',
#    'Robert Englund',
#    "Ed O'Neill"],
#   'Narrated by': 'Andrew "Dice" Clay',
#   'Music by': ['Cliff Eidelman', 'Yello'],
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Michael Tronick',
#   'Productioncompany ': 'Silver Pictures',
#   'Distributed by': '20th Century Fox',
#   'Release date': ['July 11, 1990', '(', '1990-07-11', ')'],
#   'Running time': '102 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20 million',
#   'Box office': '$21.4 million'},
#  {'url': 'https://en.wikipedia.org/wiki/After_Dark,_My_Sweet',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098994/',
#   'title': 'After Dark, My Sweet',
#   'Directed by': 'James Foley',
#   'Produced by': ['Ric Kidney', 'Robert Redlin'],
#   'Screenplay by': ['James Foley', 'Robert Redlin'],
#   'Based on': ['the novel', 'After Dark, My Sweet', 'by', 'Jim Thompson'],
#   'Starring': ['Jason Patric',
#    'Rachel Ward',
#    'Bruce Dern',
#    'George Dickerson'],
#   'Music by': 'Maurice Jarre',
#   'Cinematography': 'Mark Plummer',
#   'Edited by': 'Howard E. Smith',
#   'Productioncompany ': 'Avenue Pictures',
#   'Distributed by': 'Avenue Pictures',
#   'Release date': ['May 17, 1990',
#    '(',
#    '1990-05-17',
#    ')',
#    '(Cannes Film Market)',
#    'August 24, 1990',
#    '(',
#    '1990-08-24',
#    ')',
#    '(United States)'],
#   'Running time': '114 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$6 million',
#   'Box office': '$2.7 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Air_America_(film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099005/',
#   'title': 'Air America',
#   'Directed by': 'Roger Spottiswoode',
#   'Produced by': 'Daniel Melnick',
#   'Screenplay by': ['John Eskow', 'Richard Rush'],
#   'Based on': ['Air America', 'by', 'Christopher Robbins'],
#   'Starring': ['Mel Gibson',
#    'Robert Downey Jr.',
#    'Nancy Travis',
#    'David Marshall Grant',
#    'Lane Smith'],
#   'Music by': 'Charles Gross',
#   'Cinematography': 'Roger Deakins',
#   'Edited by': ['John Bloom', 'Lois Freeman-Fox'],
#   'Productioncompany ': ['Carolco Pictures', 'IndieProd Company'],
#   'Distributed by': 'TriStar Pictures',
#   'Release date': ['August 10, 1990', '(', '1990-08-10', ')'],
#   'Running time': '113 minutes',
#   'Country': 'United States',
#   'Language': ['English', 'Lao'],
#   'Budget': '$35 million',
#   'Box office': '$57,718,089'},
#  {'url': 'https://en.wikipedia.org/wiki/Alice_(1990_film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099012/',
#   'title': 'Alice',
#   'Directed by': 'Woody Allen',
#   'Produced by': 'Robert Greenhut',
#   'Written by': 'Woody Allen',
#   'Starring': ['Alec Baldwin',
#    'Blythe Danner',
#    'Judy Davis',
#    'Mia Farrow',
#    'William Hurt',
#    'Keye Luke',
#    'Joe Mantegna',
#    'Bernadette Peters'],
#   'Cinematography': 'Carlo Di Palma',
#   'Edited by': 'Susan E. Morse',
#   'Distributed by': 'Orion Pictures',
#   'Release date': ['December 25, 1990', '(', '1990-12-25', ')'],
#   'Running time': '106 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$12 million',
#   'Box office': '$7,331,647'},
#  {'url': 'https://en.wikipedia.org/wiki/Almost_an_Angel',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099018/',
#   'title': 'Almost an Angel',
#   'Directed by': 'John Cornell',
#   'Produced by': 'John Cornell',
#   'Written by': 'Paul Hogan',
#   'Starring': ['Paul Hogan', 'Elias Koteas', 'Linda Kozlowski'],
#   'Music by': 'Maurice Jarre',
#   'Cinematography': 'Russell Boyd',
#   'Edited by': 'David Stiven',
#   'Distributed by': 'Paramount Pictures',
#   'Release date': 'December 19, 1990',
#   'Running time': '95 minutes',
#   'Country': 'US',
#   'Language': 'English',
#   'Budget': '$25 million',
#   'Box office': '$6,939,946 (USA)'}]

# %%
# last 5 records
wiki_movies_raw[-5:]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Holmes_%26_Watson',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt1255919/',
#   'title': 'Holmes & Watson',
#   'Directed by': 'Etan Cohen',
#   'Produced by': ['Will Ferrell',
#    'Adam McKay',
#    'Jimmy Miller',
#    'Clayton Townsend'],
#   'Screenplay by': 'Etan Cohen',
#   'Based on': ['Sherlock Holmes',
#    'and',
#    'Dr. Watson',
#    'by',
#    'Sir Arthur Conan Doyle'],
#   'Starring': ['Will Ferrell',
#    'John C. Reilly',
#    'Rebecca Hall',
#    'Rob Brydon',
#    'Steve Coogan',
#    'Ralph Fiennes'],
#   'Music by': 'Mark Mothersbaugh',
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Dean Zimmerman',
#   'Productioncompanies ': ['Columbia Pictures',
#    'Gary Sanchez Productions',
#    'Mosaic Media Group',
#    'Mimran Schur Pictures'],
#   'Distributed by': 'Sony Pictures Releasing',
#   'Release date': ['December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
#   'Running time': '90 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$42 million',
#   'Box office': '$41.9 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Vice_(2018_film)',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt6266538/',
#   'title': 'Vice',
#   'Directed by': 'Adam McKay',
#   'Produced by': ['Brad Pitt',
#    'Dede Gardner',
#    'Jeremy Kleiner',
#    'Kevin J. Messick',
#    'Will Ferrell',
#    'Adam McKay'],
#   'Written by': 'Adam McKay',
#   'Starring': ['Christian Bale',
#    'Amy Adams',
#    'Steve Carell',
#    'Sam Rockwell',
#    'Tyler Perry',
#    'Alison Pill',
#    'Lily Rabe',
#    'Jesse Plemons'],
#   'Music by': 'Nicholas Britell',
#   'Cinematography': 'Greig Fraser',
#   'Edited by': 'Hank Corwin',
#   'Productioncompany ': ['Plan B Entertainment',
#    'Gary Sanchez Productions',
#    'Annapurna Pictures'],
#   'Distributed by': 'Mirror Releasing',
#   'Release date': ['December 11, 2018',
#    '(',
#    '2018-12-11',
#    ')',
#    '(',
#    'Samuel Goldwyn Theater',
#    ')',
#    'December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
#   'Running time': '132 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$60 million',
#   'Box office': '$76.1 million'},
#  {'url': 'https://en.wikipedia.org/wiki/On_the_Basis_of_Sex',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt4669788/',
#   'title': 'On the Basis of Sex',
#   'Directed by': 'Mimi Leder',
#   'Produced by': 'Robert W. Cort',
#   'Written by': 'Daniel Stiepleman',
#   'Starring': ['Felicity Jones',
#    'Armie Hammer',
#    'Justin Theroux',
#    'Sam Waterston',
#    'Kathy Bates'],
#   'Music by': 'Mychael Danna',
#   'Cinematography': 'Michael Grady',
#   'Edited by': 'Michelle Tesoro',
#   'Productioncompanies ': ['Focus Features',
#    '[1]',
#    'Participant Media',
#    '[1]',
#    'Robert Cort Productions',
#    '[1]',
#    'Alibaba Pictures',
#    '[2]'],
#   'Distributed by': 'Focus Features',
#   'Release date': ['November 8, 2018',
#    '(',
#    '2018-11-08',
#    ')',
#    '(',
#    'AFI Fest',
#    ')',
#    'December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
#   'Running time': '120 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20 million',
#   'Box office': '$38.4 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Destroyer_(2018_film)',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt7137380/',
#   'title': 'Destroyer',
#   'Directed by': 'Karyn Kusama',
#   'Produced by': ['Fred Berger', 'Phil Hay', 'Matt Manfredi'],
#   'Written by': ['Phil Hay', 'Matt Manfredi'],
#   'Starring': ['Nicole Kidman',
#    'Sebastian Stan',
#    'Toby Kebbell',
#    'Tatiana Maslany',
#    'Bradley Whitford',
#    'Jade Pettyjohn',
#    'Scoot McNairy'],
#   'Music by': 'Theodore Shapiro',
#   'Cinematography': 'Julie Kirkwood',
#   'Edited by': 'Plummy Tucker',
#   'Productioncompany ': ['30West',
#    'Automatik Entertainment',
#    'Annapurna Pictures'],
#   'Distributed by': 'Mirror Releasing',
#   'Release date': ['August 31, 2018',
#    '(',
#    '2018-08-31',
#    ')',
#    '(',
#    'Telluride',
#    ')',
#    'December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
#   'Running time': '123 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$9 million',
#   'Box office': '$5.5 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Black_Mirror:_Bandersnatch',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt9495224/',
#   'title': 'Bandersnatch',
#   'Directed by': 'David Slade',
#   'Produced by': 'Russell McLean',
#   'Written by': 'Charlie Brooker',
#   'Starring': ['Fionn Whitehead',
#    'Will Poulter',
#    'Craig Parkinson',
#    'Alice Lowe',
#    'Asim Chaudhry'],
#   'Music by': 'Brian Reitzell',
#   'Cinematography': ['Aaron Morton', 'Jake Polonsky'],
#   'Edited by': 'Tony Kearns',
#   'Productioncompany ': ['House of Tomorrow', 'Netflix'],
#   'Distributed by': 'Netflix',
#   'Release date': ['28 December 2018', '(', '2018-12-28', ')'],
#   'Running time': 'Variable; 90 minutes for default path',
#   'Country': 'United Kingdom',
#   'Language': 'English'}]

# %%
#some records in the middle
wiki_movies_raw[3600:3605]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Benji:_Off_the_Leash!',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0315273/',
#   'title': 'Benji: Off the Leash!',
#   'Directed by': 'Joe Camp',
#   'Written by': 'Joe Camp',
#   'Starring': ['Benji', 'Nick Whitaker', 'Shaggy', 'Gypsy the Cockatoo'],
#   'Music by': 'Antonio di Lorenzo',
#   'Productioncompany ': 'Mulberry Square Productions',
#   'Distributed by': 'Mulberry Square Productions',
#   'Release date': ['March 26, 2004', '(', '2004-03-26', ')'],
#   'Running time': '97 min',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$3,817,362'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Best_Thief_in_the_World',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0389796/',
#   'title': 'The Best Thief in the World',
#   'Directed by': 'Jacob Kornbluth',
#   'Produced by': ['Tim Perrell', 'Nicola Usborne'],
#   'Written by': 'Jacob Kornbluth',
#   'Starring': ['Marc Rozendaal',
#    'Michael Silverman',
#    'David Warshofsky',
#    'Audra McDonald',
#    'Lois Smith'],
#   'Music by': ['Prince Paul', 'and', 'Don Newkirk'],
#   'Cinematography': 'Ben Kutchins',
#   'Edited by': 'Stephanie Sterner',
#   'Distributed by': 'Showtime Networks',
#   'Release date': ['January 16, 2004', '(', '2004-01-16', ')'],
#   'Running time': '93 minutes',
#   'Country': 'United States',
#   'Language': 'English'},
#  {'url': 'https://en.wikipedia.org/wiki/Beyond_the_Sea_(2004_film)',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0363473/',
#   'title': 'Beyond the Sea',
#   'Directed by': 'Kevin Spacey',
#   'Produced by': ['Kevin Spacey',
#    'Phillip Barry',
#    'Dana Brunetti',
#    'Arthur Friedman',
#    'Jan Fantl',
#    'Andy Paterson'],
#   'Written by': ['Lewis Colick', 'Kevin Spacey'],
#   'Starring': ['Kevin Spacey', 'Kate Bosworth', 'Bob Hoskins', 'John Goodman'],
#   'Music by': 'Bobby Darin',
#   'Cinematography': 'Eduardo Serra',
#   'Edited by': 'Trevor Waite',
#   'Productioncompany ': 'Trigger Street Productions',
#   'Distributed by': ['Lionsgate Films',
#    '(USA)',
#    'Entertainment Film Distributors',
#    '(UK)',
#    'GAGA',
#    '(Japan)',
#    'Maple Pictures',
#    '(Canada)'],
#   'Release date': ['December 17, 2004', '(', '2004-12-17', ')'],
#   'Running time': '118 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$25 million',
#   'Box office': '$8.4 million'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Big_Bounce_(2004_film)',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0315824/',
#   'title': 'The Big Bounce',
#   'Directed by': 'George Armitage',
#   'Produced by': ['George Armitage', 'Steve Bing'],
#   'Screenplay by': 'Sebastian Gutierrez',
#   'Based on': ['The Big Bounce', 'by', 'Elmore Leonard'],
#   'Starring': ['Owen Wilson',
#    'Charlie Sheen',
#    'Morgan Freeman',
#    'Sara Foster',
#    'Gary Sinise'],
#   'Music by': 'George S. Clinton',
#   'Cinematography': 'Jeffrey L. Kimball',
#   'Edited by': 'Barry Malkin',
#   'Productioncompany ': 'Shangri-La Entertainment',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Release date': ['January 30, 2004', '(', '2004-01-30', ')'],
#   'Running time': '88 minutes',
#   'Language': 'English',
#   'Budget': '$50 million',
#   'Box office': '$6.8 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Birth_(film)',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0337876/',
#   'title': 'Birth',
#   'Directed by': 'Jonathan Glazer',
#   'Produced by': ['Lizie Gower', 'Nick Morris', 'Jean-Louis Piel'],
#   'Written by': ['Jean-Claude Carrière', 'Milo Addica', 'Jonathan Glazer'],
#   'Starring': ['Nicole Kidman',
#    'Cameron Bright',
#    'Danny Huston',
#    'Lauren Bacall'],
#   'Music by': 'Alexandre Desplat',
#   'Cinematography': 'Harris Savides',
#   'Edited by': ['Sam Sneade', 'Claus Wehlisch'],
#   'Distributed by': 'New Line Cinema',
#   'Release date': ['November 8, 2004', '(', '2004-11-08', ')'],
#   'Running time': '96 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20 million',
#   'Box office': '$23.9 million'}]

# %%
kaggle_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
kaggle_metadata.tail()
# Out:
#        adult belongs_to_collection budget  \
# 45461  False                   NaN      0
# 45462  False                   NaN      0
# 45463  False                   NaN      0
# 45464  False                   NaN      0
# 45465  False                   NaN      0
#
#                                                   genres  \
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language       original_title  \
# 45461                fa              رگ خواب
# 45462                tl  Siglo ng Pagluluwal
# 45463                en             Betrayal
# 45464                en  Satana likuyushchiy
# 45465                en             Queerama
#
#                                                 overview  ... release_date  \
# 45461        Rising and falling between a man and woman.  ...          NaN
# 45462  An artist struggles to finish his work while a...  ...   2011-11-17
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#       revenue runtime                          spoken_languages    status  \
# 45461     0.0    90.0    [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45462     0.0   360.0         [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463     0.0    90.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464     0.0    87.0                                        []  Released
# 45465     0.0    75.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                           tagline                title  video  \
# 45461  Rising and falling between a man and woman               Subdue  False
# 45462                                         NaN  Century of Birthing  False
# 45463                      A deadly game of wits.             Betrayal  False
# 45464                                         NaN     Satan Triumphant  False
# 45465                                         NaN             Queerama  False
#
#       vote_average vote_count
# 45461          4.0        1.0
# 45462          9.0        3.0
# 45463          3.8        6.0
# 45464          0.0        0.0
# 45465          0.0        0.0
#
# [5 rows x 24 columns]

# %%
kaggle_metadata.sample(n=5)
# Out:
#        adult belongs_to_collection budget  \
# 43891  False                   NaN      0
# 39460  False                   NaN      0
# 42298  False                   NaN      0
# 23163  False                   NaN      0
# 33986  False                   NaN      0
#
#                                                   genres homepage      id  \
# 43891  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...      NaN   94532
# 39460                     [{'id': 35, 'name': 'Comedy'}]      NaN   41298
# 42298                [{'id': 99, 'name': 'Documentary'}]      NaN  382212
# 23163  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN  191294
# 33986  [{'id': 12, 'name': 'Adventure'}, {'id': 36, '...      NaN   56623
#
#          imdb_id original_language             original_title  \
# 43891  tt1866230                en                  Reel Love
# 39460  tt0076532                es          El patrullero 777
# 42298  tt5450084                de               Homo Sapiens
# 23163  tt2364975                sv                Vi är bäst!
# 33986  tt1526578                fr  Ao, le dernier néandertal
#
#                                                 overview  ... release_date  \
# 43891  A successful, big city girl returns to her sma...  ...   2011-11-13
# 39460  Follows Diogenes as he goes about his day as a...  ...   1978-04-27
# 42298  The images could be taken from a science ficti...  ...   2016-07-29
# 23163  Three girls in 1980s Stockholm decide to form ...  ...   2013-03-28
# 33986  When his clan, including his wife and baby gir...  ...   2010-01-29
#
#         revenue runtime                           spoken_languages    status  \
# 43891       0.0    90.0   [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 39460       0.0   120.0   [{'iso_639_1': 'es', 'name': 'Español'}]  Released
# 42298       0.0    94.0                                         []  Released
# 23163  180590.0   102.0   [{'iso_639_1': 'sv', 'name': 'svenska'}]  Released
# 33986       0.0    84.0  [{'iso_639_1': 'fr', 'name': 'Français'}]  Released
#
#        tagline                title  video vote_average vote_count
# 43891      NaN            Reel Love  False          5.1        5.0
# 39460      NaN    El patrullero 777  False          7.0        2.0
# 42298      NaN         Homo Sapiens  False          7.3        6.0
# 23163      NaN     We Are the Best!  False          6.9       62.0
# 33986      NaN  Ao: The Last Hunter  False          6.5       16.0
#
# [5 rows x 24 columns]

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
ratings.tail()
# Out:
#           userId  movieId  rating   timestamp
# 26024284  270896    58559     5.0  1257031564
# 26024285  270896    60069     5.0  1257032032
# 26024286  270896    63082     4.5  1257031764
# 26024287  270896    64957     4.5  1257033990
# 26024288  270896    71878     2.0  1257031858

# %%
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 17050550  177079     1090     5.0   970265529
# 3691200    38461     7285     3.5  1094134399
# 15584135  162256    68954     4.0  1499091044
# 731095      7437     2160     4.0  1224730325
# 9494042    98011     4958     3.0  1202276588

# %%
ratings.dtypes
# Out:
# userId         int64
# movieId        int64
# rating       float64
# timestamp      int64
# dtype: object

# %%
kaggle_metadata.dtypes
# Out:
# adult                     object
# belongs_to_collection     object
# budget                    object
# genres                    object
# homepage                  object
# id                        object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity                object
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                     object
# vote_average             float64
# vote_count               float64
# dtype: object

# %%
wiki_movies_df = pd.DataFrame(wiki_movies_raw)

# %%
wiki_movies_df.head()
# Out:
#                                                  url    year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990.0
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990.0
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990.0
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990.0
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990.0
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# 2  Roger Spottiswoode               Daniel Melnick
# 3         Woody Allen              Robert Greenhut
# 4        John Cornell                 John Cornell
#
#                                 Screenplay by                     Story by  \
# 0  [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# 1                [James Foley, Robert Redlin]                          NaN
# 2                  [John Eskow, Richard Rush]                          NaN
# 3                                         NaN                          NaN
# 4                                         NaN                          NaN
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring  ... Predecessor  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  ...         NaN
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...  ...         NaN
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...  ...         NaN
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  ...         NaN
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]  ...         NaN
#
#   Founders Area served Products Services Russian Hebrew Revenue  \
# 0      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 1      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 2      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 3      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 4      NaN         NaN      NaN      NaN     NaN    NaN     NaN
#
#   Operating income Polish
# 0              NaN    NaN
# 1              NaN    NaN
# 2              NaN    NaN
# 3              NaN    NaN
# 4              NaN    NaN
#
# [5 rows x 193 columns]

# %%
wiki_movies_df.tail()
# Out:
#                                                     url    year  \
# 7306    https://en.wikipedia.org/wiki/Holmes_%26_Watson  2018.0
# 7307     https://en.wikipedia.org/wiki/Vice_(2018_film)  2018.0
# 7308  https://en.wikipedia.org/wiki/On_the_Basis_of_Sex  2018.0
# 7309  https://en.wikipedia.org/wiki/Destroyer_(2018_...  2018.0
# 7310  https://en.wikipedia.org/wiki/Black_Mirror:_Ba...  2018.0
#
#                                   imdb_link                title  \
# 7306  https://www.imdb.com/title/tt1255919/      Holmes & Watson
# 7307  https://www.imdb.com/title/tt6266538/                 Vice
# 7308  https://www.imdb.com/title/tt4669788/  On the Basis of Sex
# 7309  https://www.imdb.com/title/tt7137380/            Destroyer
# 7310  https://www.imdb.com/title/tt9495224/         Bandersnatch
#
#        Directed by                                        Produced by  \
# 7306    Etan Cohen  [Will Ferrell, Adam McKay, Jimmy Miller, Clayt...
# 7307    Adam McKay  [Brad Pitt, Dede Gardner, Jeremy Kleiner, Kevi...
# 7308    Mimi Leder                                     Robert W. Cort
# 7309  Karyn Kusama             [Fred Berger, Phil Hay, Matt Manfredi]
# 7310   David Slade                                     Russell McLean
#
#      Screenplay by Story by  \
# 7306    Etan Cohen      NaN
# 7307           NaN      NaN
# 7308           NaN      NaN
# 7309           NaN      NaN
# 7310           NaN      NaN
#
#                                                Based on  \
# 7306  [Sherlock Holmes, and, Dr. Watson, by, Sir Art...
# 7307                                                NaN
# 7308                                                NaN
# 7309                                                NaN
# 7310                                                NaN
#
#                                                Starring  ... Predecessor  \
# 7306  [Will Ferrell, John C. Reilly, Rebecca Hall, R...  ...         NaN
# 7307  [Christian Bale, Amy Adams, Steve Carell, Sam ...  ...         NaN
# 7308  [Felicity Jones, Armie Hammer, Justin Theroux,...  ...         NaN
# 7309  [Nicole Kidman, Sebastian Stan, Toby Kebbell, ...  ...         NaN
# 7310  [Fionn Whitehead, Will Poulter, Craig Parkinso...  ...         NaN
#
#      Founders Area served Products Services Russian Hebrew Revenue  \
# 7306      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 7307      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 7308      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 7309      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 7310      NaN         NaN      NaN      NaN     NaN    NaN     NaN
#
#      Operating income Polish
# 7306              NaN    NaN
# 7307              NaN    NaN
# 7308              NaN    NaN
# 7309              NaN    NaN
# 7310              NaN    NaN
#
# [5 rows x 193 columns]

# %%
wiki_movies_df.sample(n=5)
# Out:
#                                                     url    year  \
# 4544     https://en.wikipedia.org/wiki/Dan_in_Real_Life  2007.0
# 1826                                                NaN     NaN
# 3846  https://en.wikipedia.org/wiki/The_Brothers_Gri...  2005.0
# 2964  https://en.wikipedia.org/wiki/Elvira%27s_Haunt...  2001.0
# 640   https://en.wikipedia.org/wiki/Silent_Night,_De...  1992.0
#
#                                   imdb_link  \
# 4544  https://www.imdb.com/title/tt0480242/
# 1826                                    NaN
# 3846  https://www.imdb.com/title/tt0355295/
# 2964  https://www.imdb.com/title/tt0265171/
# 640   https://www.imdb.com/title/tt0105410/
#
#                                             title       Directed by  \
# 4544                             Dan in Real Life      Peter Hedges
# 1826                                          NaN               NaN
# 3846                           The Brothers Grimm     Terry Gilliam
# 2964                       Elvira's Haunted Hills         Sam Irvin
# 640   Silent Night, Deadly Night 5: The Toy Maker  Martin Kitrosser
#
#                               Produced by Screenplay by Story by Based on  \
# 4544                    Jonathan Shestack           NaN      NaN      NaN
# 1826                                  NaN           NaN      NaN      NaN
# 3846       [Charles Roven, Daniel Bobker]           NaN      NaN      NaN
# 2964                         Mark Pierson           NaN      NaN      NaN
# 640   [Richard N. Gladstein, Brian Yuzna]           NaN      NaN      NaN
#
#                                                Starring  ... Predecessor  \
# 4544  [Steve Carell, Alison Pill, Juliette Binoche, ...  ...         NaN
# 1826                                                NaN  ...         NaN
# 3846  [Matt Damon, Heath Ledger, Peter Stormare, Len...  ...         NaN
# 2964  [Elvira, Richard O'Brien, Mary Scheer, Scott A...  ...         NaN
# 640   [William Thorne, Mickey Rooney, Jane Higginson...  ...         NaN
#
#      Founders Area served Products Services Russian Hebrew Revenue  \
# 4544      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 1826      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 3846      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 2964      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 640       NaN         NaN      NaN      NaN     NaN    NaN     NaN
#
#      Operating income Polish
# 4544              NaN    NaN
# 1826              NaN    NaN
# 3846              NaN    NaN
# 2964              NaN    NaN
# 640               NaN    NaN
#
# [5 rows x 193 columns]

# %%
wiki_movies_df.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Genre',
#  'Theme music composer',
#  'Country of origin',
#  'Original language(s)',
#  'Producer(s)',
#  'Editor(s)',
#  'Production company(s)',
#  'Original network',
#  'Original release',
#  'Productioncompanies ',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Distributor',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Composer(s)',
#  'Created by',
#  'Also known as',
#  'Opening theme',
#  'No. of episodes',
#  'Preceded by',
#  'Author',
#  'Publisher',
#  'Publication date',
#  'Media type',
#  'Pages',
#  'ISBN',
#  'OCLC',
#  'LC Class',
#  'Cover artist',
#  'Series',
#  'Set in',
#  'Adaptation by',
#  'Suggested by',
#  'Biographical data',
#  'Born',
#  'Died',
#  'Resting place',
#  'Occupation',
#  'Years active',
#  'Spouse(s)',
#  'Children',
#  'Parent(s)',
#  'Genres',
#  'Instruments',
#  'Labels',
#  'Website',
#  'Traditional',
#  'Mandarin',
#  'Type',
#  'Industry',
#  'Fate',
#  'Founded',
#  'Founder',
#  'Headquarters',
#  'Parent',
#  'Released',
#  'Recorded',
#  'Venue',
#  'Length',
#  'Label',
#  'Director',
#  'Producer',
#  'Area',
#  'Coordinates',
#  'Status',
#  'Opening date',
#  'Closing date',
#  'Replaced',
#  'Replaced by',
#  'Name',
#  'Attraction type',
#  'Music',
#  'Duration',
#  'Simplified Chinese',
#  'Traditional Chinese',
#  'Hanyu Pinyin',
#  'Literal meaning',
#  'Transcriptions',
#  'Bopomofo',
#  'Gwoyeu Romatzyh',
#  'Wade–Giles',
#  'IPA',
#  'Yale Romanization',
#  'Jyutping',
#  'Hokkien POJ',
#  'Animation by',
#  'Color process',
#  'Engine(s)',
#  'Genre(s)',
#  'Actor control',
#  'Production company',
#  'Release(s)',
#  'Format(s)',
#  'Simplified',
#  'Characters',
#  'Date premiered',
#  'Place premiered',
#  'Setting',
#  'Original language',
#  'Subject',
#  'Published',
#  'Dewey Decimal',
#  'Text',
#  'Illustrator',
#  'Original title',
#  'Published in English',
#  'French',
#  'Developed by',
#  'Ending theme',
#  'No. of seasons',
#  'Nationality',
#  'Portrayed by',
#  'Alias',
#  'Species',
#  'Gender',
#  'Family',
#  'Alma mater',
#  'Camera setup',
#  'Novel(s)',
#  'Comics',
#  'Film(s)',
#  'Screen story by',
#  'Hangul',
#  'Revised Romanization',
#  'McCune–Reischauer',
#  'Developer(s)',
#  'Publisher(s)',
#  'Designer(s)',
#  'Programmer(s)',
#  'Artist(s)',
#  'Writer(s)',
#  'Engine',
#  'Platform(s)',
#  'Release',
#  'Mode(s)',
#  'Original work',
#  'Television series',
#  'Japanese',
#  'Hepburn',
#  'Literally',
#  'Cantonese',
#  'Full name',
#  'Height',
#  'Seasons',
#  'Chinese',
#  'Other names',
#  'Relatives',
#  'Yiddish',
#  'Formerly',
#  'Key people',
#  'Total assets',
#  'Owner',
#  'Number of employees',
#  'Divisions',
#  'Subsidiaries',
#  'Arabic',
#  'Romanized',
#  'Predecessor',
#  'Founders',
#  'Area served',
#  'Products',
#  'Services',
#  'Russian',
#  'Hebrew',
#  'Revenue',
#  'Operating income',
#  'Polish']

# %%
wiki_movies = [movie for movie in wiki_movies_raw
               if ('Director' in movie or 'Directed by' in movie)
                   and 'imdb_link' in movie
                   and 'No. of episodes' not in movie]
len(wiki_movies)
# Out:
# 7076

# %%
wiki_movies_df = pd.DataFrame(wiki_movies)

# %%
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# 2  Roger Spottiswoode               Daniel Melnick
# 3         Woody Allen              Robert Greenhut
# 4        John Cornell                 John Cornell
#
#                                 Screenplay by                     Story by  \
# 0  [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# 1                [James Foley, Robert Redlin]                          NaN
# 2                  [John Eskow, Richard Rush]                          NaN
# 3                                         NaN                          NaN
# 4                                         NaN                          NaN
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring  ... Hepburn Literally  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  ...     NaN       NaN
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...  ...     NaN       NaN
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...  ...     NaN       NaN
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  ...     NaN       NaN
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]  ...     NaN       NaN
#
#   Cantonese Chinese Yiddish Arabic Romanized Russian Hebrew Polish
# 0       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 1       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 2       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 3       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 4       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
#
# [5 rows x 75 columns]

# %%
def clean_movie(movie):
    movie = dict(movie)
    return movie

# %%
wiki_movies_df[wiki_movies_df['Arabic'].notnull()]
# Out:
#                                                   url  year  \
# 6834  https://en.wikipedia.org/wiki/The_Insult_(film)  2018
# 7058   https://en.wikipedia.org/wiki/Capernaum_(film)  2018
#
#                                   imdb_link       title    Directed by  \
# 6834  https://www.imdb.com/title/tt7048622/  The Insult   Ziad Doueiri
# 7058  https://www.imdb.com/title/tt8267604/   Capernaum  Nadine Labaki
#
#                                             Produced by  \
# 6834  [Rachid Bouchareb, Jean Bréhat, Julie Gayet, A...
# 7058                    [Michel Merkt, Khaled Mouzanar]
#
#                                           Screenplay by  \
# 6834                                                NaN
# 7058  [Nadine Labaki, Jihad Hojaily, Michelle Keserw...
#
#                                                Story by Based on  \
# 6834                                                NaN      NaN
# 7058  [Georges Khabbaz, Nadine Labaki, Michelle Kese...      NaN
#
#                                                Starring  ... Hepburn  \
# 6834                       [Adel Karam, Kamel El Basha]  ...     NaN
# 7058  [Zain Al Rafeea, Yordanos Shiferaw, Boluwatife...  ...     NaN
#
#         Literally Cantonese Chinese Yiddish       Arabic        Romanized  \
# 6834  Case No. 23       NaN     NaN     NaN  قضية رقم ٢٣  Qadiyya raqm 23
# 7058          NaN       NaN     NaN     NaN    کفرناحوم‎              NaN
#
#      Russian Hebrew Polish
# 6834     NaN    NaN    NaN
# 7058     NaN    NaN    NaN
#
# [2 rows x 75 columns]

# %%
wiki_movies_df[wiki_movies_df['Arabic'].notnull()]['url']
# Out:
# 6834    https://en.wikipedia.org/wiki/The_Insult_(film)
# 7058     https://en.wikipedia.org/wiki/Capernaum_(film)
# Name: url, dtype: object

# %%
wiki_movies_df[wiki_movies_df['Japanese'].notnull()]['url']
# Out:
# 6393    https://en.wikipedia.org/wiki/When_Marnie_Was_...
# 6829    https://en.wikipedia.org/wiki/Mary_and_the_Wit...
# 7009    https://en.wikipedia.org/wiki/My_Hero_Academia...
# 7054            https://en.wikipedia.org/wiki/Shoplifters
# Name: url, dtype: object

# %%
wiki_movies_df[wiki_movies_df['Language'].notnull()]
# Out:
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...                                                 ...   ...
# 7071    https://en.wikipedia.org/wiki/Holmes_%26_Watson  2018
# 7072     https://en.wikipedia.org/wiki/Vice_(2018_film)  2018
# 7073  https://en.wikipedia.org/wiki/On_the_Basis_of_Sex  2018
# 7074  https://en.wikipedia.org/wiki/Destroyer_(2018_...  2018
# 7075  https://en.wikipedia.org/wiki/Black_Mirror:_Ba...  2018
#
#                                   imdb_link                            title  \
# 0     https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1     https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2     https://www.imdb.com/title/tt0099005/                      Air America
# 3     https://www.imdb.com/title/tt0099012/                            Alice
# 4     https://www.imdb.com/title/tt0099018/                  Almost an Angel
# ...                                     ...                              ...
# 7071  https://www.imdb.com/title/tt1255919/                  Holmes & Watson
# 7072  https://www.imdb.com/title/tt6266538/                             Vice
# 7073  https://www.imdb.com/title/tt4669788/              On the Basis of Sex
# 7074  https://www.imdb.com/title/tt7137380/                        Destroyer
# 7075  https://www.imdb.com/title/tt9495224/                     Bandersnatch
#
#              Directed by                                        Produced by  \
# 0           Renny Harlin                         [Steve Perry, Joel Silver]
# 1            James Foley                        [Ric Kidney, Robert Redlin]
# 2     Roger Spottiswoode                                     Daniel Melnick
# 3            Woody Allen                                    Robert Greenhut
# 4           John Cornell                                       John Cornell
# ...                  ...                                                ...
# 7071          Etan Cohen  [Will Ferrell, Adam McKay, Jimmy Miller, Clayt...
# 7072          Adam McKay  [Brad Pitt, Dede Gardner, Jeremy Kleiner, Kevi...
# 7073          Mimi Leder                                     Robert W. Cort
# 7074        Karyn Kusama             [Fred Berger, Phil Hay, Matt Manfredi]
# 7075         David Slade                                     Russell McLean
#
#                                    Screenplay by                     Story by  \
# 0     [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# 1                   [James Foley, Robert Redlin]                          NaN
# 2                     [John Eskow, Richard Rush]                          NaN
# 3                                            NaN                          NaN
# 4                                            NaN                          NaN
# ...                                          ...                          ...
# 7071                                  Etan Cohen                          NaN
# 7072                                         NaN                          NaN
# 7073                                         NaN                          NaN
# 7074                                         NaN                          NaN
# 7075                                         NaN                          NaN
#
#                                                Based on  \
# 0                           [Characters, by Rex Weiner]
# 1     [the novel, After Dark, My Sweet, by, Jim Thom...
# 2                [Air America, by, Christopher Robbins]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7071  [Sherlock Holmes, and, Dr. Watson, by, Sir Art...
# 7072                                                NaN
# 7073                                                NaN
# 7074                                                NaN
# 7075                                                NaN
#
#                                                Starring  ... Hepburn  \
# 0     [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  ...     NaN
# 1     [Jason Patric, Rachel Ward, Bruce Dern, George...  ...     NaN
# 2     [Mel Gibson, Robert Downey Jr., Nancy Travis, ...  ...     NaN
# 3     [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  ...     NaN
# 4           [Paul Hogan, Elias Koteas, Linda Kozlowski]  ...     NaN
# ...                                                 ...  ...     ...
# 7071  [Will Ferrell, John C. Reilly, Rebecca Hall, R...  ...     NaN
# 7072  [Christian Bale, Amy Adams, Steve Carell, Sam ...  ...     NaN
# 7073  [Felicity Jones, Armie Hammer, Justin Theroux,...  ...     NaN
# 7074  [Nicole Kidman, Sebastian Stan, Toby Kebbell, ...  ...     NaN
# 7075  [Fionn Whitehead, Will Poulter, Craig Parkinso...  ...     NaN
#
#      Literally Cantonese Chinese Yiddish Arabic Romanized Russian Hebrew  \
# 0          NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 1          NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 2          NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 3          NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 4          NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# ...        ...       ...     ...     ...    ...       ...     ...    ...
# 7071       NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 7072       NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 7073       NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 7074       NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
# 7075       NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
#
#      Polish
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 7071    NaN
# 7072    NaN
# 7073    NaN
# 7074    NaN
# 7075    NaN
#
# [6832 rows x 75 columns]

# %%
wiki_movies_df[wiki_movies_df['Hangul'].notnull()]['url']
# Out:
# 3413    https://en.wikipedia.org/wiki/Wonderful_Days_(...
# 4238             https://en.wikipedia.org/wiki/Shark_Bait
# Name: url, dtype: object

# %%
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Adaptation by',
#  'Also known as',
#  'Animation by',
#  'Arabic',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cantonese',
#  'Chinese',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Country of origin',
#  'Created by',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Edited by',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'French',
#  'Genre',
#  'Hangul',
#  'Hebrew',
#  'Hepburn',
#  'Japanese',
#  'Label',
#  'Language',
#  'Length',
#  'Literally',
#  'Mandarin',
#  'McCune–Reischauer',
#  'Music by',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Original title',
#  'Picture format',
#  'Polish',
#  'Preceded by',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
#  'Productioncompany ',
#  'Recorded',
#  'Release date',
#  'Released',
#  'Revised Romanization',
#  'Romanized',
#  'Running time',
#  'Russian',
#  'Screen story by',
#  'Screenplay by',
#  'Simplified',
#  'Starring',
#  'Story by',
#  'Suggested by',
#  'Theme music composer',
#  'Traditional',
#  'Venue',
#  'Voices of',
#  'Written by',
#  'Yiddish',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
wiki_movies_df[wiki_movies_df['Chinese'].notnull()]
# Out:
#                                          url  year  \
# 6620  https://en.wikipedia.org/wiki/Rock_Dog  2017
#
#                                   imdb_link     title  Directed by  \
# 6620  https://www.imdb.com/title/tt2822672/  Rock Dog  Ash Brannon
#
#                                             Produced by  \
# 6620  [Amber Wang, David B. Miller, Rob Feng, Joyce ...
#
#                     Screenplay by                  Story by  \
# 6620  [Ash Brannon, Kurt Voelker]  [Ash Brannon, Zheng Jun]
#
#                               Based on  \
# 6620  [Tibetan Rock Dog, by Zheng Jun]
#
#                                                Starring  ... Hepburn  \
# 6620  [Luke Wilson, Eddie Izzard, J. K. Simmons, Lew...  ...     NaN
#
#      Literally Cantonese Chinese Yiddish Arabic Romanized Russian Hebrew  \
# 6620       NaN       NaN    摇滚藏獒     NaN    NaN       NaN     NaN    NaN
#
#      Polish
# 6620    NaN
#
# [1 rows x 75 columns]

# %%
wiki_movies_df[wiki_movies_df['Also known as'].notnull()]['url']
# Out:
# 1342    https://en.wikipedia.org/wiki/Night_Watch_(199...
# Name: url, dtype: object

# %%
wiki_movies_df['Chinese'].to_list()[6620]
# Out:
# '摇滚藏獒'

# %%
# Make an empty dict to hold all of the alternative titles.
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    alt_titles = {}
    return movie

# %%
# Make an empty dict to hold all of the alternative titles.
# Loop through a list of all alternative title keys
# Check if the current key exists in the movie object. If so, remove the key-value pair and add to the alternative titles dict.
# After looping through every key, add the alternative titles dict to the movie object.
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    alt_titles = {}
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune–Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:
        if key in movie:
            alt_titles[key] = movie[key]
            movie.pop(key)
    if len(alt_titles) > 0:
        movie['alt_titles'] = alt_titles
    return movie

# %%
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    alt_titles = {}
    # combine alternate titles into one list
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune-Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:
        if key in movie:
            alt_titles[key] = movie[key]
            movie.pop(key)
    if len(alt_titles) > 0:
        movie['alt_titles'] = alt_titles

    # merge column names
    def change_column_name(old_name, new_name):
        if old_name in movie:
            movie[new_name] = movie.pop(old_name)
    change_column_name('Adaptation by', 'Writer(s)')
    change_column_name('Country of origin', 'Country')
    change_column_name('Directed by', 'Director')
    change_column_name('Distributed by', 'Distributor')
    change_column_name('Edited by', 'Editor(s)')
    change_column_name('Length', 'Running time')
    change_column_name('Original release', 'Release date')
    change_column_name('Music by', 'Composer(s)')
    change_column_name('Produced by', 'Producer(s)')
    change_column_name('Producer', 'Producer(s)')
    change_column_name('Productioncompanies ', 'Production company(s)')
    change_column_name('Productioncompany ', 'Production company(s)')
    change_column_name('Released', 'Release Date')
    change_column_name('Release Date', 'Release date')
    change_column_name('Screen story by', 'Writer(s)')
    change_column_name('Screenplay by', 'Writer(s)')
    change_column_name('Story by', 'Writer(s)')
    change_column_name('Theme music composer', 'Composer(s)')
    change_column_name('Written by', 'Writer(s)')

    return movie

# %%
clean_movies = [clean_movie(movie) for movie in wiki_movies]
wiki_movies_df = pd.DataFrame(clean_movies)

# %%
clean_movies
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/The_Adventures_of_Ford_Fairlane',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098987/',
#   'title': 'The Adventures of Ford Fairlane',
#   'Based on': ['Characters', 'by Rex Weiner'],
#   'Starring': ['Andrew Dice Clay',
#    'Wayne Newton',
#    'Priscilla Presley',
#    'Lauren Holly',
#    'Morris Day',
#    'Robert Englund',
#    "Ed O'Neill"],
#   'Narrated by': 'Andrew "Dice" Clay',
#   'Cinematography': 'Oliver Wood',
#   'Release date': ['July 11, 1990', '(', '1990-07-11', ')'],
#   'Running time': '102 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20 million',
#   'Box office': '$21.4 million',
#   'Director': 'Renny Harlin',
#   'Distributor': '20th Century Fox',
#   'Editor(s)': 'Michael Tronick',
#   'Composer(s)': ['Cliff Eidelman', 'Yello'],
#   'Producer(s)': ['Steve Perry', 'Joel Silver'],
#   'Production company(s)': 'Silver Pictures',
#   'Writer(s)': ['David Arnott', 'James Cappe']},
#  {'url': 'https://en.wikipedia.org/wiki/After_Dark,_My_Sweet',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098994/',
#   'title': 'After Dark, My Sweet',
#   'Based on': ['the novel', 'After Dark, My Sweet', 'by', 'Jim Thompson'],
#   'Starring': ['Jason Patric',
#    'Rachel Ward',
#    'Bruce Dern',
#    'George Dickerson'],
#   'Cinematography': 'Mark Plummer',
#   'Release date': ['May 17, 1990',
#    '(',
#    '1990-05-17',
#    ')',
#    '(Cannes Film Market)',
#    'August 24, 1990',
#    '(',
#    '1990-08-24',
#    ')',
#    '(United States)'],
#   'Running time': '114 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$6 million',
#   'Box office': '$2.7 million',
#   'Director': 'James Foley',
#   'Distributor': 'Avenue Pictures',
#   'Editor(s)': 'Howard E. Smith',
#   'Composer(s)': 'Maurice Jarre',
#   'Producer(s)': ['Ric Kidney', 'Robert Redlin'],
#   'Production company(s)': 'Avenue Pictures',
#   'Writer(s)': ['James Foley', 'Robert Redlin']},
#  {'url': 'https://en.wikipedia.org/wiki/Air_America_(film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099005/',
#   'title': 'Air America',
#   'Based on': ['Air America', 'by', 'Christopher Robbins'],
#   'Starring': ['Mel Gibson',
#    'Robert Downey Jr.',
#    'Nancy Travis',
#    'David Marshall Grant',
#    'Lane Smith'],
#   'Cinematography': 'Roger Deakins',
#   'Release date': ['August 10, 1990', '(', '1990-08-10', ')'],
#   'Running time': '113 minutes',
#   'Country': 'United States',
#   'Language': ['English', 'Lao'],
#   'Budget': '$35 million',
#   'Box office': '$57,718,089',
#   'Director': 'Roger Spottiswoode',
#   'Distributor': 'TriStar Pictures',
#   'Editor(s)': ['John Bloom', 'Lois Freeman-Fox'],
#   'Composer(s)': 'Charles Gross',
#   'Producer(s)': 'Daniel Melnick',
#   'Production company(s)': ['Carolco Pictures', 'IndieProd Company'],
#   'Writer(s)': ['John Eskow', 'Richard Rush']},
#  {'url': 'https://en.wikipedia.org/wiki/Alice_(1990_film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099012/',
#   'title': 'Alice',
#   'Starring': ['Alec Baldwin',
#    'Blythe Danner',
#    'Judy Davis',
#    'Mia Farrow',
#    'William Hurt',
#    'Keye Luke',
#    'Joe Mantegna',
#    'Bernadette Peters'],
#   'Cinematography': 'Carlo Di Palma',
#   'Release date': ['December 25, 1990', '(', '1990-12-25', ')'],
#   'Running time': '106 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$12 million',
#   'Box office': '$7,331,647',
#   'Director': 'Woody Allen',
#   'Distributor': 'Orion Pictures',
#   'Editor(s)': 'Susan E. Morse',
#   'Producer(s)': 'Robert Greenhut',
#   'Writer(s)': 'Woody Allen'},
#  {'url': 'https://en.wikipedia.org/wiki/Almost_an_Angel',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099018/',
#   'title': 'Almost an Angel',
#   'Starring': ['Paul Hogan', 'Elias Koteas', 'Linda Kozlowski'],
#   'Cinematography': 'Russell Boyd',
#   'Release date': 'December 19, 1990',
#   'Running time': '95 minutes',
#   'Country': 'US',
#   'Language': 'English',
#   'Budget': '$25 million',
#   'Box office': '$6,939,946 (USA)',
#   'Director': 'John Cornell',
#   'Distributor': 'Paramount Pictures',
#   'Editor(s)': 'David Stiven',
#   'Composer(s)': 'Maurice Jarre',
#   'Producer(s)': 'John Cornell',
#   'Writer(s)': 'Paul Hogan'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Ambulance',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099026/',
#   'title': 'The Ambulance',
#   'Starring': ['Eric Roberts',
#    'James Earl Jones',
#    'Red Buttons',
#    'Megan Gallagher'],
#   'Cinematography': 'Jacques Haitkin',
#   'Release date': ['March 22, 1990', '(', '1990-03-22', ')'],
#   'Running time': '95 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Director': 'Larry Cohen',
#   'Distributor': 'Triumph Releasing Corporation',
#   'Editor(s)': ['Claudia Finkle', 'Armond Leibowitz'],
#   'Composer(s)': 'Jay Chattaway',
#   'Producer(s)': ['Larry Cohen', 'Moctesuma Esparza', 'Robert Katz'],
#   'Production company(s)': 'Epic Productions',
#   'Writer(s)': 'Larry Cohen'},
#  {'url': 'https://en.wikipedia.org/wiki/American_Dream_(film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099028/',
#   'title': 'American Dream',
#   'Cinematography': ['Tom Hurwitz', 'Mathieu Roberts', 'Nesya Shapiro'],
#   'Release date': ['October 6, 1990',
#    '(',
#    '1990-10-06',
#    ')',
#    '(',
#    'New York Film Festival',
#    ')'],
#   'Running time': '100 minutes',
#   'Country': ['United States', 'United Kingdom'],
#   'Language': 'English',
#   'Director': ['Barbara Kopple',
#    'Co-directors:',
#    'Cathy Caplan',
#    'Thomas Haneke',
#    'Lawrence Silk'],
#   'Distributor': 'Prestige Films',
#   'Editor(s)': ['Cathy Caplan', 'Thomas Haneke', 'Lawrence Silk'],
#   'Composer(s)': 'Michael Small',
#   'Producer(s)': ['Arthur Cohn', 'Barbara Kopple'],
#   'Production company(s)': ['Cabin Creek',
#    'Catholic Communication Campaign',
#    'Channel 4 Films']},
#  {'url': 'https://en.wikipedia.org/wiki/American_Ninja_4:_The_Annihilation',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0101326/',
#   'title': 'American Ninja 4: The Annihilation',
#   'Starring': ['Michael Dudikoff',
#    'David Bradley',
#    'James Booth',
#    'Dwayne Alexandre'],
#   'Release date': ['March 8, 1991', '(', '1991-03-08', ')'],
#   'Running time': '99 minutes',
#   'Country': ['United States', 'Lesotho'],
#   'Language': 'English',
#   'Director': 'Cedric Sundstrom',
#   'Distributor': 'Cannon Group',
#   'Producer(s)': 'Ovidio G Assonitis',
#   'Writer(s)': 'David Geeves'},
#  {'url': 'https://en.wikipedia.org/wiki/Andre%27s_Mother',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099037/',
#   'title': "Andre's Mother",
#   'Starring': ['Richard Thomas', 'Sada Thompson', 'Sylvia Sidney'],
#   'Cinematography': 'Bobby Bukowski',
#   'Release date': ['March 7, 1990', '(', '1990-03-07', ')'],
#   'Running time': '50 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Director': 'Deborah Reinisch',
#   'Distributor': 'Public Broadcasting Service',
#   'Editor(s)': 'Jeffrey Wolf',
#   'Composer(s)': 'Jonathan Sheffer',
#   'Producer(s)': ['Sarah Green', 'Deborah Reinisch'],
#   'Writer(s)': 'Terrence McNally'},
#  {'url': 'https://en.wikipedia.org/wiki/Angel_Town_(film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099039/',
#   'title': 'Angel Town',
#   'Starring': ['Olivier Gruner',
#    'Theresa Saldana',
#    'Frank Aragon',
#    'Tony Valentino',
#    'Peter Kwong',
#    'Mike Moroff'],
#   'Cinematography': 'John LeBlanc',
#   'Release date': ['February 23, 1990 (', 'USA', ')'],
#   'Running time': '102 min',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$855,810',
#   'Director': 'Eric Karson',
#   'Distributor': 'Imperial Entertainment',
#   'Editor(s)': 'Duane Hartzell',
#   'Composer(s)': 'Terry Plumeri',
#   'Producer(s)': ['Ash R. Shah', 'Eric Karson'],
#   'Writer(s)': 'S. Warren'},
#  {'url': 'https://en.wikipedia.org/wiki/Another_48_Hrs.',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099044/',
#   'title': 'Another 48 Hrs.',
#   'Based on': ['Characters by',
#    'Roger Spottiswoode',
#    'Walter Hill',
#    'Larry Gross',
#    'Steven E. de Souza'],
#   'Starring': ['Eddie Murphy',
#    'Nick Nolte',
#    'Brion James',
#    "Ed O'Ross",
#    'Andrew Divoff'],
#   'Cinematography': 'Matthew F. Leonetti',
#   'Release date': ['June 8, 1990', '(', '1990-06-08', ')'],
#   'Running time': '93 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$50 million',
#   'Box office': '$195.3 million',
#   'Director': 'Walter Hill',
#   'Distributor': 'Paramount Pictures',
#   'Editor(s)': ['Donn Aron',
#    'Carmel Davies',
#    'Freeman A. Davies',
#    'Tim Ryder'],
#   'Composer(s)': 'James Horner',
#   'Producer(s)': ['Lawrence Gordon', 'Robert D. Wachs'],
#   'Production company(s)': 'Eddie Murphy Productions',
#   'Writer(s)': 'Fred Braughton'},
#  {'url': 'https://en.wikipedia.org/wiki/Arachnophobia_(film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099052/',
#   'title': 'Arachnophobia',
#   'Starring': ['Jeff Daniels',
#    'Julian Sands',
#    'Harley Jane Kozak',
#    'John Goodman'],
#   'Cinematography': 'Mikael Salomon',
#   'Release date': ['July 18, 1990', '(', '1990-07-18', ')'],
#   'Running time': '110 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$22 million',
#   'Box office': '$53.2 million',
#   'Director': 'Frank Marshall',
#   'Distributor': 'Buena Vista Pictures',
#   'Editor(s)': 'Michael Kahn',
#   'Composer(s)': 'Trevor Jones',
#   'Producer(s)': ['Kathleen Kennedy', 'Richard Vane'],
#   'Production company(s)': ['Hollywood Pictures',
#    'Amblin Entertainment',
#    'Tangled Web Productions'],
#   'Writer(s)': ['Don Jakoby', 'Al Williams']},
#  {'url': 'https://en.wikipedia.org/wiki/Avalon_(1990_film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099073/',
#   'title': 'Avalon',
#   'Starring': ['Armin Mueller-Stahl',
#    'Elizabeth Perkins',
#    'Joan Plowright',
#    'Aidan Quinn'],
#   'Cinematography': 'Allen Daviau',
#   'Release date': ['October 5, 1990',
#    '(',
#    '1990-10-05',
#    ')',
#    '(United States)'],
#   'Running time': '126 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$15.7 million',
#   'Director': 'Barry Levinson',
#   'Distributor': ['TriStar Pictures',
#    '(United States)',
#    'Columbia Pictures',
#    '(United Kingdom)',
#    '[1]'],
#   'Editor(s)': 'Stu Linder',
#   'Composer(s)': 'Randy Newman',
#   'Producer(s)': ['Mark Johnson', 'Barry Levinson'],
#   'Production company(s)': 'Baltimore Pictures',
#   'Writer(s)': 'Barry Levinson'},
#  {'url': 'https://en.wikipedia.org/wiki/Awakenings',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099077/',
#   'title': 'Awakenings',
#   'Based on': ['Awakenings', 'by', 'Oliver Sacks'],
#   'Starring': ['Robert De Niro',
#    'Robin Williams',
#    'John Heard',
#    'Julie Kavner',
#    'Penelope Ann Miller',
#    'Max von Sydow'],
#   'Cinematography': 'Miroslav Ondricek',
#   'Release date': ['December 20, 1990 (limited U.S.)',
#    'January 11, 1991 (wide U.S.)'],
#   'Running time': '121 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$29 million',
#   'Box office': '$52.1 million',
#   'Director': 'Penny Marshall',
#   'Distributor': 'Columbia Pictures',
#   'Editor(s)': ['Battle Davis', 'Jerry Greenberg'],
#   'Composer(s)': 'Randy Newman',
#   'Producer(s)': ['Walter F. Parkes', 'Lawrence Lasker'],
#   'Production company(s)': 'Lasker/Parkes Productions',
#   'Writer(s)': 'Steven Zaillian'},
#  {'url': 'https://en.wikipedia.org/wiki/Back_to_the_Future_Part_III',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099088/',
#   'title': 'Back to the Future Part III',
#   'Starring': ['Michael J. Fox',
#    'Christopher Lloyd',
#    'Mary Steenburgen',
#    'Thomas F. Wilson',
#    'Lea Thompson'],
#   'Cinematography': 'Dean Cundey',
#   'Release date': ['May 25, 1990', '(', '1990-05-25', ')'],
#   'Running time': '118 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$40 million',
#   'Box office': '$244.5 million',
#   'Director': 'Robert Zemeckis',
#   'Distributor': 'Universal Pictures',
#   'Editor(s)': ['Harry Keramidas', 'Arthur Schmidt'],
#   'Composer(s)': 'Alan Silvestri',
#   'Producer(s)': ['Neil Canton', 'Bob Gale'],
#   'Production company(s)': ['Amblin Entertainment',
#    '[1]',
#    'Universal Pictures',
#    '[1]'],
#   'Writer(s)': ['Robert Zemeckis', 'Bob Gale']},
#  {'url': 'https://en.wikipedia.org/wiki/Bad_Influence_(film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099091/',
#   'title': 'Bad Influence',
#   'Starring': ['Rob Lowe', 'James Spader'],
#   'Cinematography': 'Robert Elswit',
#   'Release date': 'March 9, 1990',
#   'Running time': '99 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$7 million',
#   'Box office': '$12,626,043',
#   'Director': 'Curtis Hanson',
#   'Distributor': 'Triumph Releasing Corporation',
#   'Editor(s)': 'Bonnie Koehler',
#   'Composer(s)': 'Trevor Jones',
#   'Producer(s)': 'Steve Tisch',
#   'Production company(s)': 'Epic Productions',
#   'Writer(s)': 'David Koepp'},
#  {'url': 'https://en.wikipedia.org/wiki/Basket_Case_2',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099108/',
#   'title': 'Basket Case 2',
#   'Starring': 'Kevin Van Hentenryck',
#   'Cinematography': 'Robert M. Baldwin',
#   'Release date': ['March 2, 1990', '(', '1990-03-02', ')'],
#   'Running time': '90 minutes',
#   'Language': 'English',
#   'Budget': ['$2,500,000', '[', 'citation needed', ']'],
#   'Director': 'Frank Henenlotter',
#   'Distributor': 'Shapiro Glickenhaus Entertainment',
#   'Editor(s)': 'Kevin Tent',
#   'Composer(s)': 'Joe Renzetti',
#   'Producer(s)': 'Edgar Ievins',
#   'Writer(s)': 'Frank Henenlotter'},
#  {'url': 'https://en.wikipedia.org/wiki/Betsy%27s_Wedding',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099128/',
#   'title': "Betsy's Wedding",
#   'Starring': ['Alan Alda',
#    'Joey Bishop',
#    'Madeline Kahn',
#    "Catherine O'Hara",
#    'Joe Pesci',
#    'Ally Sheedy',
#    'Burt Young',
#    'Molly Ringwald'],
#   'Cinematography': 'Kelvin Pike',
#   'Release date': ['June 22, 1990', '(', '1990-06-22', ')'],
#   'Running time': '94 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$19,740,070',
#   'Director': 'Alan Alda',
#   'Distributor': 'Buena Vista Pictures',
#   'Editor(s)': 'Michael E. Polakow',
#   'Composer(s)': 'Bruce Broughton',
#   'Producer(s)': ['Martin Bregman', 'Louis A. Stroller'],
#   'Production company(s)': 'Touchstone Pictures',
#   'Writer(s)': 'Alan Alda'},
#  {'url': 'https://en.wikipedia.org/wiki/Bird_on_a_Wire_(film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099141/',
#   'title': 'Bird on a Wire',
#   'Starring': ['Mel Gibson', 'Goldie Hawn', 'David Carradine', 'Bill Duke'],
#   'Cinematography': 'Robert Primes',
#   'Release date': ['May 18, 1990', '(', '1990-05-18', ')'],
#   'Running time': '110 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20 million',
#   'Box office': '$138,697,012',
#   'Director': 'John Badham',
#   'Distributor': 'Universal Pictures',
#   'Editor(s)': ['Frank Morriss', 'Dallas Puett'],
#   'Composer(s)': 'Hans Zimmer',
#   'Producer(s)': 'Rob Cohen',
#   'Production company(s)': ['Interscope Communications',
#    'The Badham/Cohen Group'],
#   'Writer(s)': ['Louis Venosta', 'David Seltzer']},
#  {'url': 'https://en.wikipedia.org/wiki/Blind_Faith_(1990_film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099148/',
#   'title': 'Blind Faith',
#   'Genre': 'Thriller',
#   'Based on': ['Blind Faith', 'by', 'Joe McGinniss'],
#   'Starring': ['Robert Urich',
#    'Joanna Kerns',
#    'David Barry Gray',
#    'Jay Underwood',
#    'Johnny Galecki'],
#   'Original language(s)': 'English',
#   'Producer(s)': ['Susan Baerwald (executive producer)',
#    'Dan Wigutow (executive producer)',
#    'Daniel Franklin (co-producer)'],
#   'Cinematography': 'Chuck Arnold',
#   'Editor(s)': ['Christopher Cooke', 'James Galloway'],
#   'Running time': '190 minutes',
#   'Production company(s)': 'NBC Productions',
#   'Original network': 'NBC',
#   'Country': 'United States',
#   'Director': 'Paul Wendkos',
#   'Release date': 'February 11, 1990',
#   'Writer(s)': 'Joe McGinniss',
#   'Composer(s)': 'Laurence Rosenthal'},
#  {'url': 'https://en.wikipedia.org/wiki/Bloodfist_II',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099155/',
#   'title': 'Bloodfist II',
#   'Starring': ['Don Wilson',
#    'Maurice Smith',
#    'James Warring',
#    'Timothy Baker',
#    'Richard Hill'],
#   'Cinematography': 'Bruce Dorfman',
#   'Release date': ['October 12, 1990', '(', '1990-10-12', ')'],
#   'Running time': '85 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$1,292,323',
#   'Director': 'Andy Blumenthal',
#   'Editor(s)': 'Karen D. Joseph',
#   'Composer(s)': 'Nigel Holton',
#   'Producer(s)': ['New Horizons',
#    'Concorde Pictures',
#    '(',
#    'Roger Corman',
#    'Catherine Cyran',
#    'Cirio H. Santiago',
#    ')'],
#   'Writer(s)': 'Catherine Cyran'},
#  {'url': 'https://en.wikipedia.org/wiki/Blue_Steel_(1990_film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099160/',
#   'title': 'Blue Steel',
#   'Starring': ['Jamie Lee Curtis',
#    'Ron Silver',
#    'Clancy Brown',
#    'Elizabeth Peña',
#    'Louise Fletcher'],
#   'Cinematography': 'Amir Mokri',
#   'Release date': ['January 1990',
#    '(',
#    '1990-01',
#    ')',
#    '(',
#    'Sundance Film Festival',
#    ')',
#    'March 16, 1990',
#    '(',
#    '1990-03-16',
#    ')'],
#   'Running time': '102 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$8.2 million',
#   'Director': 'Kathryn Bigelow',
#   'Distributor': 'Metro-Goldwyn-Mayer',
#   'Editor(s)': 'Lee Percy',
#   'Composer(s)': 'Brad Fiedel',
#   'Producer(s)': ['Edward R. Pressman', 'Oliver Stone', 'Lawrence Kasanoff'],
#   'Production company(s)': ['Lightning Pictures',
#    'Mack-Taylor Productions',
#    'Precision Films'],
#   'Writer(s)': ['Kathryn Bigelow', 'Eric Red', '[1]']},
#  {'url': 'https://en.wikipedia.org/wiki/The_Bonfire_of_the_Vanities_(film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099165/',
#   'title': 'The Bonfire of the Vanities',
#   'Based on': ['The Bonfire of the Vanities', 'by', 'Tom Wolfe'],
#   'Starring': ['Tom Hanks',
#    'Bruce Willis',
#    'Melanie Griffith',
#    'Morgan Freeman'],
#   'Cinematography': 'Vilmos Zsigmond',
#   'Release date': ['December 21, 1990', '(', '1990-12-21', ')'],
#   'Running time': '126 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$47 million',
#   'Box office': '$15.6 million',
#   'Director': 'Brian De Palma',
#   'Distributor': 'Warner Bros.',
#   'Editor(s)': ['Bill Pankow', 'David Ray'],
#   'Composer(s)': 'Dave Grusin',
#   'Producer(s)': 'Brian De Palma',
#   'Writer(s)': 'Michael Cristofer'},
#  {'url': 'https://en.wikipedia.org/wiki/Bride_of_Re-Animator',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099180/',
#   'title': 'Bride of Re-Animator',
#   'Based on': ['Characters', 'by', 'H. P. Lovecraft'],
#   'Starring': ['Jeffrey Combs',
#    'Bruce Abbott',
#    'Fabiana Udenio',
#    'Kathleen Kinmont'],
#   'Cinematography': 'Rick Fichter',
#   'Release date': ['September 8, 1990',
#    '(',
#    '1990-09-08',
#    ')',
#    '(',
#    'TIFF',
#    ')',
#    'February 22, 1991',
#    '(',
#    '1991-02-22',
#    ')'],
#   'Running time': '96 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Director': 'Brian Yuzna',
#   'Distributor': '50th Street Films',
#   'Editor(s)': 'Peter Teschner',
#   'Composer(s)': 'Richard Band',
#   'Producer(s)': 'Brian Yuzna',
#   'Production company(s)': 'Wild Street Pictures',
#   'Writer(s)': ['Rick Fry', 'Woody Keith', 'Brian Yuzna']},
#  {'url': 'https://en.wikipedia.org/wiki/Cadence_(film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0101531/',
#   'title': 'Cadence',
#   'Starring': ['Charlie Sheen',
#    'Martin Sheen',
#    'Laurence Fishburne',
#    'Michael Beach',
#    'Ramon Estevez'],
#   'Cinematography': 'Richard Leiterman',
#   'Release date': ['1990',
#    '(',
#    '1990',
#    ')',
#    '(Deauville Film Festival)',
#    'January 18, 1990',
#    '(',
#    '1990-01-18',
#    ')',
#    '(U.S.)'],
#   'Running time': '97 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$2,070,871',
#   'Director': 'Martin Sheen',
#   'Distributor': ['New Line Cinema', 'Republic Pictures'],
#   'Editor(s)': 'Martin Hunter',
#   'Composer(s)': 'Georges Delerue',
#   'Producer(s)': ['Timothy Gamble', 'Frank Giustra', 'Peter E. Strauss'],
#   'Writer(s)': 'Dennis Shryack'},
#  {'url': 'https://en.wikipedia.org/wiki/Cadillac_Man',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099204/',
#   'title': 'Cadillac Man',
#   'Starring': ['Robin Williams',
#    'Tim Robbins',
#    'Pamela Reed',
#    'Fran Drescher'],
#   'Cinematography': 'David Gribble',
#   'Release date': ['May 18, 1990', '(', '1990-05-18', ')'],
#   'Running time': '97 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$15 million',
#   'Box office': '$27.6 million (United States)',
#   'Director': 'Roger Donaldson',
#   'Distributor': 'Orion Pictures',
#   'Editor(s)': 'Richard Francis-Bruce',
#   'Composer(s)': 'J. Peter Robinson',
#   'Producer(s)': ['Roger Donaldson', 'Charles Roven'],
#   'Writer(s)': 'Ken Friedman'},
#  {'url': 'https://en.wikipedia.org/wiki/Camp_Cucamonga',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099212/',
#   'title': 'Camp Cucamonga',
#   'Genre': ['Action', 'Adventure', 'Comedy'],
#   'Starring': ['John Ratzenberger',
#    'Brian Robbins',
#    'Jennifer Aniston',
#    'Chad Allen',
#    'Candace Cameron',
#    'Danica McKellar',
#    'Josh Saviano',
#    'Tasha Scott',
#    'Jaleel White',
#    'Johnny Galecki',
#    'Dorothy Lyman',
#    'Richard Herd',
#    'Sherman Hemsley',
#    'G. Gordon Liddy'],
#   'Original language(s)': 'English',
#   'Executive producer(s)': 'Rich Melcombe',
#   'Producer(s)': ['Scott Maitland (co-producer)',
#    'Bennett Tramer (supervising producer)'],
#   'Production location(s)': ['Paramount Ranch - 2813 Cornell Road,',
#    'Agoura, California'],
#   'Cinematography': 'Peter Smokler',
#   'Editor(s)': 'Larry Harris',
#   'Running time': '93 min',
#   'Production company(s)': ['NBC Productions', 'Richmel Productions'],
#   'Distributor': 'NBC',
#   'Original network': 'NBC',
#   'Picture format': 'Color',
#   'Audio format': 'Stereo',
#   'Country': 'United States',
#   'Director': 'Roger Duchowny',
#   'Release date': 'September 23, 1990',
#   'Composer(s)': 'Michael Cruz',
#   'Writer(s)': ['Bennett Tramer (Story & teleplay)',
#    'Rich Melcombe',
#    '(Story)']},
#  {'url': 'https://en.wikipedia.org/wiki/Captain_America_(1990_film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0103923/',
#   'title': 'Captain America',
#   'Based on': ['Captain America', 'by', 'Joe Simon', 'Jack Kirby'],
#   'Starring': ['Matt Salinger',
#    'Ronny Cox',
#    'Scott Paulin',
#    'Ned Beatty',
#    'Darren McGavin',
#    'Francesca Neri',
#    'Michael Nouri'],
#   'Cinematography': 'Philip Alan Waters',
#   'Release date': ['December 14, 1990',
#    '(',
#    '1990-12-14',
#    ')',
#    '(United Kingdom)',
#    'July 22, 1992',
#    '(',
#    '1992-07-22',
#    ')',
#    '(United States)'],
#   'Running time': '97 minutes',
#   'Country': ['Yugoslavia', 'United States'],
#   'Language': 'English',
#   'Budget': '$10 million',
#   'Box office': '$10,173',
#   'Director': 'Albert Pyun',
#   'Distributor': ['20/20 Vision',
#    '(UK VHS)',
#    'Columbia Tristar Home Video',
#    '(US VHS)',
#    'Metro-Goldwyn-Mayer',
#    '(Current)'],
#   'Editor(s)': 'Jon Poll',
#   'Composer(s)': 'Barry Goldberg',
#   'Producer(s)': ['Joseph Calamari',
#    'Menahem Golan',
#    'Tom Karnowski',
#    'Stan Lee'],
#   'Production company(s)': ['Marvel Entertainment Group',
#    'Jadran Film',
#    '21st Century Film Corporation'],
#   'Writer(s)': ['Stephen Tolkin', 'Lawrence Block']},
#  {'url': 'https://en.wikipedia.org/wiki/Cartoon_All-Stars_to_the_Rescue',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0154129/',
#   'title': 'Cartoon All-Stars to the Rescue',
#   'Genre': 'Social guidance film',
#   'Voices of': 'See full below',
#   'Original language(s)': 'English',
#   'Executive producer(s)': 'Roy E. Disney',
#   'Producer(s)': 'Buzz Potamkin',
#   'Editor(s)': 'Jay Bixsen',
#   'Running time': '32 min.',
#   'Production company(s)': ['Southern Star Productions',
#    'Wang Film Productions',
#    '(animation)'],
#   'Distributor': ["McDonald's",
#    '(sponsorship)',
#    "Ronald McDonald Children's Charities",
#    '(sponsorship)',
#    "Chuck E. Cheese's",
#    '(sponsorship)',
#    'Buena Vista Home Video',
#    '(VHS)'],
#   'Original network': ['ABC',
#    'NBC',
#    'Fox',
#    'CBS',
#    'USA Network',
#    'Syndication'],
#   'Followed by': 'See below',
#   'Country': 'United States',
#   'Director': ['Milton Gray',
#    'Marsh Lamore',
#    'Bob Shellhorn',
#    'Mike Svayko',
#    'Karen Peterson',
#    '(supervising)'],
#   'Release date': ['April 21, 1990',
#    '(',
#    '1990-04-21',
#    ')',
#    '(USA)',
#    'June 22, 1990',
#    '(',
#    '1990-06-22',
#    ')',
#    '(UK)'],
#   'Composer(s)': ['Richard Kosinski',
#    'Sam Winans',
#    'Paul Buckmaster',
#    'Bill Reichenbach',
#    'Bob Mann',
#    'Guy Moon',
#    'Alan Menken'],
#   'Writer(s)': ['Duane Poole', 'Tom Swale']},
#  {'url': 'https://en.wikipedia.org/wiki/Catchfire',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0096875/',
#   'title': 'Catchfire',
#   'Starring': ['Jodie Foster', 'Dennis Hopper', 'Fred Ward', 'Vincent Price'],
#   'Cinematography': 'Edward Lachman',
#   'Release date': ['April 3, 1990', '(', '1990-04-03', ')'],
#   'Running time': '98 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$10 million',
#   'Box office': '$5 million',
#   'Director': ['Dennis Hopper', '(as', 'Alan Smithee', ')'],
#   'Distributor': 'Vestron Pictures',
#   'Editor(s)': 'David Rawlins',
#   'Composer(s)': 'Curt Sobel',
#   'Producer(s)': 'Dick Clark',
#   'Writer(s)': ['Rachel Kronstadt Mann',
#    'Ann Louise Bardach',
#    'Alex Cox',
#    'Tod Davies']},
#  {'url': 'https://en.wikipedia.org/wiki/Challenger_(1990_film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099237/',
#   'title': 'Challenger',
#   'Starring': ['Karen Allen',
#    'Barry Bostwick',
#    'Richard Jenkins',
#    'Joe Morton',
#    'Keone Young',
#    'Brian Kerwin',
#    'Julie Fulton',
#    'Kale Browne',
#    'Kristin Bond',
#    'Angela Bassett'],
#   'Composer(s)': 'David E. Cole',
#   'Original language(s)': 'English',
#   'Producer(s)': ['George Englund', 'Courtney Pledger', 'Debbie Robins'],
#   'Original network': 'American Broadcasting Company',
#   'Country': 'United States',
#   'Director': 'Ben Jordan',
#   'Release date': ['February 25, 1990', '(', '1990-02-25', ')'],
#   'Writer(s)': 'George Englund'},
#  {'url': 'https://en.wikipedia.org/wiki/Checkered_Flag_(film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099245/',
#   'title': 'Checkered Flag',
#   'Release date': ['1990', '(', '1990', ')', '[1]'],
#   'Running time': '95 minutes',
#   'Language': 'English',
#   'Director': ['John Glen', 'Michael Levine'],
#   'Distributor': 'New World International',
#   'Producer(s)': 'James Margellos',
#   'Writer(s)': ['Clayton Frohman', 'E.F. Wallengren', 'Jason Brett']},
#  {'url': 'https://en.wikipedia.org/wiki/Child_in_the_Night',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099252/',
#   'title': 'Child in the Night',
#   'Genre': 'Mystery/Thriller/Suspense',
#   'Starring': ['JoBeth Williams',
#    'Tom Skerritt',
#    'Elijah Wood',
#    'Darren McGavin',
#    'Season Hubley'],
#   'Original language(s)': 'English',
#   'Executive producer(s)': 'Mike Robe',
#   'Producer(s)': ['Ian Martin',
#    'John Perrin Flynn (co-producer)',
#    'Benjamin A. Weissman (co-producer)'],
#   'Cinematography': 'Gerald Hirschfeld',
#   'Editor(s)': 'Benjamin A. Weissman',
#   'Running time': '98 minutes',
#   'Production company(s)': ['Allied Communications',
#    'Jayhawk Productions',
#    'Mike Robe Productions'],
#   'Distributor': 'CBS',
#   'Original network': 'CBS',
#   'Country': 'United States',
#   'Director': 'Mike Robe',
#   'Release date': 'May 1, 1990',
#   'Composer(s)': 'Mark Snow',
#   'Writer(s)': 'Michael Petryni'},
#  {'url': 'https://en.wikipedia.org/wiki/Child%27s_Play_2',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099253/',
#   'title': "Child's Play 2",
#   'Based on': ['Characters', 'by Don Mancini'],
#   'Starring': ['Alex Vincent',
#    'Jenny Agutter',
#    'Gerrit Graham',
#    'Christine Elise',
#    'Grace Zabriskie'],
#   'Cinematography': 'Stefan Czapsky',
#   'Release date': ['November 9, 1990', '(', '1990-11-09', ')'],
#   'Running time': '84 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$13 million',
#   'Box office': '$35.8 million',
#   'Director': 'John Lafia',
#   'Distributor': 'Universal Pictures',
#   'Editor(s)': 'Edward Warschilka',
#   'Composer(s)': 'Graeme Revell',
#   'Producer(s)': 'David Kirschner',
#   'Production company(s)': 'Living Doll Productions',
#   'Writer(s)': 'Don Mancini'},
#  {'url': 'https://en.wikipedia.org/wiki/China_Cry',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0101578/',
#   'title': 'China Cry',
#   'Based on': ['China Cry', 'by', 'Nora Lam', '& Irene Burk Harrell'],
#   'Starring': ['Julia Nickson-Soul', 'France Nuyen', 'James Shigeta'],
#   'Cinematography': 'David Worth',
#   'Release date': ['November 2, 1990', '(', '1990-11-02', ')', '(USA)'],
#   'Running time': '101 min',
#   'Country': 'USA',
#   'Language': 'English',
#   'Box office': ['US$', '4,212,828'],
#   'Director': 'James F. Collier',
#   'Distributor': 'Penland Productions',
#   'Editor(s)': 'Duane Hartzell & Ruby Yang',
#   'Composer(s)': ['Joel Hirschhorn', '&', 'Al Kasha'],
#   'Producer(s)': 'Don L. Parker',
#   'Production company(s)': 'Parakletus, TBN Films',
#   'Writer(s)': 'James F. Collier'},
#  {'url': 'https://en.wikipedia.org/wiki/The_China_Lake_Murders',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099259/',
#   'title': 'The China Lake Murders',
#   'Genre': ['Mystery', 'Thriller'],
#   'Starring': ['Isaac Allan', 'Tom Skerritt', 'Michael Parks'],
#   'Original language(s)': 'English',
#   'Executive producer(s)': ['James G. Hirsch', 'Robert A. Papazian'],
#   'Producer(s)': ['William Beaudine Jr.', 'Beth Tate (co-producer)'],
#   'Cinematography': 'Geoffrey Schaaf',
#   'Editor(s)': 'Sidney Wolinsky',
#   'Running time': '97 min',
#   'Production company(s)': ['MCA Television Entertainment',
#    'Papazian-Hirsch Entertainment International'],
#   'Distributor': 'Fox Broadcasting Company',
#   'Picture format': 'Color',
#   'Audio format': 'Mono',
#   'Country': 'United States',
#   'Director': 'Alan Metzger',
#   'Release date': ['January 31, 1990', '(', '1990-01-31', ')'],
#   'Composer(s)': 'Dana Kaproff',
#   'Writer(s)': 'N.D. Schreiner'},
#  {'url': 'https://en.wikipedia.org/wiki/China_O%27Brien',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099260/',
#   'title': "China O'Brien",
#   'Starring': ['Cynthia Rothrock',
#    'Richard Norton',
#    'Keith Cooke',
#    'Doug Wright',
#    'Nijel',
#    'Arturo Rivera'],
#   'Cinematography': 'Kent L. Wakeford',
#   'Release date': ['1988', '(', '1988', ')'],
#   'Running time': '86 minutes',
#   'Language': 'English',
#   'Director': 'Robert Clouse',
#   'Distributor': ['Studio / Sterling', 'Golden Harvest', 'Media Asia Group'],
#   'Editor(s)': 'Mark Harrah',
#   'Composer(s)': ['David Wheatley', 'Paul Antonelli'],
#   'Producer(s)': ['Fred Weintraub', 'Sandra Weintraub'],
#   'Writer(s)': 'Sandra Weintraub'},
#  {'url': 'https://en.wikipedia.org/wiki/Class_of_1999',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099277/',
#   'title': 'Class of 1999',
#   'Starring': ['Bradley Gregg',
#    'Traci Lind',
#    'John P. Ryan',
#    'Pam Grier',
#    'Joshua Miller',
#    'Stacy Keach',
#    'Malcolm McDowell'],
#   'Cinematography': 'Mark Irwin',
#   'Release date': 'May 11, 1990',
#   'Running time': '99 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$5.2 million',
#   'Box office': '$2.4 million',
#   'Director': 'Mark L. Lester',
#   'Distributor': 'Lightning Pictures',
#   'Editor(s)': 'Scott Conrad',
#   'Composer(s)': 'Michael Hoenig',
#   'Producer(s)': 'Mark L. Lester',
#   'Writer(s)': 'Mark L. Lester'},
#  {'url': 'https://en.wikipedia.org/wiki/Coins_in_the_Fountain',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099284/',
#   'title': 'Coins in the Fountain',
#   'Starring': ['Loni Anderson',
#    'Stepfanie Kramer',
#    'Shanna Reed',
#    'Carl Weintraub',
#    'Stuart Wilson',
#    'Anthony Newley'],
#   'Producer(s)': 'Joseph B. Wallenstein',
#   'Editor(s)': 'J. Benjamin Chulay',
#   'Running time': '97 minutes',
#   'Director': 'Tony Wharmby',
#   'Release date': ['September 28, 1990', '(', '1990-09-28', ')'],
#   'Composer(s)': 'Nan Schwartz',
#   'Writer(s)': 'Lindsay Harrison'},
#  {'url': 'https://en.wikipedia.org/wiki/Come_See_the_Paradise',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099291/',
#   'title': 'Come See the Paradise',
#   'Starring': ['Dennis Quaid',
#    'Tamlyn Tomita',
#    'Sab Shimono',
#    'Shizuko Hoshi'],
#   'Cinematography': 'Michael Seresin',
#   'Release date': ['December 23, 1990', '(', '1990-12-23', ')'],
#   'Running time': '138 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$17.5 million',
#   'Box office': '$947,306',
#   'Director': 'Alan Parker',
#   'Distributor': '20th Century Fox',
#   'Editor(s)': 'Gerry Hambling',
#   'Composer(s)': 'Randy Edelman',
#   'Producer(s)': ['Robert F. Colesberry', 'Nellie Nugiel'],
#   'Writer(s)': 'Alan Parker'},
#  {'url': 'https://en.wikipedia.org/wiki/Coupe_de_Ville_(film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099310/',
#   'title': 'Coupe de Ville',
#   'Starring': ['Patrick Dempsey',
#    'Arye Gross',
#    'Daniel Stern',
#    'Annabeth Gish',
#    'Rita Taggart',
#    'Joseph Bologna',
#    'Alan Arkin'],
#   'Cinematography': 'Reynaldo Villalobos',
#   'Release date': ['March 9, 1990', '(', '1990-03-09', ')'],
#   'Running time': '99 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$715,983',
#   'Director': 'Joe Roth',
#   'Distributor': 'Universal Pictures',
#   'Editor(s)': 'Paul Hirsch',
#   'Composer(s)': 'James Newton Howard',
#   'Producer(s)': ['James G. Robinson', 'Mike Binder'],
#   'Production company(s)': 'Morgan Creek Productions',
#   'Writer(s)': 'Mike Binder'},
#  {'url': 'https://en.wikipedia.org/wiki/Crash_and_Burn_(1990_film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099313/',
#   'title': 'Crash and Burn',
#   'Starring': ['Paul Ganus', 'Megan Ward', 'Jack McGee', 'Eva LaRue'],
#   'Cinematography': 'Mark Ahlberg',
#   'Release date': ['September 1990', '(', '1990-09', ')'],
#   'Running time': '85 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Director': 'Charles Band',
#   'Distributor': 'Paramount Home Video',
#   'Editor(s)': 'Ted Nicolaou',
#   'Composer(s)': 'Richard Band',
#   'Producer(s)': ['David DeCoteau', 'John Schouweiler'],
#   'Production company(s)': 'Full Moon Entertainment',
#   'Writer(s)': 'J. S. Cardone'},
#  {'url': 'https://en.wikipedia.org/wiki/Crazy_People',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099316/',
#   'title': 'Crazy People',
#   'Starring': ['Dudley Moore', 'Daryl Hannah', 'Paul Reiser'],
#   'Cinematography': 'Victor J. Kemper',
#   'Release date': ['April 13, 1990', '(', '1990-04-13', ')', '(U.S.)'],
#   'Running time': '91 min.',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': 'US$18 million',
#   'Box office': 'US$13,236,513',
#   'Director': ['Tony Bill', 'Barry L. Young (commercials)'],
#   'Distributor': 'Paramount Pictures',
#   'Editor(s)': 'Mia Goldman',
#   'Composer(s)': 'Cliff Eidelman',
#   'Producer(s)': ['Thomas Brand', 'Robert K. Weiss'],
#   'Writer(s)': 'Mitch Markowitz'},
#  {'url': 'https://en.wikipedia.org/wiki/Cry-Baby',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099329/',
#   'title': 'Cry-Baby',
#   'Starring': ['Johnny Depp',
#    'Amy Locane',
#    'Susan Tyrrell',
#    'Iggy Pop',
#    'Ricki Lake',
#    'Traci Lords',
#    'Polly Bergen'],
#   'Cinematography': 'David Insley',
#   'Release date': ['March 14, 1990',
#    '(',
#    '1990-03-14',
#    ')',
#    '(Baltimore)',
#    'April 6, 1990',
#    '(',
#    '1990-04-06',
#    ')',
#    '(United States)'],
#   'Running time': '85 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$12 million',
#   'Box office': '$8.3 million',
#   'Director': 'John Waters',
#   'Distributor': 'Universal Pictures',
#   'Editor(s)': 'Janice Hampton',
#   'Composer(s)': 'Patrick Williams',
#   'Producer(s)': 'Rachel Talalay',
#   'Production company(s)': 'Imagine Entertainment',
#   'Writer(s)': 'John Waters'},
#  {'url': 'https://en.wikipedia.org/wiki/Daddy%27s_Dyin%27:_Who%27s_Got_the_Will%3F',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099342/',
#   'title': "Daddy's Dyin' ...Who's Got the Will?",
#   'Starring': ['Beau Bridges',
#    "Beverly D'Angelo",
#    'Tess Harper',
#    'Judge Reinhold',
#    'Amy Wright',
#    'Patrika Darbo',
#    'Molly McClure',
#    'Keith Carradine'],
#   'Cinematography': 'Paul Elliott',
#   'Release date': ['May 4, 1990', '(', '1990-05-04', ')'],
#   'Running time': '95 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$4 million',
#   'Box office': '$1,373,728',
#   'Director': 'Jack Fisk',
#   'Distributor': ['MGM', '/', 'UA', 'Pictures Inc.'],
#   'Editor(s)': 'Edward A. Warschilka',
#   'Composer(s)': 'David McHugh',
#   'Producer(s)': ['Steve Golin', 'Monty Montgomery'],
#   'Production company(s)': ['Metro-Goldwyn-Mayer', 'Propaganda Films'],
#   'Writer(s)': 'Del Shores'},
#  {'url': 'https://en.wikipedia.org/wiki/Dances_with_Wolves',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099348/',
#   'title': 'Dances with Wolves',
#   'Based on': ['Dances with Wolves', 'by Michael Blake'],
#   'Starring': ['Kevin Costner',
#    'Mary McDonnell',
#    'Graham Greene',
#    'Rodney Grant'],
#   'Cinematography': 'Dean Semler',
#   'Release date': ['October 19, 1990',
#    '(',
#    '1990-10-19',
#    ')',
#    '(',
#    'Uptown Theater',
#    ')',
#    'November 9, 1990',
#    '(',
#    '1990-11-09',
#    ')',
#    '(United States)'],
#   'Running time': '181 minutes',
#   'Country': 'United States',
#   'Language': ['English', 'Lakota', 'Pawnee'],
#   'Budget': '$22 million',
#   'Box office': '$424.2 million',
#   'Director': 'Kevin Costner',
#   'Distributor': 'Orion Pictures',
#   'Editor(s)': 'Neil Travis',
#   'Composer(s)': 'John Barry',
#   'Producer(s)': ['Jim Wilson', 'Kevin Costner'],
#   'Production company(s)': 'Tig Productions',
#   'Writer(s)': 'Michael Blake'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Dark_Side_of_the_Moon_(1990_film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099364/',
#   'title': 'The Dark Side of the Moon',
#   'Starring': ['Robert Sampson',
#    'Will Bledsoe',
#    'Joe Turkel',
#    'Camilla More',
#    'John Diehl',
#    'Wendy MacDonald',
#    'Alan Blumenfeld'],
#   'Release date': ['1990', '(', '1990', ')'],
#   'Country': 'United States',
#   'Language': 'English',
#   'Director': 'D.J. Webster',
#   'Distributor': 'Trimark Pictures',
#   'Composer(s)': ['Philip Davies', 'Mark Ryder'],
#   'Producer(s)': ['Keith Walley', 'D.J. Webster'],
#   'Writer(s)': ['Carey Hayes', 'Chad Hayes']},
#  {'url': 'https://en.wikipedia.org/wiki/Darkman',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099365/',
#   'title': 'Darkman',
#   'Starring': ['Liam Neeson',
#    'Frances McDormand',
#    'Colin Friels',
#    'Larry Drake'],
#   'Cinematography': 'Bill Pope',
#   'Release date': ['August 24, 1990', '(', '1990-08-24', ')'],
#   'Running time': '95 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$16 million',
#   'Box office': '$48.8 million',
#   'Director': 'Sam Raimi',
#   'Distributor': 'Universal Pictures',
#   'Editor(s)': ['Bud S. Smith', 'David Stiven'],
#   'Composer(s)': 'Danny Elfman',
#   'Producer(s)': 'Robert Tapert',
#   'Production company(s)': 'Renaissance Pictures',
#   'Writer(s)': 'Sam Raimi'},
#  {'url': 'https://en.wikipedia.org/wiki/Daughter_of_Darkness_(1990_film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099368/',
#   'title': 'Daughter of Darkness',
#   'Genre': 'Horror',
#   'Starring': ['Anthony Perkins',
#    'Mia Sara',
#    'Robert Reynolds',
#    'Dezsõ Garas',
#    'Jack Coleman'],
#   'Original language(s)': 'English',
#   'Executive producer(s)': ['Gerald W. Abrams', 'Harry B. Chandler'],
#   'Producer(s)': 'Andras Hamori',
#   'Production location(s)': 'Budapest',
#   'Cinematography': 'Iván Márk',
#   'Editor(s)': 'Andy Horvitch',
#   'Running time': '93 minutes',
#   'Production company(s)': ['Accent Entertainment Corporation',
#    'King Phoenix Entertainment'],
#   'Distributor': ['CBS', 'King Features Entertainment'],
#   'Original network': 'CBS',
#   'Picture format': 'Color',
#   'Audio format': 'Stereo',
#   'Country': 'United States',
#   'Director': 'Stuart Gordon',
#   'Release date': ['January 26, 1990', '(', '1990-01-26', ')'],
#   'Composer(s)': 'Colin Towns',
#   'Writer(s)': 'Andrew Laskos'},
#  {'url': 'https://en.wikipedia.org/wiki/Days_of_Thunder',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099371/',
#   'title': 'Days of Thunder',
#   'Starring': ['Tom Cruise',
#    'Robert Duvall',
#    'Randy Quaid',
#    'Nicole Kidman',
#    'Michael Rooker',
#    'John C. Reilly',
#    'Cary Elwes'],
#   'Cinematography': 'Ward Russell',
#   'Release date': ['June 27, 1990', '(', '1990-06-27', ')'],
#   'Running time': '108 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$60 million',
#   'Box office': '$157.9 million',
#   'Director': 'Tony Scott',
#   'Distributor': 'Paramount Pictures',
#   'Editor(s)': ['Billy Weber', 'Chris Lebenzon'],
#   'Composer(s)': 'Hans Zimmer',
#   'Producer(s)': ['Don Simpson', 'Jerry Bruckheimer'],
#   'Production company(s)': 'Don Simpson/Jerry Bruckheimer Productions',
#   'Writer(s)': ['Robert Towne', 'Tom Cruise']},
#  {'url': 'https://en.wikipedia.org/wiki/Death_Machine',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0109575/',
#   'title': 'Death Machine',
#   'Starring': ['Brad Dourif',
#    'Ely Pouget',
#    'William Hootkins',
#    'John Sharian',
#    'Richard Brake'],
#   'Cinematography': 'John de Borman',
#   'Release date': ['February 4, 1994',
#    '(',
#    'February 4, 1994',
#    ')',
#    '(United Kingdom)',
#    '[1]'],
#   'Running time': '120 minutes',
#   'Country': ['United Kingdom', '[1]', 'Japan', '[1]'],
#   'Budget': '$6.5 million',
#   'Director': 'Stephen Norrington',
#   'Distributor': 'Entertainment Film Distributors',
#   'Editor(s)': 'Paul Endacott',
#   'Composer(s)': 'Crispin Merrell',
#   'Producer(s)': 'Dominic Anciano',
#   'Production company(s)': 'Fugitive Features',
#   'Writer(s)': 'Stephen Norrington'},
#  {'url': 'https://en.wikipedia.org/wiki/Deceptions',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099390/',
#   'title': 'Deceptions',
#   'Genre': 'Drama',
#   'Starring': ['Harry Hamlin',
#    'Robert Davi',
#    'Nicollette Sheridan',
#    'Marshall Colt',
#    'Kevin King'],
#   'Original language(s)': 'English',
#   'Executive producer(s)': ['Ruben Preuss', 'Miguel Tejada-Flores'],
#   'Producer(s)': 'Guy J. Louthan',
#   'Production location(s)': 'Los Angeles',
#   'Cinematography': 'Zoran Hochstatter',
#   'Editor(s)': 'Rozanne Zingale',
#   'Running time': '95 minutes',
#   'Production company(s)': ['Alpha Entertainment', 'Showtime Networks'],
#   'Distributor': 'Republic Pictures Home Video',
#   'Original network': 'Showtime',
#   'Picture format': 'Color',
#   'Audio format': ['Ultra', 'Stereo'],
#   'Country': 'United States',
#   'Director': 'Ruben Preuss',
#   'Release date': ['June 10, 1990', '(', '1990-06-10', ')'],
#   'Composer(s)': 'Gary S. Scott',
#   'Writer(s)': ['Ken Denbow', 'Richard Taylor']},
#  {'url': 'https://en.wikipedia.org/wiki/Decoration_Day_(film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099391/',
#   'title': 'Decoration Day',
#   'Genre': 'Drama',
#   'Created by': ['John William Corrington', '(novel)'],
#   'Starring': ['James Garner',
#    'Judith Ivey',
#    'Ruby Dee',
#    'Bill Cobbs',
#    'Laurence Fishburne',
#    'Jo Anderson',
#    'Norm Skaggs',
#    'Wallace Wilkinson'],
#   'Original language(s)': 'English',
#   'Producer(s)': ['Dick Gallegly', 'Marian Rees'],
#   'Production location(s)': ['Agness Scott College', 'Newnan, Georgia'],
#   'Cinematography': 'Neil Roach',
#   'Editor(s)': 'Harvey Rosenstock',
#   'Running time': '100 minutes',
#   'Production company(s)': ['Hallmark Hall of Fame',
#    'Marian Rees Associates',
#    'Vantage Entertainment Group'],
#   'Distributor': 'NBC',
#   'Original network': 'NBC',
#   'Picture format': 'Color',
#   'Audio format': 'Mono',
#   'Country': 'United States',
#   'Director': 'Robert Markowitz',
#   'Release date': 'December 2, 1990',
#   'Composer(s)': 'Patrick Williams',
#   'Writer(s)': 'Robert W. Lenski'},
#  {'url': 'https://en.wikipedia.org/wiki/Def_by_Temptation',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099395/',
#   'title': 'Def by Temptation',
#   'Starring': ['James Bond III',
#    'Kadeem Hardison',
#    'Bill Nunn',
#    'Samuel L. Jackson',
#    'Minnie Gentry',
#    'Rony Clanton',
#    'John Canada Terrell',
#    'Cynthia Bond'],
#   'Cinematography': 'Ernest R. Dickerson',
#   'Release date': ['May 11, 1990', '(', '1990-05-11', ')'],
#   'Running time': '94 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$2.2 million',
#   'Director': 'James Bond III',
#   'Distributor': 'Shapiro-Glickenhaus Entertainment',
#   'Editor(s)': ["Brian O'Hara", 'Li-Shin Yu'],
#   'Composer(s)': 'Paul Laurence',
#   'Producer(s)': 'James Bond III',
#   'Production company(s)': ['Bonded Filmworks', 'Orpheus Pictures'],
#   'Writer(s)': 'James Bond III'},
#  {'url': 'https://en.wikipedia.org/wiki/Delta_Force_2:_The_Colombian_Connection',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099399/',
#   'title': 'Delta Force 2',
#   'Based on': ['Characters', 'by James Bruner', 'Menahem Golan'],
#   'Starring': ['Chuck Norris',
#    'John P. Ryan',
#    'Paul Perri',
#    'Richard Jaeckel',
#    'Begoña Plaza',
#    'Mateo Gómez',
#    'Héctor Mercado',
#    'Billy Drago'],
#   'Cinematography': 'João Fernandes',
#   'Release date': ['August 24, 1990', '(', '1990-08-24', ')'],
#   'Running time': '111 minutes',
#   'Country': 'United States',
#   'Language': 'English, Spanish',
#   'Budget': '$16 million',
#   'Box office': ['$6,698,361 (', 'United States', ')', '[2]'],
#   'Director': 'Aaron Norris',
#   'Distributor': 'Metro-Goldwyn-Mayer',
#   'Editor(s)': 'Michael J. Duthie',
#   'Composer(s)': 'Frédéric Talgorn',
#   'Producer(s)': ['Yoram Globus', 'Christopher Pearce'],
#   'Production company(s)': 'The Cannon Group',
#   'Writer(s)': 'Lee Reynolds'},
#  {'url': 'https://en.wikipedia.org/wiki/Denial_(1990_film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0101707/',
#   'title': 'Denial',
#   'Starring': ['Robin Wright', 'Jason Patric', 'Rae Dawn Chong'],
#   'Release date': ['January 1990', '(', '1990-01', ')'],
#   'Running time': '103 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Director': 'Erin Dignam',
#   'Writer(s)': 'Erin Dignam'},
#  {'url': 'https://en.wikipedia.org/wiki/Desperate_Hours',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099409/',
#   'title': 'Desperate Hours',
#   'Based on': ['Desperate Hours', 'by Joseph Hayes'],
#   'Starring': ['Mickey Rourke',
#    'Anthony Hopkins',
#    'Mimi Rogers',
#    'Lindsay Crouse',
#    'Kelly Lynch'],
#   'Cinematography': 'Douglas Milsome',
#   'Release date': ['October 5, 1990', '(', '1990-10-05', ')'],
#   'Running time': '106 minutes',
#   'Language': 'English',
#   'Budget': '$18 million',
#   'Box office': '$2.7 million (US)',
#   'Director': 'Michael Cimino',
#   'Distributor': 'MGM/UA Distribution Co.',
#   'Editor(s)': ['Christopher Rouse', 'Peter R. Hunt', '(supervising editor)'],
#   'Composer(s)': 'David Mansfield',
#   'Producer(s)': ['Michael Cimino', 'Dino De Laurentiis'],
#   'Production company(s)': ['Dino De Laurentiis Communications',
#    'Cannon Films',
#    'Film and Television Company',
#    '[1]'],
#   'Writer(s)': ['Joseph Hayes', 'Lawrence Konner', 'Mark Rosenthal']},
#  {'url': 'https://en.wikipedia.org/wiki/Dick_Tracy_(1990_film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099422/',
#   'title': 'Dick Tracy',
#   'Based on': ['Dick Tracy', 'by', 'Chester Gould'],
#   'Starring': ['Warren Beatty',
#    'Al Pacino',
# ...
#   'Release date': ['1994', '(', '1994', ')'],
#   'Running time': '70 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Director': 'Caveh Zahedi',
#   'Editor(s)': ['Caveh Zahedi',
#    'Molly Fitzjarrald',
#    'Amanda Field',
#    'Thomas Logoreci'],
#   'Producer(s)': 'Henry S. Rosenthal'},
#  {'url': 'https://en.wikipedia.org/wiki/I_Like_It_Like_That_(film)',
#   'year': 1994,
#   'imdb_link': 'https://www.imdb.com/title/tt0110091/',
#   'title': 'I Like It Like That',
#   'Starring': ['Lauren Velez',
#    'Jon Seda',
#    'Griffin Dunne',
#    'Jesse Borrego',
#    'Rita Moreno',
#    'Lisa Vidal'],
#   'Release date': ['October 14, 1994', '(', '1994-10-14', ')'],
#   'Running time': '104 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Director': 'Darnell Martin',
#   'Distributor': 'Columbia Pictures',
#   'Producer(s)': ['Ann Carli',
#    'Victor De Jesus',
#    'Wendy Finerman',
#    'Lane Janger',
#    'Stephen Lloyd',
#    'Diana Phillips',
#    'Tracy Leigh Vilar'],
#   'Writer(s)': 'Darnell Martin'},
#  {'url': 'https://en.wikipedia.org/wiki/I_Love_Trouble_(1994_film)',
#   'year': 1994,
#   'imdb_link': 'https://www.imdb.com/title/tt0110093/',
#   'title': 'I Love Trouble',
#   'Starring': ['Julia Roberts',
#    'Nick Nolte',
#    'Saul Rubinek',
#    'Robert Loggia',
#    'James Rebhorn'],
#   'Cinematography': 'John Lindley',
#   'Release date': ['June 29, 1994', '(', '1994-06-29', ')', '(U.S.)'],
#   'Running time': '123 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$45 million',
#   'Box office': '$61.9 million',
#   'Director': 'Charles Shyer',
#   'Distributor': 'Buena Vista Pictures',
#   'Editor(s)': 'Walter Murch',
#   'Composer(s)': 'David Newman',
#   'Producer(s)': 'Nancy Meyers',
#   'Production company(s)': ['Touchstone Pictures', 'Caravan Pictures'],
#   'Writer(s)': ['Charles Shyer', 'Nancy Meyers']},
#  {'url': 'https://en.wikipedia.org/wiki/I%27ll_Do_Anything',
#   'year': 1994,
#   'imdb_link': 'https://www.imdb.com/title/tt0110097/',
#   'title': "I'll Do Anything",
#   'Starring': ['Nick Nolte',
#    'Albert Brooks',
#    'Julie Kavner',
#    'Joely Richardson',
#    'Tracey Ullman',
#    'Whittni Wright'],
#   'Cinematography': 'Michael Ballhaus',
#   'Release date': ['February 4, 1994', '(', '1994-02-04', ')'],
#   'Running time': '115 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$40 million',
#   'Box office': '$10 million',
#   'Director': 'James L. Brooks',
#   'Distributor': 'Columbia Pictures',
#   'Editor(s)': 'Richard Marks',
#   'Composer(s)': 'Hans Zimmer',
#   'Producer(s)': ['James L. Brooks', 'Polly Platt'],
#   'Production company(s)': 'Gracie Films',
#   'Writer(s)': 'James L. Brooks'},
#  {'url': 'https://en.wikipedia.org/wiki/I.Q._(film)',
#   'year': 1994,
#   'imdb_link': 'https://www.imdb.com/title/tt0110099/',
#   'title': 'I.Q.',
#   'Starring': ['Meg Ryan', 'Tim Robbins', 'Walter Matthau', 'Charles Durning'],
#   'Cinematography': 'Ian Baker',
#   'Release date': 'December 25, 1994',
#   'Running time': '95 minutes',
#   'Country': 'United States',
#   'Language': ['English', 'German'],
#   'Budget': '$25 million',
#   'Box office': '$26,381,221',
#   'Director': 'Fred Schepisi',
#   'Distributor': 'Paramount Pictures',
#   'Editor(s)': 'Jill Bilcock',
#   'Composer(s)': 'Jerry Goldsmith',
#   'Producer(s)': ['Fred Schepisi',
#    'Carol Baum',
#    'Scott Rudin',
#    'Neil A. Machlis'],
#   'Writer(s)': 'Andy Breckman'},
#  {'url': 'https://en.wikipedia.org/wiki/Imaginary_Crimes',
#   'year': 1994,
#   'imdb_link': 'https://www.imdb.com/title/tt0110115/',
#   'title': 'Imaginary Crimes',
#   'Based on': ['Imaginary Crimes', 'by', 'Sheila Ballantyne'],
#   'Starring': ['Harvey Keitel',
#    'Fairuza Balk',
#    'Kelly Lynch',
#    "Vincent D'Onofrio",
#    'Chris Penn',
#    'Seymour Cassel'],
#   'Cinematography': 'John J. Campbell',
#   'Release date': ['October 14, 1994', '(', '1994-10-14', ')'],
#   'Running time': '107 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$89,611',
#   'Director': 'Anthony Drazan',
#   'Distributor': 'Warner Bros.',
#   'Editor(s)': 'Elizabeth Kling',
#   'Composer(s)': 'Stephen Endelman',
#   'Producer(s)': 'James G. Robinson',
#   'Production company(s)': 'Morgan Creek Productions',
#   'Writer(s)': ['Kristine Johnson', 'Davia Nelson']},
#  {'url': 'https://en.wikipedia.org/wiki/Immortal_Beloved_(1994_film)',
#   'year': 1994,
#   'imdb_link': 'https://www.imdb.com/title/tt0110116/',
#   'title': 'Immortal Beloved',
#   'Starring': ['Gary Oldman',
#    'Jeroen Krabbé',
#    'Isabella Rossellini',
#    'Johanna ter Steege',
#    'Valeria Golino'],
#   'Release date': ['December 16, 1994', '(', '1994-12-16', ')'],
#   'Running time': '121 minutes',
#   'Country': ['United Kingdom', 'United States'],
#   'Language': ['English', 'Hungarian'],
#   'Box office': '$9.9 million',
#   'Director': 'Bernard Rose',
#   'Distributor': 'Columbia Pictures',
#   'Composer(s)': ['George Fenton',
#    'Ludwig van Beethoven',
#    'Gioacchino Rossini'],
#   'Producer(s)': ['Stephen McEveety', 'Bruce Davey'],
#   'Production company(s)': 'Icon Productions',
#   'Writer(s)': 'Bernard Rose'},
#  {'url': 'https://en.wikipedia.org/wiki/In_Search_of_Dr._Seuss',
#   'year': 1994,
#   'imdb_link': 'https://www.imdb.com/title/tt0110121/',
#   'title': 'In Search of Dr. Seuss',
#   'Starring': ['Kathy Najimy',
#    'Matt Frewer',
#    'Christopher Lloyd',
#    'Graham Jarvis',
#    'Brady Bluhm',
#    'Andrea Martin',
#    'David Paymer',
#    'J.D. Daniels',
#    'Patrick Stewart',
#    'Billy Crystal',
#    'Andraé Crouch',
#    'Bright Eyes',
#    'Robin Williams',
#    'Eileen Brennan'],
#   'Composer(s)': 'Steve Goldstein',
#   'Original language(s)': 'English',
#   'Producer(s)': ['Keith R. Clarke', 'Joni Levin', 'Thomas A. Walsh'],
#   'Cinematography': 'Michael Lonzo',
#   'Editor(s)': 'Michael Kelly',
#   'Running time': '90 minutes',
#   'Distributor': 'Turner Home Entertainment',
#   'Original network': 'TNT',
#   'Country': 'United States',
#   'Director': 'Vincent Paterson',
#   'Release date': ['November 6, 1994', '(', '1994-11-06', ')'],
#   'Writer(s)': 'Keith R. Clarke'},
#  {'url': 'https://en.wikipedia.org/wiki/In_the_Army_Now_(film)',
#   'year': 1994,
#   'imdb_link': 'https://www.imdb.com/title/tt0110123/',
#   'title': 'In the Army Now',
#   'Starring': ['Pauly Shore',
#    'Lori Petty',
#    'David Alan Grier',
#    'Andy Dick',
#    'Esai Morales'],
#   'Cinematography': 'William Wages',
#   'Release date': ['August 12, 1994', '(', '1994-08-12', ')'],
#   'Running time': '88 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$28,881,266',
#   'Director': 'Daniel Petrie, Jr.',
#   'Distributor': 'Buena Vista Pictures',
#   'Editor(s)': 'O. Nicholas Brown',
#   'Composer(s)': 'Robert Folk',
#   'Producer(s)': 'Michael Rotenberg',
#   'Production company(s)': 'Hollywood Pictures',
#   'Writer(s)': ['Steve Zacharias', 'Jeff Buhai', 'Robbie Fox']},
#  {'url': 'https://en.wikipedia.org/wiki/The_Inkwell',
#   'year': 1994,
#   'imdb_link': 'https://www.imdb.com/title/tt0110137/',
#   'title': 'The Inkwell',
#   'Starring': ['Larenz Tate',
#    'Joe Morton',
#    'Suzzanne Douglas',
#    'Glynn Turman'],
#   'Cinematography': 'John L. Demps, Jr.',
#   'Release date': 'April 22, 1994',
#   'Running time': '110 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$8,000,000 (approximately)',
#   'Box office': '$8,880,705',
#   'Director': 'Matty Rich',
#   'Distributor': 'Buena Vista Pictures',
#   'Editor(s)': 'Quinnie Martin Jr.',
#   'Composer(s)': 'Terrence Blanchard',
#   'Producer(s)': ['Irving Azoff',
#    'Matthew Baer',
#    'Jon J. Jashni',
#    'Guy Riedel'],
#   'Production company(s)': 'Touchstone Pictures',
#   'Writer(s)': ['Trey Ellis', 'Paris Qualles']},
#  {'url': 'https://en.wikipedia.org/wiki/Intersection_(1994_film)',
#   'year': 1994,
#   'imdb_link': 'https://www.imdb.com/title/tt0110146/',
#   'title': 'Intersection',
#   'Starring': ['Richard Gere',
#    'Sharon Stone',
#    'Lolita Davidovich',
#    'Martin Landau'],
#   'Cinematography': 'Vilmos Zsigmond',
#   'Release date': ['January 21, 1994', '(', '1994-01-21', ')'],
#   'Running time': '98 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$45 million',
#   'Box office': '$21,355,893',
#   'Director': 'Mark Rydell',
#   'Distributor': 'Paramount Pictures',
#   'Editor(s)': 'Mark Warner',
#   'Composer(s)': 'James Newton Howard',
#   'Producer(s)': ['Mark Rydell', 'Bud Yorkin'],
#   'Writer(s)': ['David Rayfiel', 'Marshall Brickman']},
#  {'url': 'https://en.wikipedia.org/wiki/Interview_with_the_Vampire_(film)',
#   'year': 1994,
#   'imdb_link': 'https://www.imdb.com/title/tt0110148/',
#   'title': 'Interview with the Vampire',
#   'Based on': ['Interview with the Vampire', 'by Anne Rice'],
#   'Starring': ['Tom Cruise',
#    'Brad Pitt',
#    'Stephen Rea',
#    'Antonio Banderas',
#    'Christian Slater',
#    'Kirsten Dunst'],
#   'Cinematography': 'Philippe Rousselot',
#   'Release date': ['November 11, 1994', '(', '1994-11-11', ')'],
#   'Running time': '122 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$60 million',
#   'Box office': '$223.7 million',
#   'Director': 'Neil Jordan',
#   'Distributor': 'Warner Bros.',
#   'Editor(s)': ['Mick Audsley', 'Joke van Wijk'],
#   'Composer(s)': 'Elliot Goldenthal',
#   'Producer(s)': ['David Geffen', 'Stephen Woolley'],
#   'Production company(s)': 'The Geffen Film Company',
#   'Writer(s)': 'Anne Rice'},
#  {'url': 'https://en.wikipedia.org/wiki/Iron_Will',
#   'year': 1994,
#   'imdb_link': 'https://www.imdb.com/title/tt0110157/',
#   'title': 'Iron Will',
#   'Starring': ['Mackenzie Astin', 'Kevin Spacey', 'David Ogden Stiers'],
#   'Cinematography': 'William Wages',
#   'Release date': ['January 14, 1994', '(', '1994-01-14', ')'],
#   'Running time': '108 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$21 million',
#   'Director': 'Charles Haid',
#   'Distributor': 'Buena Vista Pictures',
#   'Editor(s)': 'Andrew Doerfer',
#   'Composer(s)': 'Joel McNeely',
#   'Producer(s)': ['Patrick J. Palmer',
#    'James Ployhar',
#    'Robert Schwartz',
#    'George Zepp'],
#   'Production company(s)': 'Walt Disney Pictures',
#   'Writer(s)': ['John Michael Hayes', 'Djordje Milicevic', 'Jeff Arch']},
#  {'url': 'https://en.wikipedia.org/wiki/Is_There_Life_Out_There%3F',
#   'year': 1994,
#   'imdb_link': 'https://www.imdb.com/title/tt0110160/',
#   'title': 'Is There Life Out There?',
#   'Genre': 'Drama',
#   'Starring': ['Reba McEntire',
#    'Keith Carradine',
#    'Genia Michaela',
#    'Mitchell Anderson'],
#   'Composer(s)': 'J. A. C. Redford',
#   'Original language(s)': 'English',
#   'Executive producer(s)': ['Narvel Blackstock', 'Reba McEntire'],
#   'Producer(s)': 'Anne Hopkins',
#   'Production location(s)': 'Nashville',
#   'Cinematography': 'Andrew Dunn',
#   'Editor(s)': 'Pamela Malouf-Cundy',
#   'Running time': '89 minutes',
#   'Production company(s)': ['Marian Rees Associates',
#    'Procter & Gamble Productions',
#    'Starstruck Entertainment'],
#   'Distributor': 'CBS',
#   'Original network': 'CBS',
#   'Picture format': 'Color',
#   'Audio format': 'Stereo',
#   'Country': 'United States',
#   'Director': 'David Jones',
#   'Release date': ['October 9, 1994', '(', '1994-10-09', ')'],
#   'Writer(s)': 'Dalene Young'},
#  {'url': 'https://en.wikipedia.org/wiki/It_Could_Happen_to_You_(1994_film)',
#   'year': 1994,
#   'imdb_link': 'https://www.imdb.com/title/tt0110167/',
#   'title': 'It Could Happen to You',
#   'Starring': ['Nicolas Cage',
#    'Bridget Fonda',
#    'Rosie Perez',
#    'Isaac Hayes',
#    'Seymour Cassel',
#    'Stanley Tucci',
#    'J.E. Freeman'],
#   'Cinematography': 'Caleb Deschanel',
#   'Release date': ['July 29, 1994', '(', '1994-07-29', ')'],
#   'Running time': '101 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20 million',
#   'Box office': '$37,939,757',
#   'Director': 'Andrew Bergman',
#   'Distributor': 'TriStar Pictures',
#   'Editor(s)': 'Barry Malkin',
#   'Composer(s)': ['Carter Burwell', 'Joe Mulherin'],
#   'Producer(s)': ['Mike Lobell', 'Gary Adelson'],
#   'Writer(s)': 'Jane Anderson'},
#  {'url': 'https://en.wikipedia.org/wiki/It_Don%27t_Cost_Nothin%27_to_Say_Good_Morning',
#   'year': 1994,
#   'imdb_link': 'https://www.imdb.com/title/tt0245173/',
#   'title': "It Don't Cost Nothin' to Say Good Morning",
#   'Starring': 'Kenny Hotz',
#   'Cinematography': ['Sebastian Cluer', 'Kenny Hotz'],
#   'Release date': ['1994', '(', '1994', ')'],
#   'Country': 'Canada',
#   'Director': ['Kenny Hotz', 'Spencer Rice'],
#   'Editor(s)': 'Kenny Hotz',
#   'Producer(s)': ['Sebastian Cluer', 'Kenny Hotz']},
#  {'url': 'https://en.wikipedia.org/wiki/It%27s_Pat',
#   'year': 1994,
#   'imdb_link': 'https://www.imdb.com/title/tt0110169/',
#   'title': "It's Pat",
#   'Based on': ['The character', 'by Julia Sweeney'],
#   'Starring': ['Julia Sweeney', 'Dave Foley', 'Charles Rocket'],
#   'Cinematography': 'Jeff Jur',
#   'Release date': ['August 26, 1994', '(', '1994-08-26', ')'],
#   'Running time': '78 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$8 million',
#   'Box office': '$60,822',
#   'Director': 'Adam Bernstein',
#   'Distributor': 'Buena Vista Pictures',
#   'Editor(s)': 'Norman Hollyn',
#   'Composer(s)': 'Mark Mothersbaugh',
#   'Producer(s)': 'Charles B. Wessler',
#   'Production company(s)': 'Touchstone Pictures',
#   'Writer(s)': ['Julia Sweeney', 'Jim Emerson', 'Stephen Hibbert']},
#  {'url': 'https://en.wikipedia.org/wiki/Jacob_(film)',
#   'year': 1994,
#   'imdb_link': 'https://www.imdb.com/title/tt0110175/',
#   'Starring': ['Matthew Modine',
#    'Lara Flynn Boyle',
#    'Sean Bean',
#    'Giancarlo Giannini'],
#   'Release date': 'December 4, 1994 (U.S.A.)',
#   'Director': 'Peter Hall',
#   'Distributor': 'TNT',
#   'Composer(s)': 'Ennio Morricone'},
#  {'url': 'https://en.wikipedia.org/wiki/Jason%27s_Lyric',
#   'year': 1994,
#   'imdb_link': 'https://www.imdb.com/title/tt0110186/',
#   'title': "Jason's Lyric",
#   'Starring': ['Allen Payne',
#    'Jada Pinkett',
#    'Bokeem Woodbine',
#    "Anthony 'Treach' Criss",
#    'Eddie Griffin',
#    'Forest Whitaker'],
#   'Cinematography': 'Francis Kenny',
#   'Release date': ['September 28, 1994', '(', '1994-09-28', ')'],
#   'Running time': '120 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$7 million',
#   'Box office': '$20,851,521',
#   'Director': 'Doug McHenry',
#   'Distributor': 'Gramercy Pictures',
#   'Editor(s)': 'Andrew Mondshein',
#   'Composer(s)': 'AR',
#   'Producer(s)': ['Doug McHenry', 'George Jackson', 'Marilla Lane Ross'],
#   'Production company(s)': ['PolyGram Filmed Entertainment',
#    'Propaganda Films',
#    'Jackson/McHenry Company'],
#   'Writer(s)': 'Bobby Smith, Jr'},
#  {'url': 'https://en.wikipedia.org/wiki/Jimmy_Hollywood',
#   'year': 1994,
#   'imdb_link': 'https://www.imdb.com/title/tt0110197/',
#   'title': 'Jimmy Hollywood',
#   'Starring': ['Joe Pesci', 'Christian Slater', 'Victoria Abril'],
#   'Cinematography': 'Peter Sova',
#   'Release date': ['April 1, 1994', '(', '1994-04-01', ')'],
#   'Running time': '117 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$30 million',
#   'Box office': '$3.8 million',
#   'Director': 'Barry Levinson',
#   'Distributor': 'Paramount Pictures',
#   'Editor(s)': 'Jay Rabinowitz',
#   'Composer(s)': ['Robbie Robertson', 'Howard Drossin'],
#   'Producer(s)': ['Mark Johnson', 'Barry Levinson'],
#   'Writer(s)': 'Barry Levinson'},
#  {'url': 'https://en.wikipedia.org/wiki/Junior_(1994_film)',
#   'year': 1994,
#   'imdb_link': 'https://www.imdb.com/title/tt0110216/',
#   'title': 'Junior',
#   'Starring': ['Arnold Schwarzenegger',
#    'Danny DeVito',
#    'Emma Thompson',
#    'Frank Langella',
#    'Pamela Reed'],
#   'Cinematography': 'Adam Greenberg',
#   'Release date': ['November 23, 1994', '(', '1994-11-23', ')'],
#   'Running time': '109 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$60 million',
#   'Box office': '$108.4 million',
#   'Director': 'Ivan Reitman',
#   'Distributor': 'Universal Pictures',
#   'Editor(s)': ['Wendy Greene Bricmont', 'Sheldon Kahn'],
#   'Composer(s)': 'James Newton Howard',
#   'Producer(s)': 'Ivan Reitman',
#   'Production company(s)': 'Northern Lights Entertainment',
#   'Writer(s)': ['Kevin Wade', 'Chris Conrad']},
#  ...]

# %%
wiki_movies_df.sample(n=5)
# Out:
#                                                     url  year  \
# 3264    https://en.wikipedia.org/wiki/Casa_de_los_Babys  2003
# 4433  https://en.wikipedia.org/wiki/The_Hunting_Part...  2007
# 2715  https://en.wikipedia.org/wiki/The_Replacements...  2000
# 172   https://en.wikipedia.org/wiki/No_Retreat,_No_S...  1990
# 2524  https://en.wikipedia.org/wiki/Simply_Irresisti...  1999
#
#                                   imdb_link  \
# 3264  https://www.imdb.com/title/tt0303830/
# 4433  https://www.imdb.com/title/tt0455782/
# 2715  https://www.imdb.com/title/tt0191397/
# 172   https://www.imdb.com/title/tt0100266/
# 2524  https://www.imdb.com/title/tt0145893/
#
#                                            title Based on  \
# 3264                           Casa de los Babys      NaN
# 4433                           The Hunting Party      NaN
# 2715                            The Replacements      NaN
# 172   No Retreat, No Surrender 3: Blood Brothers      NaN
# 2524                         Simply Irresistible      NaN
#
#                                                Starring Narrated by  \
# 3264  [Marcia Gay Harden, Maggie Gyllenhaal, Daryl H...         NaN
# 4433  [Richard Gere, Terrence Howard, Jesse Eisenber...         NaN
# 2715  [Keanu Reeves, Gene Hackman, Orlando Jones, Jo...         NaN
# 172     [Loren Avedon, Keith Vitali, Joseph Campanella]         NaN
# 2524  [Sarah Michelle Gellar, Sean Patrick Flanery, ...         NaN
#
#            Cinematography                                       Release date  \
# 3264  Mauricio Rubinstein  [September 5, 2003, (, 2003-09-05, ), (, Venic...
# 4433     David Tattersall              [14 September 2007, (, 2007-09-14, )]
# 2715         Tak Fujimoto                                    August 11, 2000
# 172           John Huneck               [January 25, 1990, (, 1990-01-25, )]
# 2524    Robert M. Stevens               [February 5, 1999, (, 1999-02-05, )]
#
#      Running time  ... Created by Preceded by Suggested by alt_titles  \
# 3264   95 minutes  ...        NaN         NaN          NaN        NaN
# 4433  101 minutes  ...        NaN         NaN          NaN        NaN
# 2715  118 minutes  ...        NaN         NaN          NaN        NaN
# 172   101 minutes  ...        NaN         NaN          NaN        NaN
# 2524   96 minutes  ...        NaN         NaN          NaN        NaN
#
#      Recorded Venue Label Animation by Color process McCune–Reischauer
# 3264      NaN   NaN   NaN          NaN           NaN               NaN
# 4433      NaN   NaN   NaN          NaN           NaN               NaN
# 2715      NaN   NaN   NaN          NaN           NaN               NaN
# 172       NaN   NaN   NaN          NaN           NaN               NaN
# 2524      NaN   NaN   NaN          NaN           NaN               NaN
#
# [5 rows x 40 columns]

# %%
wiki_movies_df['Writer(s)'].to_list()
# Out:
# [['David Arnott', 'James Cappe'],
#  ['James Foley', 'Robert Redlin'],
#  ['John Eskow', 'Richard Rush'],
#  'Woody Allen',
#  'Paul Hogan',
#  'Larry Cohen',
#  nan,
#  'David Geeves',
#  'Terrence McNally',
#  'S. Warren',
#  'Fred Braughton',
#  ['Don Jakoby', 'Al Williams'],
#  'Barry Levinson',
#  'Steven Zaillian',
#  ['Robert Zemeckis', 'Bob Gale'],
#  'David Koepp',
#  'Frank Henenlotter',
#  'Alan Alda',
#  ['Louis Venosta', 'David Seltzer'],
#  'Joe McGinniss',
#  'Catherine Cyran',
#  ['Kathryn Bigelow', 'Eric Red', '[1]'],
#  'Michael Cristofer',
#  ['Rick Fry', 'Woody Keith', 'Brian Yuzna'],
#  'Dennis Shryack',
#  'Ken Friedman',
#  ['Bennett Tramer (Story & teleplay)', 'Rich Melcombe', '(Story)'],
#  ['Stephen Tolkin', 'Lawrence Block'],
#  ['Duane Poole', 'Tom Swale'],
#  ['Rachel Kronstadt Mann', 'Ann Louise Bardach', 'Alex Cox', 'Tod Davies'],
#  'George Englund',
#  ['Clayton Frohman', 'E.F. Wallengren', 'Jason Brett'],
#  'Michael Petryni',
#  'Don Mancini',
#  'James F. Collier',
#  'N.D. Schreiner',
#  'Sandra Weintraub',
#  'Mark L. Lester',
#  'Lindsay Harrison',
#  'Alan Parker',
#  'Mike Binder',
#  'J. S. Cardone',
#  'Mitch Markowitz',
#  'John Waters',
#  'Del Shores',
#  'Michael Blake',
#  ['Carey Hayes', 'Chad Hayes'],
#  'Sam Raimi',
#  'Andrew Laskos',
#  ['Robert Towne', 'Tom Cruise'],
#  'Stephen Norrington',
#  ['Ken Denbow', 'Richard Taylor'],
#  'Robert W. Lenski',
#  'James Bond III',
#  'Lee Reynolds',
#  'Erin Dignam',
#  ['Joseph Hayes', 'Lawrence Konner', 'Mark Rosenthal'],
#  ['Jim Cash', 'Jack Epps Jr.'],
#  ['Steven E. de Souza', 'Doug Richardson'],
#  ['Divine', 'David Lochary', 'Mary Vivian Pearce', 'John Waters'],
#  'Tim Conway',
#  'Nat Mauldin',
#  'Eric Hendershot',
#  'Alan Burnett',
#  ['Tim Burton', 'Caroline Thompson'],
#  'Dyan Cannon',
#  'Charlie Cohen',
#  'Arthur Miller',
#  'William Peter Blatty',
#  'James B. Schwartz',
#  'Tommy Chong',
#  'David A. Prior',
#  ['Step Tyner', 'John K. Swensson', 'Dale Dye'],
#  'Robert Resnikoff',
#  'David Loughery',
#  'Peter Filardi',
#  ['Roy Langsdon', 'John Platt'],
#  ['Stephen Peters', 'Kenneth Ross'],
#  ['Robert "Bob" Martin', 'Frank Henenlotter'],
#  ['Roger Corman', 'F. X. Feeney'],
#  'Andrew Bergman',
#  'Bart Davis',
#  ['Norman Steinberg', 'David Frankel'],
#  'Michael Paul Girard',
#  'Bruce Joel Rubin',
#  ['Brent Maddock', 'S. S. Wilson', 'Chris Reese'],
#  'John Derek',
#  'Daniel M. Peterson',
#  ['Mario Puzo', 'Francis Ford Coppola'],
#  ['Nicholas Pileggi', 'Martin Scorsese'],
#  'Prince',
#  'Peter Weir',
#  'Charles S. Haas',
#  'Donald E. Westlake',
#  'Wayne Coe',
#  ['William Friedkin', 'Dan Greenburg', 'Stephen Volk'],
#  'Andy Sidaris',
#  'Joe Woo Jr.',
#  'Harold Pinter',
#  'Steven McKay',
#  'Richard Stanley',
#  ['Judith Rascoe', 'David Rayfiel'],
#  'James D. Parriott',
#  ['Philip Kaufman', 'Rose Kaufman'],
#  ['Richard Fire', 'John McNaughton'],
#  'John Hughes',
#  ['Brent Maddock', 'S.S. Wilson'],
#  ['Charles Williams', 'Nona Tyson'],
#  'Reginald Hudlin',
#  ['Larry Ferguson', 'Donald E. Stewart'],
#  ['Jonathan Tydor', 'David Koepp'],
#  'John Kostmayer',
#  ['Bruce Lansbury', 'Philip John Taylor'],
#  'David Lynch',
#  ['Brian Yuzna', 'Arthur H. Gorson', 'S.J. Smith'],
#  'Henry Bean',
#  'Mark Salzman',
#  ['Lawrence D. Cohen', 'Tommy Lee Wallace'],
#  'Bruce Joel Rubin',
#  'Dennis Marks',
#  'John Patrick Shanley',
#  'Maggie Greenwald',
#  ['John De Bello', 'Constantine Dillon', 'Rick Rockwell'],
#  'Murray Salem',
#  'Nicholas St. John',
#  ['David A. Frank', 'Phillip Gutteridge'],
#  'Jere Cunningham',
#  'David J. Schow',
#  'Jeremy Pikser',
#  ['S. N. Warren', 'Jean-Claude van Damme', 'Sheldon Lettich'],
#  'John Cork',
#  ['Amy Heckerling', 'Neal Israel'],
#  ['Richard Christian Matheson', 'Richard Matheson', 'Bob Clark'],
#  'Sarah Schiff',
#  'Alan Rudolph',
#  'Menahem Golan',
#  'Tom Ropelewski',
#  'Larry Cohen',
#  ['Michael Grais', 'Mark Victor', '[1]'],
#  ['Charles S. Haas', '(screenplay)', 'Fredric Brown', '(novel)'],
#  ['Daniel Raskov', 'Tino Insana'],
#  ['Gordon Chavis', 'Peter Lehner'],
#  'Monte Merrick',
#  'Emilio Estevez',
#  ['Barbara Benedek', 'Paul Brickman'],
#  ['William Reilly', 'William Shakespeare'],
#  'Charles Band',
#  'June Roberts',
#  'Glenn Takajian',
#  'Whit Stillman',
#  'George Armitage',
#  ['Joel Coen', 'Ethan Coen'],
#  'William Goldman',
#  ['Philippe Setbon', 'Derry Hall', 'Brad Lynch', 'Louise Vincent'],
#  'William Boyd',
#  'Spike Lee',
#  ['David Flaherty', 'Gabriel Markiw'],
#  'Gerald Di Pego',
#  'Roland Emmerich',
#  'Mark Curtiss',
#  ['William Harrison', 'Bob Rafelson'],
#  ['James Orr', 'Jim Cruickshank'],
#  'Ruth Prawer Jhabvala',
#  'Stanley Weiser',
#  'Nora Ephron',
#  'Peter Hyams',
#  ['Chuck Pfarrer', 'Gary Goldman'],
#  'Karin Howard',
#  ['Tom Citrano', 'Andrew Stevens'],
#  'George A. Romero',
#  'Clive Barker',
#  'Jonathan D. Gift',
#  'Keith W. Stranberg',
#  'Patricia Watson',
#  ['Mitchel Katlin', 'Nat Bernstein'],
#  'Daniel Pyne',
#  nan,
#  'Dennis Paoli',
#  ['Alan Burnett', 'Len Uhley', 'Mark Zaslove'],
#  'Carrie Fisher',
#  ['Jim Thomas', 'John Thomas'],
#  ['Frank Pierson', 'Alan J. Pakula'],
#  'J. F. Lawton',
#  ['Scott Alexander', 'Larry Karaszewski'],
#  'Ron Oliver',
#  'Joseph Stefano',
#  'Allan Moyle',
#  ['Sidney Lumet', 'Edwin Torres', '(book)'],
#  'Howard Franklin',
#  'John Hill',
#  'Philip Ridley',
#  'Bob Logan',
#  ['Jim Cox', 'Karey Kirkpatrick', 'Byron Simpson', 'Joe Ranft'],
#  ['Jim Harrison', 'Jeffrey Alan Fiskin'],
#  'Nicholas Kazan',
#  'Frank Miller',
#  'Stuart Gordon',
#  'Deborah Brock',
#  'Sylvester Stallone',
#  ['Kevin Harkey',
#   'Bill Kopp',
#   'Rob Minkoff',
#   'Mark Kausler',
#   'Patrick A. Ventura'],
#  ['Armando Acosta', 'Koen Van Brabant'],
#  ['Scott Spiegel', 'Boaz Yakin'],
#  'Terry Sanders',
#  'Tom Stoppard',
#  ['O.V. Falck-Ytter',
#   '(novel)',
#   'Nils Gaup',
#   'Bob Foss',
#   'Greg Dinner',
#   'Nick Thiel'],
#  'Andrew Klavan',
#  ['John Blumenthal', 'Michael Berry'],
#  ['Evan Jones', 'John Strong'],
#  ['Grant Morris', 'Ron House', 'Alan Shearman'],
#  'Martha Goldhirsh',
#  'Bruce Carson',
#  ['James B. Rogers', 'Bob Sheridan'],
#  ['Don Carmody', 'John Dunning', 'Michael Paseornek'],
#  ['Joe Gannon', 'Crispan Bolt'],
#  'Doug Magee',
#  ['Eric Parkinson', 'Vivian Schilling'],
#  ['Patrick Read Johnson', 'Scott Lawrence Alexander'],
#  ['Roman Coppola', 'Lucas Reiner'],
#  'Tobe Hooper',
#  'Robert J. Avrech',
#  ['Harriet Frank, Jr.', 'Irving Ravetch'],
#  'Dennis McIntyre',
#  'Robert Getchell',
#  ['James Scott', 'Graham Greene'],
#  ['Jill Mazursky', 'J. J. Abrams'],
#  ['Michael McDowell',
#   "(Lot 249 and Lover's Vow)",
#   'George A. Romero',
#   '(Cat from Hell)'],
#  'Bobby Herbeck',
#  ['John Conti', 'Ken Lester', 'Bill Mullan', 'Phil Savath', 'Al Thurgood'],
#  'Peter Bogdanovich',
#  'G. William Jones',
#  'Charlie Peters',
#  'Michael Thomas',
#  'Mohsen Makhmalbaf',
#  ['Robert Downey Sr.', 'Laura Ernst', 'Al Schwartz'],
#  'Charles Burnett',
#  ['Ronald Shusett', "Dan O'Bannon", 'Jon Povill'],
#  ['Fraser Clarke Heston (screenplay)', 'Robert Louis Stevenson', '(novel)'],
#  ['Brent Maddock', 'S. S. Wilson', 'Ron Underwood'],
#  ['Rossella Drudi', 'Claudio Fraggaso', '[a]'],
#  ['Fabrizio Laurenti', 'Albert Lawrence', 'Daniele Stroppa'],
#  'Hal Hartley',
#  ['Mario Vargas Llosa', 'William Boyd'],
#  ['Fernando Trueba', 'Manuel Matji', 'Menno Meyjes'],
#  'Robert Towne',
#  'Julian Mitchell',
#  ['Jeffrey Delman', 'Evan Dunsky', 'Thomas Rendon', 'John A. Russo'],
#  'Karen Leigh Hopkins',
#  ['Jerry McNeely', 'Cynthia Whitcomb'],
#  ['John Boorman', 'Telsche Boorman'],
#  ['Peter Viertel', 'James Bridges', 'Burt Kennedy'],
#  ['Ted Tally', 'Alvin Sargent'],
#  'Patricia Rozema',
#  ['Donald E. Westlake',
#   '(book)',
#   'Donald E. Westlake',
#   '(screenplay)',
#   'David Koepp',
#   '(as Leonard Maas Jr.) (screenplay)'],
#  ['Patricia Louisianna Knop', 'Zalman King'],
#  'David Lynch',
#  ['Jim Hanson', 'Sal Manna'],
#  'Allan Scott',
#  ['Sandra Bernhard', 'John Boskovich'],
#  'John Fusco',
#  'Jack Morris',
#  ['Richard A. Lupoff', 'Stephen Tolkin', 'Jonathan Heap'],
#  ['George Gallo', 'Frank Pesce', 'James Franciscus (story)'],
#  'Sandy Tung',
#  ['Caroline Thompson', 'Larry Wilson'],
#  ['Thom Eberhardt', 'Richard Kramer'],
#  'Charles Swenson',
#  'Ziggy Steinberg',
#  ['Hector Babenco', 'Jean-Claude Carrière', 'Vincent Patrick'],
#  'Gregory Widen',
#  ['Ethan Coen', 'Joel Coen'],
#  ['Roger Allers',
#   'Brenda Chapman',
#   'Chris Sanders',
#   'Burny Mattinson',
#   'Kevin Harkey',
#   'Brian Pimental',
#   'Bruce Woodside',
#   'Joe Ranft',
#   'Tom Ellery',
#   'Kelly Asbury',
#   'Robert Lence'],
#  ['Chris Matheson', 'Ed Solomon'],
#  'Tom Stoppard',
#  'Jim Strain',
#  ['Arthur Collis', 'Bradley Battersby'],
#  ['Patricia Herskovic', 'Joyce Taylor'],
#  'James Cummins',
#  ['Mason Nage', '(story and screenplay)', 'Richard Fire', '(screenplay)'],
#  'John Singleton',
#  ['Raymond Mahoney', 'Wayne John'],
#  ['Rick Fry', 'Woody Keith', 'Brian Yuzna'],
#  'Stephen Hawking',
#  'Ann E. Eskridge',
#  'James Toback',
#  ['Ezra Litwak', 'Marjorie Schwartz'],
#  ['John McDonald', 'James Donadio'],
#  'Wesley Strick',
#  ['Stephen Tolkin', 'Lawrence Block'],
#  'John Hughes',
#  'Guerdon Trueblood',
#  ['Nicolas Falacci', 'William Hopkins', 'Tony Randel', 'Christopher Webster'],
#  'Don Mancini',
#  'Dan Hoskins',
#  'John Sayles',
#  ['Lowell Ganz', 'Babaloo Mandel'],
#  ['Carolyn Shelby', 'Christopher Ames', 'Samantha Shad'],
#  'Radha Bharadwaj',
#  'Allan Scott',
#  ['Dick Clement', 'Ian La Frenais', 'Roddy Doyle'],
#  'Nicholas Meyer',
#  'David Stenn',
#  'John Hughes',
#  'Adam Rifkin',
#  'Julie Dash',
#  'Scott Frank',
#  ['Mary Agnes Donoghue', 'Bruce Joel Rubin'],
#  'Albert Brooks',
#  'James Hicks',
#  ['Lawrence J. Cohen', 'Fred Freeman'],
#  'Andy Sidaris',
#  ['Jeffrey Price', 'Peter S. Seaman', 'Daniel Pyne'],
#  'Robert Caswell',
#  'Bob Comfort',
#  ['Neil Landau', 'Tara Ison'],
#  ['J. Randal Johnson', 'Oliver Stone'],
#  ['Sheldon Lettich', 'Jean-Claude van Damme', 'Steve Meerson', 'Peter Krikes'],
#  'Elizabeth Livingston',
#  'John Hughes',
#  ['Marti Leimbach', 'Richard Friedenberg'],
#  ["David O'Malley", 'Mark W. Rosenbaum', 'Michael Spence'],
#  ['John Cherry', 'Coke Sams'],
#  ['Duncan Gibbins', 'Yale Udoff'],
#  'Robert Stitzel',
#  'Bill Condon',
#  ['Charles Shyer', 'Nancy Meyers', 'Frances Goodrich', 'Albert Hackett'],
#  ['Eric Steven Stahl', 'Gerald Laurence'],
#  'Richard LaGravenese',
#  ['Robert Townsend', 'Keenen Ivory Wayans', '[3]'],
#  ['Robert Dillon', 'David Shaber'],
#  ['Neal Jimenez', 'Lindy Laub'],
#  'Terrence McNally',
#  'Rachel Talalay',
#  ['Fannie Flagg', 'Carol Sobieski'],
#  ['Lawrence Kasdan', 'Meg Kasdan'],
#  'Irwin Winkler',
#  'Joseph Vasquez',
#  'Jule Selbo',
#  ['Lem Dobbs', 'Michael Kozoll'],
#  'Don Michael Paul',
#  'Brian Hohlfeld',
#  ['Peter Chelsom', 'Adrian Dunbar'],
#  ['Fax Bahr', 'George Hickenlooper'],
#  'Lionel Chetwynd',
#  ['Brian Clemens', 'William N. Panzer'],
#  ['Bruce McDonald', 'Don McKellar', 'Allan Magee'],
#  ['Don Carmody', 'Robert Geoffrion', 'Galen Thompson'],
#  'David Mamet',
#  ['Jim V. Hart', 'Nick Castle'],
#  ['Jim Abrahams', 'Pat Proft'],
#  'Christopher Münch',
#  ['Daryl G. Nickens', 'Rusty Cundieff'],
#  ['Bruce Willis', 'Robert Kraft'],
#  'Fred Dekker',
#  'Sean Penn',
#  ['Andrei Konchalovsky', 'Anatoliy Usov'],
#  ['Oliver Stone', 'Zachary Sklar'],
#  'Tom DiCillo',
#  'Spike Lee',
#  'Lem Dobbs',
#  'David S. Ward',
#  'James Dearden',
#  'Steve Martin',
#  ['Shane Black', 'Greg Hicks'],
#  'Mike Figgis',
#  ['Mel Brooks', 'Ron Clark', 'Rudy De Luca', 'Steve Haberman'],
#  ['Tamar Brott', 'Richard Shepard'],
#  'Scott Frank',
#  'Ron Nyswaner',
#  nan,
#  'Jenny Wingfield',
#  'Neil Simon',
#  'James Glickenhaus',
#  ['Michael Lehmann', 'Redbeard Simmons'],
#  ['William Reilly', 'William Shakespeare'],
#  'Sooni Taraporevala',
#  ['Michael Mahern', 'Nicholas Kazan'],
#  ['William Reilly', 'Claude Kerven'],
#  'Laurice Elehwany',
#  'Gus Van Sant',
#  ['Parker Bennett', 'Terry Runte'],
#  ['David Zucker', 'Pat Proft'],
#  'David Cronenberg',
#  ['Rick Natkin', 'David Fuller'],
#  'Thomas Lee Wright',
#  'Jim Jarmusch',
#  ['David W. Rintels', 'Nikhilesh Mehra'],
#  'Peter Aykroyd',
#  'Michael Lindsay-Hogg',
#  'Malia Scotch Marmo',
#  'Heywood Gould',
#  'Chris Columbus',
#  ['Michael Barrie', 'Jim Mulholland'],
#  'Alvin Sargent',
#  'David Lee Henry',
#  'Mary Agnes Donoghue',
#  ['Pete Dexter', '(novel and screenplay)'],
#  'David Eyre Jr.',
#  'Wes Craven',
#  'David Obst',
#  'David C. Wilson',
#  ['Rick King', 'W. Peter Iliff'],
#  'Todd Haynes',
#  ['Pat Conroy', 'Becky Johnston'],
#  ['Scott Alexander', 'Larry Karaszewski'],
#  'David Pabian',
#  ['Charles Band', 'C. Courtney Joyner', 'David Schmoeller'],
#  ['Francis Veber', 'Herschel Weingrod', 'Timothy Harris'],
#  'John Toles-Bey',
#  'Calder Willingham',
#  'Michael Tolkin',
#  'J. J. Abrams',
#  'Leslie Stevens',
#  ['Fred Dekker', 'Menno Meyjes'],
#  'Pen Densham',
#  ['Danny Bilson', 'Paul De Meo', 'William Dear'],
#  ['Rodney Dangerfield', 'Harold Ramis'],
#  ['Dennis Shryack', '[1]', 'Michael Blodgett', '[1]'],
#  ['Kim Wozencraft', '(book)', 'Pete Dexter', '(screenplay)'],
#  ['Roger L. Simon', 'Paul Mazursky'],
#  ['Joyce Selznick', '(story)', 'Frank de Felitta (screenplay)'],
#  'David Beaird',
#  'Jane Wagner',
#  ['Lloyd Kaufman', 'Andrew Osborne', 'Jeffery W. Sass'],
#  'Woody Allen',
#  'Wolfgang Petersen',
#  'Joe Gayton',
#  ['Stephen Glantz', 'Caliope Brattlestreet'],
#  'Ted Tally',
#  'Richard Linklater',
#  ['Ronald Bass', 'Bruce Joel Rubin', '(uncredited)'],
#  'Robert Harling',
#  ['Stephen King',
#   '(',
#   'short story',
#   ')',
#   'Lawrence Konner',
#   'Mark Rosenthal',
#   '(teleplay)'],
#  ['Leonard Nimoy', 'Lawrence Konner', 'Mark Rosenthal'],
#  'Richard Harris',
#  'Walter Doniger',
#  'Matty Rich',
#  ['Pam Gibson', 'Nelson George'],
#  'Frank Cappello',
#  'Sam Simon',
#  'Blake Edwards',
#  ['Sidney J. Furie', 'Rick Natkin', 'David Fuller'],
#  ['David Himmelstein', 'Thomas Michael Donnelly', 'Larry Ferguson'],
#  'Topper Carew',
#  'Todd W. Langen',
#  ['James Cameron', 'William Wisher'],
#  'Callie Khouri',
#  'Rolfe Kanefsky',
#  'P. J. Castellaneta',
#  ['David Koepp', 'Daniel Petrie Jr.'],
#  'Amos Poe',
#  'Kevin Wade',
#  'Andy Breckman',
#  ['Dario Argento',
#   'Franco Ferrini',
#   'George A. Romero',
#   'Peter Koper',
#   '(uncredited)'],
#  ['Alison Rosenfeld', 'James Desmarais'],
#  ['Alvin Sargent', 'Laura Ziskin'],
#  ['Jeanne Rosenberg', 'Nick Thiel', 'David Fallon'],
#  ['Ken Russell', 'Deborah Dalton'],
#  ['Matt Williams', 'Oley Sassone'],
#  ['Michael Mewshaw', '(novel)', 'David Ambrose'],
#  'Roselyne Bosch',
#  nan,
#  ['Kenny Kim', 'Edward Emanuel'],
#  ['Burny Mattinson',
#   'Roger Allers',
#   'Daan Jippes',
#   'Kevin Harkey',
#   'Sue Nicholas',
#   'Francis Glebas',
#   'Darrell Rooney',
#   'Larry Leker',
#   'James Fujii',
#   'Kirk Hanson',
#   'Kevin Lima',
#   'Rebecca Rees',
#   'David S. Smith',
#   'Chris Sanders',
#   'Brian Pimental',
#   'Patrick A. Ventura'],
#  'Vincent Ward',
#  'Floyd Mutrux',
#  'Ron Cutler',
#  'John Fusco',
#  ['Zoë Lund', 'Paul Calderon', 'Abel Ferrara'],
#  'Joe Eszterhas',
#  ['Daniel Waters', 'Sam Hamm'],
#  ['Gabrielle-Suzanne Barbot de Villeneuve',
#   '(original author)',
#   'Jack Olesker'],
#  'Reginald Hudlin',
#  ['John Hughes', 'Amy Holden Jones'],
#  'Mark Herman',
#  'Robert C. Cooper',
#  'Tim Robbins',
#  'Lawrence Kasdan',
#  'Eddie Murphy',
#  ['James Kevin McGuinness',
#   '(story)',
#   'George S. Kaufman',
#   'and',
#   'Morrie Ryskind',
#   '(screenplay "',
#   'A Night at the Opera',
#   '")',
#   'Pat Proft',
#   '(screenplay)'],
#  'James V. Hart',
#  'Joss Whedon',
#  'Bernard Rose',
#  'John Dwyer',
#  'Temístocles López',
#  'Diana Hawkins',
#  ['A. L. Katz', 'Gilbert Adler'],
#  'Mario Puzo',
#  'Nicole Conn',
#  ['Michael Swerdlick', 'Richard Brenne', 'Wayne Allan Rice'],
#  'Matthew Chapman',
#  ['Michael Grais', 'Mark Victor'],
#  'Scott Sommer',
#  'Mike Binder',
#  'Joe McGinniss',
#  'Tony Gilroy',
#  ['Martin Donovan', 'David Koepp'],
#  ['Michael Tolkin', 'Henry Bean'],
#  'Steven McKay',
#  ['Marty Kaplan', 'Jonathan Reynolds'],
#  ['Manny Coto', 'Graeme Whifler'],
#  ['George Zaloom', 'Shawn Schepps'],
#  'Alan Rudolph',
#  'Larry McMurtry',
#  ['Ron Howard', 'Bob Dolman'],
#  'Jim Cox',
#  'Aaron Sorkin',
#  ['Dennis Shryack', 'Michael Butler'],
#  ['Robert H. Berger', 'Wesley Strick'],
#  'Robert Klane',
#  'J. J. Abrams',
#  ['Steven Pressfield',
#   'Ronald Shusett (screen story, based on',
#   'Immortality, Inc.',
#   'by',
#   'Robert Sheckley',
#   ')'],
#  ['Don Klein', 'Tom Kartozian'],
#  'Allison Anders',
#  ['Djordje Milicevic', 'Robert Mark Kamen'],
#  'David Mamet',
#  'Grace Cary Bickley',
#  'Amanda Silver',
#  ['Laura Ziskin', 'Alvin Sargent', 'David Webb Peoples'],
#  'Brian Helgeland',
#  'David Mamet',
#  'John Hughes',
#  'Garry Goodrow',
#  'Andrew Bergman',
#  ['Mark Stein', 'Brian Grazer'],
#  'Woody Allen',
#  ['Tim Kissell', 'Sollace Mitchell', 'Alexandre Rockwell'],
#  'Michael Wolk',
#  ['John Brancato', 'Michael Ferris'],
#  'Bruce Robinson',
#  'Ernest R. Dickerson',
#  'Leslie Harris',
#  'Brad Mirman',
#  ['Bruce A. Evans', 'Raynold Gideon'],
#  'Curtis Burch',
#  ['Michael Mann', 'Christopher Crowe'],
#  ['Brett Leonard', 'Gimel Everett'],
#  ['Kelly Candaele', 'Kim Wilson'],
#  'Janus Cercone',
#  'Ed Solomon',
#  'Jeffrey Boam',
#  'Paul Schrader',
#  'Bart Baker',
#  ['George Miller', 'Nick Enright'],
#  ['Screenplay:', 'Allan Moyle', 'Laurie Frank', 'Story:', 'Allan Moyle'],
#  'Don Roos',
#  'Dale Launer',
#  ['John Turturro', 'Brandon Cole'],
#  ['Martin Donovan', 'Richard Pelusi'],
#  ['Arnold Perl', 'Spike Lee'],
#  'Cynthia Cidre',
#  'Rémy Belvaux',
#  'Carole Eastman',
#  'Bob Logan',
#  ['Tom Schulman', 'Sally Robinson'],
#  ['Julie Brown', 'Charlie Coffey'],
#  ['Robert Collector', 'Dana Olsen', 'William Goldman'],
#  'Julian Barry',
#  'Keith Gordon',
#  'Steven Brill',
#  'Scott Bindley',
#  ['Barry Primus', 'J.F. Lawton'],
#  'Damon Wayans',
#  ['Chris Matheson', 'Ed Solomon'],
#  'Spalding Gray',
#  ['Theo Pelletier (story)',
#   'John Junkerman (story)',
#   'Gary Ross',
#   '(screenplay)',
#   'Kevin Wade',
#   '(screenplay)',
#   'Monte Merrick'],
#  ['Billy Crystal', 'Babaloo Mandel', 'Lowell Ganz'],
#  'Jerry Juhl',
#  'Dale Launer',
#  'Stacy Cochran',
#  'Rebecca Charles',
#  ['Bob Tzudiker', 'Noni White'],
#  'Richard Price',
#  'Barbara Hammer',
#  'Marty Kaplan',
#  ['Robert W. Lenski', '(teleplay)'],
#  'Horton Foote',
#  'Richard Nielsen',
#  ['Rodolfo Sonego',
#   'Giorgio Arlorio',
#   'Stefano Strucchi',
#   'Luciano Vincenzoni',
#   'Charles Shyer',
#   'Nancy Meyers',
#   'Steve Kluger'],
#  ['Billy Bob Thornton', 'Tom Epperson'],
#  'Wayne Allan Rice',
#  'Charlie Peters',
#  ['Stewart Raffill', 'Dan Gordon'],
#  'John Sayles',
#  ['W. Peter Iliff', 'Donald E. Stewart'],
#  'Richard Outten',
#  'Michael Moore',
#  ['Shane Connaughton', 'Kerry Crabbe'],
#  'Michael Tolkin',
#  'Melissa Goddard',
#  nan,
#  'Robert Mark Kamen',
#  'M. Night Shyamalan',
#  'Craig Lucas',
#  ['Daniel Adams', 'William Snowden'],
#  'William Nicholson',
#  'Richard Beattie',
#  'Howard Franklin',
#  'Rex McGee',
#  ['Peter I. Baloff', 'Dave Wollert'],
#  'David Mickey Evans',
#  'Gary O. Bennett',
#  'Brian De Palma',
#  'Alan McElroy',
#  ['John Dahl', 'Rick Dahl'],
#  'Quentin Tarantino',
#  'Brent V. Friedman',
#  ['Steve Zacharias', 'Jeff Buhai'],
#  'Richard Friedenberg',
#  'Abbe Wool',
#  'Frank Miller',
#  ['Don Bluth',
#   'John Pomeroy',
#   'David J. Steinberg',
#   'David N. Weiss',
#   'T.J. Kuenster',
#   'Gary Goldman'],
#  'Stephen Davis',
#  ['John Golden', 'Stephen La Rocque'],
#  ['Scott Shaw', 'Kenneth H. Kim'],
#  'Bo Goldman',
#  'Dick Wolf',
#  ['Charles Band', '(original idea)', 'Jackson Barr (screenplay)'],
#  ['Rou Tomono', "Duane Dell'Amico"],
#  'Bobcat Goldthwait',
#  'David Seltzer',
#  ['O.V. Falck-Ytter',
#   '(novel)',
#   'Nils Gaup',
#   'Bob Foss',
#   'Greg Dinner',
#   'Nick Thiel'],
#  ['Lou Illar', 'Galen Thompson'],
#  ['Martin Kitrosser', 'Brian Yuzna'],
#  'Hal Hartley',
#  'Jack Olesker',
#  'Don Roos',
#  'Cameron Crowe',
#  'Joseph Howard',
#  'Stephen King',
#  ['Phil Alden Robinson', 'Lawrence Lasker', 'Walter Parkes'],
#  ['Woody Keith', 'Rick Fry'],
#  ['Stephen Milburn Anderson', 'Donald Bakeer (novel)'],
#  'Alexander Cassini',
#  ['Jim Jennewain', 'Tom S. Parker', 'Richard Siegel'],
#  ['Blake Snyder', 'William Osborne', 'William Davies'],
#  ['Stephan Blom-Cooper', 'V. Phipps-Wilson', 'Gerald Ayres'],
#  ['Mark Frost', 'Lee Reynolds'],
#  'Craig Bolotin',
#  'Robert J. Avrech',
#  ['Tom Kalin', 'Hilton Als'],
#  'Craig Bolotin',
#  'Bill Phillips',
#  ['Screenplay:', 'Nora Ephron', 'Delia Ephron', 'Book:', 'Meg Wolitzer'],
#  'Jack Olesker',
#  ['Hans Christian Andersen', '(author)', 'Jack Olesker'],
#  'John Fusco',
#  ['Paul Dini', 'Nicholas Hollander', 'Tom Ruegger', 'Sherri Stoner'],
#  ['Jeff Franklin', 'Boyd Hale'],
#  'Dennis Marks',
#  'James Hansen',
#  ['Valerie Curtin', 'Barry Levinson'],
#  ['Bob Gale', 'Robert Zemeckis'],
#  ['Bill Plympton', 'Maureen McElheron', 'P. C. Vey'],
#  ['L.A. Puopolo', 'Chris Ceraso'],
#  ['David Lynch', 'Robert Engels'],
#  'J. F. Lawton',
#  'David Webb Peoples',
#  ['Richard Rothstein', 'Christopher Leitch', 'Dean Devlin'],
#  ['George Putnam', 'John Katchmer'],
#  ['Todd Graff', '(play and screenplay)'],
#  'Todd McCarthy',
#  'Neal Jimenez',
#  'Anthony Hickox',
#  ['Mike Myers', 'Bonnie Turner', 'Terry Turner'],
#  ['Marc Rocco', 'Michael Hitchcock', 'Kurt Voss'],
#  'Christopher Crowe',
#  'Ron Shelton',
#  'Daniel Pyne',
#  ['James Lorinz', 'Frank Rainone', 'Rocco Simonelli'],
#  ['Jeff Benjamin (story)',
#   'Roger Vaughan (story)',
#   'Kimball Livingston\t(story)',
#   'Rudy Wurlitzer',
#   '(screenplay)',
#   'Mac Gudgeon (screenplay)'],
#  'William Goldman',
#  'Anthony Drazan',
#  ['Mansour Pourmand (story)', 'Barbara Bishop (screenplay)'],
#  'Solomon Weingarten',
#  'Paul Rudnick',
#  'Stephen Sommers',
#  ['Jay Cocks', 'Martin Scorsese'],
#  'Nick Broomfield',
#  'Stephen McEveety',
#  'John Patrick Shanley',
#  'E. Max Frye',
#  'Jim Kouf',
#  ['Emir Kusturica', 'David Atkins'],
#  ['Sam Raimi', 'Ivan Raimi'],
#  'Patrick Hasburgh',
#  'Maggie Greenwald',
#  'Nick Mead',
#  'Alan Burnett',
#  ['Barry Berman', 'Lesley McNeil'],
#  ['Max Strom', 'John Allen Nelson'],
#  ['Lawrence Konner', 'Mark Rosenthal'],
#  'Ross Thomas',
#  'Roger Hedden',
#  'Brad Mirman',
#  ['Raymond Cistheri', 'Larry Cohen'],
#  ['James B. Harris', 'Gerald Petievich'],
#  ['Brian Bird', 'John Wierick'],
#  ['Garson Kanin', '(play)', 'Douglas McGrath'],
#  'Philippe Caland',
#  'Chazz Palminteri',
#  ['Chris Rock', 'Nelson George', 'Robert LoCash'],
#  'Paul W. Shapiro',
#  ['Trey Parker', 'Matt Stone', '(uncredited)', '[1]'],
#  'David Koepp',
#  'Ivan Menchell',
#  ['John Long', '(premise)', 'Michael France'],
#  ['Tom Davis', 'Dan Aykroyd', 'Bonnie Turner', 'Terry Turner'],
#  ['Lynn Siefert', 'Tommy Swerdlow', 'Michael Goldberg'],
#  'Arne Olsen',
#  'Alan Shapiro',
#  'Nicholas St. John',
#  'Naomi Foner',
#  'George A. Romero',
#  'Gary Ross',
#  'Richard Linklater',
#  ['Christopher Coppola', 'Nick Vallelonga'],
#  ['Peter M. Lenkov', 'Robert Reneau'],
#  'John Hughes',
#  ['Rob Cohen', 'John Raffo', 'Edward Khmara'],
#  ['John R. Cherry III', 'William M. Akers'],
#  ['Richard Nelson', '(screenplay)', 'Edith Wharton', '(novel)'],
#  'Thomas Ian Griffith',
#  ['Frank Sacks', 'Robert Boris'],
#  'Ebbe Roe Smith',
#  ['Laurens Van der Post',
#   'Robert Caswell',
#   'Jonathan Hensleigh',
#   'Sally Robinson',
#   'David M. Evans',
#   '(uncredited)'],
#  "David O'Malley",
#  ['Rafael Yglesias', ', based on his novel'],
#  ['Luana Anders', 'Catherine Cyran', 'Beverly Gray'],
#  'Tracy Tormé',
#  ['David Rabe', 'Robert Towne', 'David Rayfiel'],
#  'Steve Kloves',
#  ['Mark Rosenthal', 'Lawrence Konner'],
#  'Keith A. Walker',
#  'David Twohy,Ananthu',
#  ['John Milius', 'Larry Gross'],
#  'Ronald F. Maxwell',
#  ['William Davies', 'William Osborne'],
#  'Ian McEwan',
#  'Danny Rubin',
#  'Mark Steven Johnson',
#  'Larry Cohen',
#  ['Robby London', 'Martha Moran'],
#  'Chuck Pfarrer',
#  ['Gregory Hansen', 'Erik Hansen', 'Brent Maddock', 'S. S. Wilson', '[1]'],
#  ['Le Ly Hayslip', 'Jay Wurts'],
#  'Alan Spencer',
#  ['Mick Garris', 'David Kirschner'],
#  'Patrick Sheane Duncan',
#  ['Caroline Thompson',
#   'Linda Woolverton',
#   'Jonathan Roberts',
#   '(',
#   'uncredited',
#   ')'],
#  ['Jim Abrahams', 'Pat Proft'],
#  ['Michael Lessac', 'Robert Jay Litz', '(story)'],
#  nan,
#  ['Isabel Allende', '(', 'novel', ')', 'Bille August (screenplay)'],
#  'Jeff Maguire',
#  ['Terry George', 'Jim Sheridan'],
#  'Amy Holden Jones',
#  'Mike Binder',
#  'Steven Zaillian',
#  ['Jay Huguely', 'Adam Marcus', 'Dean Lorey'],
#  'Frank Deese',
#  'Steven Pressfield',
#  ['Amy Tan', 'Ronald Bass'],
#  ['Lewis Colick', 'Jere Cunningham'],
#  ['Michael Crichton', 'David Koepp'],
#  ['Stephen Levy', 'Tim Metcalfe'],
#  'Steven Soderbergh',
#  ['Zak Penn', 'Adam Leff'],
#  'Mark Jones',
#  'Marc Lawrence',
#  ['Don Holley', 'Tori Tellem'],
#  'Neil Simon',
#  'David Henry Hwang',
#  'Richard Price',
#  ['Marcia Brandwynne', 'Nadine Schiff', 'Holly Goldberg Sloan'],
#  ['Aaron Sorkin', 'Jonas McCord'],
#  'Malcolm MacRury',
#  'John Lafia',
#  ['Woody Allen', 'Marshall Brickman'],
#  ['Jerico Stone', 'Charles S. Haas'],
#  ['Stanley Cohen', 'Richard Tannenbaum'],
#  ['Allen Hughes', 'Albert Hughes', 'Tyger Williams'],
#  'Robert Townsend',
#  ['Ramón Menéndez', 'Tom Musca', 'Carol Sobieski'],
#  ['Eric Roth', 'Michael Cristofer'],
#  ['Michael Gottlieb', 'Edward Rugoff'],
#  ['Amy Schor', 'Vicki Polon'],
#  ['Randi Mayem Singer', 'Leslie Dixon'],
#  'Kenneth Branagh',
#  'Bruce Joel Rubin',
#  ['Daniel Algrant', 'John Warren'],
#  'W. D. Richter',
#  'Caroline Thompson',
#  ['Joe Eszterhas', 'Richard Marquand'],
#  ['Mark Young', 'Kelly Ward'],
#  ['Sheldon Lettich', 'Luis Esteban'],
#  'Alan J. Pakula',
#  'John Lee Hancock',
#  'Ron Nyswaner',
#  'Jane Campion',
#  'John Singleton',
#  ['Robert Getchell', 'Alexandra Seros'],
#  ['Sy Richardson', 'Dario Scardapane'],
#  ['David S. Ward', 'Aaron Latham'],
#  ['Bryan Singer', 'Christopher McQuarrie', 'Michael Feit Dougan'],
#  ['Charles Band',
#   'Douglas Aarniokoski',
#   'Steven E. Carr',
#   'Jo Duffy',
#   'Todd Henschell',
#   'Keith S. Payson',
#   'David Schmoeller'],
#  ['William Davies', 'William Osborne'],
#  ['John Dahl', 'Rick Dahl'],
#  'John Penney',
#  'Alfred Uhry',
#  ['Michael Crichton', '[1]', 'Philip Kaufman', 'Michael Backes'],
#  ['Evan Chandler', 'J. David Shapiro'],
#  'Frank Miller',
#  'Hilary Henkin',
#  'Sam Harper',
#  'Milcha Sanchez-Scott',
#  ['Robert Dillon', 'Michael Thomas'],
#  'Victor Nunez',
#  'Angelo Pizzo',
#  'Lyle Kessler',
#  ['David Mickey Evans', 'Robert Gunter'],
#  'Steven Zaillian',
#  'Steven Zaillian',
#  ['Luis Santeiro',
#   'Sara Compton',
#   'Judy Freudberg',
#   'Jeff Moss',
#   'Norman Stiles'],
#  ['Robert Altman', 'Frank Barhydt'],
#  ['James Orr', 'Jim Cruickshank', 'Judi Ann Mason'],
#  'John Guare',
#  'James Glickenhaus',
#  'Jeff Arch',
#  'Joe Eszterhas',
#  ['Michael Frost Beckner', 'Crash Leyland'],
#  'Robbie Fox',
#  ['Nicholas Meyer', 'Anthony Shaffer'],
#  ['Patrick J. Clifton', 'Susan McMartin', 'Peter M. Lenkov'],
#  'Blake Edwards',
#  ['Rowdy Herrington', 'Marty Kaplan'],
#  ['Parker Bennett', 'Terry Runté', 'Ed Solomon'],
#  ['Scott McGehee', 'David Siegel'],
#  'Jonathan Marc Feldman',
#  'Stuart Gillard',
#  ['Kevin Falls', 'Tom Engleman'],
#  'Steven M. Martin',
#  'Carol Heikkinen',
#  'Robert Getchell',
#  'David Loughery',
#  'Adam Greenman',
#  'Dennis Marks',
#  'Kevin Jarre',
#  'Gregg Araki',
#  'Quentin Tarantino',
#  ['Leslie Bohem', 'Endre Bohem'],
#  'Ian Abrams',
#  'Tom Sierchio',
#  'Todd Graff',
#  nan,
#  'Kevin Rock',
#  'Tom Flynn',
#  ['Mike Myers', 'Bonnie Turner', 'Terry Turner'],
#  'John Patrick Shanley',
#  ['Ang Lee', 'Neil Peng', 'James Schamus'],
#  'Robert Klane',
#  'Peter Hedges',
#  'Kate Lanier',
#  'Catherine Cyran',
#  ['Doctor Dré', 'Ed Lover', 'Seth Greenland'],
#  'Vince Gilligan',
#  ['Robert Ginty', 'Anthony Palmer'],
#  'Steve Conrad',
#  ['Roy Carlson', 'Michael Thoma'],
#  ['Percy Adlon', 'Felix O. Adlon'],
#  nan,
#  ['Sang-ok Shin', 'Mark Saltzman'],
#  'Monte Merrick',
#  ['Jeff Pollack', 'Benny Medina'],
#  'Robert McKee',
#  'Jack Bernstein',
#  ['George Casey', 'Mose Richards'],
#  'Max Apple',
#  'Rich Wilkes',
#  ['Duane Capzzi',
#   'Douglas Langdale',
#   'Mark McCorkle',
#   'Robert Schooley',
#   'Tad Stones'],
#  ["Rockne S. O'Bannon", 'Diane Frolov', 'Andrew Schneider'],
#  'Hal Hartley',
#  'Dana Baratta',
#  'Holly Goldberg Sloan',
#  ['Todd Graff', 'Novel', ':', 'Avra Wing'],
#  'Eric Freiser',
#  'John Hughes',
#  ['Albert S. Ruddy', 'Charles Finch', 'Gray Frederickson'],
#  ['Lauran Hoffman', '(based on her play)'],
#  'Whit Stillman',
#  'Franco Columbu',
#  'Steven E. de Souza',
#  ['Ken Wheat', 'Jim Wheat', 'Robert Eisele'],
#  'Caroline Thompson',
#  ['Blake Snyder', 'Colby Carr'],
#  ['Damon Wayans', 'J. F. Lawton'],
#  'Daniel Knauf',
#  'Dana Stevens',
#  nan,
#  ['Jackson Barr', 'David Pabian', 'Ted Nicolaou'],
#  ['John Rice', 'Joe Batteer', 'Jay Roach'],
#  'Ron Shelton',
#  ['Rama Laurie Stagner', 'Arlene Sarner', 'Jerry Leichtling'],
#  ['Brian Owens', 'Andrew Kevin Walker'],
#  'Scott Abbott',
#  'Jessica Yu',
#  ['Woody Allen', 'Douglas McGrath'],
#  ['Chris Elliott', 'Adam Resnick'],
#  ['Andrew Kurtzman', 'Eliot Wald'],
#  ['Erik Tarloff', 'Ebbe Roe Smith', 'Peter McCarthy', 'Peter Crabbe'],
#  'Adam Rifkin',
#  ['Joe Batteer', 'John Rice', 'Dan Gilroy'],
#  'Roy Carlson',
#  ['Charles Perrault', '(original story)', 'George Bloom'],
#  ['Billy Crystal', 'Lowell Ganz', 'Babaloo Mandel'],
#  ['Lloyd Kaufman', 'Carl Morano', 'Matt Unger'],
#  'Lodge Kerrigan',
#  'Robert King',
#  ['John Milius', 'Donald E. Stewart', 'Steven Zaillian'],
#  'Kevin Smith',
#  ['Akiva Goldsman', 'Robert Getchell'],
#  ['Jay Dee Rock', 'Bobby Von Hayes'],
#  'Ron Shelton',
#  'Billy Ray',
#  ['Debra Hill', 'Gigi Vorgan'],
#  'Erik Anjou',
#  'Ralph Bakshi',
#  'Lindsay Maher',
#  'Jessie Nelson',
#  'Rob Thompson',
#  'Matthew Barney',
#  'Joie Susannah Lee',
#  ['David J. Schow', 'John Shirley'],
#  nan,
#  ['Barry Victor', 'Troy Bolotnick', 'Straw Weisman'],
#  'Steven Brill',
#  'Christian Drew Sidaris',
#  ['Ariel Dorfman', 'Rafael Yglesias'],
#  ['Michael Colleary', 'Allan A. Goldstein'],
#  ['Bob Sheridan', 'Christopher Wooden'],
#  'Paul Attanasio',
#  'Woody Allen',
#  ['Walter Bernstein', 'Lionel Chetwynd'],
#  ['Paul Dini', 'Neal Shusterman'],
#  'Nicholas Kazan',
#  ['Peter Barsocchini', 'John Bishop'],
#  ['Peter Farrelly', 'Bobby Farrelly', 'Bennett Yellin'],
#  ['Scott Alexander', 'Larry Karaszewski'],
#  'Gus Van Sant',
#  ['Deborah Amelon', 'Bob Brunner'],
#  ['Mickey Rourke', ', Mari Kornhauser'],
#  ['Craig J. Nevius', 'Kevin Rock'],
#  'Mark Sevi',
#  ['Sara Parriott', 'Josann McGibbon'],
#  'Rusty Cundieff',
#  ['Tom S. Parker', 'Jim Jennewein', 'Steven E. de Souza'],
#  ['Randall Frakes', 'Steve Kallaugher', 'Mitch Marcus'],
#  'Eric Roth',
#  'Robert Boris',
#  'Boaz Yakin',
#  nan,
#  nan,
#  ['Walter Hill', 'Amy Holden Jones'],
#  ['Tom S. Parker', 'Jim Jennewein'],
#  nan,
#  ['Rose Troche', 'Guinevere Turner'],
#  'David Henry Hwang',
#  ['Lowell Ganz', 'Babaloo Mandel'],
#  ['Hugh Wilson', 'Peter Torokvei'],
#  'Persia Woolley',
#  'Stephen Sommers',
#  'Robert Mittenthal',
#  nan,
#  ['Jim Kouf', '(characters)', 'Seth Pinsker'],
#  ['Brad Mirman', 'William N. Panzer'],
#  ['David Weisberg', 'Douglas Cook'],
#  ['Steve James', 'Frederick Marx'],
#  ['David Toney', 'Takashi Bufford'],
#  'Jurgen Wolff',
#  ['Joel Coen', 'Ethan Coen', 'Sam Raimi'],
#  nan,
#  'Darnell Martin',
#  ['Charles Shyer', 'Nancy Meyers'],
#  'James L. Brooks',
#  'Andy Breckman',
#  ['Kristine Johnson', 'Davia Nelson'],
#  'Bernard Rose',
#  'Keith R. Clarke',
#  ['Steve Zacharias', 'Jeff Buhai', 'Robbie Fox'],
#  ['Trey Ellis', 'Paris Qualles'],
#  ['David Rayfiel', 'Marshall Brickman'],
#  'Anne Rice',
#  ['John Michael Hayes', 'Djordje Milicevic', 'Jeff Arch'],
#  'Dalene Young',
#  'Jane Anderson',
#  nan,
#  ['Julia Sweeney', 'Jim Emerson', 'Stephen Hibbert'],
#  nan,
#  'Bobby Smith, Jr',
#  'Barry Levinson',
#  ['Kevin Wade', 'Chris Conrad'],
#  ...]

# %%
# regex to define a search pattern and then .drop_duplicates() to drop duplicates
wiki_movies_df['imdb_id'] = wiki_movies_df['imdb_link'].str.extract(r'(tt\d{7})')
print(len(wiki_movies_df))
wiki_movies_df.drop_duplicates(subset='imdb_id', inplace=True)
print(len(wiki_movies_df))
wiki_movies_df.head()
# Out:
# 7076
# 7033
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring         Narrated by  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  Andrew "Dice" Clay
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...                 NaN
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...                 NaN
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...                 NaN
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]                 NaN
#
#    Cinematography                                       Release date  \
# 0     Oliver Wood                  [July 11, 1990, (, 1990-07-11, )]
# 1    Mark Plummer  [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...
# 2   Roger Deakins                [August 10, 1990, (, 1990-08-10, )]
# 3  Carlo Di Palma              [December 25, 1990, (, 1990-12-25, )]
# 4    Russell Boyd                                  December 19, 1990
#
#   Running time  ... Preceded by Suggested by alt_titles Recorded Venue Label  \
# 0  102 minutes  ...         NaN          NaN        NaN      NaN   NaN   NaN
# 1  114 minutes  ...         NaN          NaN        NaN      NaN   NaN   NaN
# 2  113 minutes  ...         NaN          NaN        NaN      NaN   NaN   NaN
# 3  106 minutes  ...         NaN          NaN        NaN      NaN   NaN   NaN
# 4   95 minutes  ...         NaN          NaN        NaN      NaN   NaN   NaN
#
#   Animation by Color process McCune–Reischauer    imdb_id
# 0          NaN           NaN               NaN  tt0098987
# 1          NaN           NaN               NaN  tt0098994
# 2          NaN           NaN               NaN  tt0099005
# 3          NaN           NaN               NaN  tt0099012
# 4          NaN           NaN               NaN  tt0099018
#
# [5 rows x 41 columns]

# %%
[[column,wiki_movies_df[column].isnull().sum()] for column in wiki_movies_df.columns]
# Out:
# [['url', 0],
#  ['year', 0],
#  ['imdb_link', 0],
#  ['title', 1],
#  ['Based on', 4852],
#  ['Starring', 184],
#  ['Narrated by', 6752],
#  ['Cinematography', 691],
#  ['Release date', 32],
#  ['Running time', 139],
#  ['Country', 236],
#  ['Language', 244],
#  ['Budget', 2295],
#  ['Box office', 1548],
#  ['Director', 0],
#  ['Distributor', 357],
#  ['Editor(s)', 548],
#  ['Composer(s)', 518],
#  ['Producer(s)', 202],
#  ['Production company(s)', 1678],
#  ['Writer(s)', 199],
#  ['Genre', 6923],
#  ['Original language(s)', 6875],
#  ['Original network', 6908],
#  ['Executive producer(s)', 6936],
#  ['Production location(s)', 6986],
#  ['Picture format', 6969],
#  ['Audio format', 6972],
#  ['Voices of', 7031],
#  ['Followed by', 7024],
#  ['Created by', 7023],
#  ['Preceded by', 7023],
#  ['Suggested by', 7032],
#  ['alt_titles', 7012],
#  ['Recorded', 7031],
#  ['Venue', 7032],
#  ['Label', 7031],
#  ['Animation by', 7031],
#  ['Color process', 7032],
#  ['McCune–Reischauer', 7031],
#  ['imdb_id', 0]]

# %%
wiki_columns_to_keep = [column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum() < len(wiki_movies_df) * 0.9]
wiki_movies_df = wiki_movies_df[wiki_columns_to_keep]

# %%
wiki_movies_df.count()
# Out:
# url                      7033
# year                     7033
# imdb_link                7033
# title                    7032
# Based on                 2181
# Starring                 6849
# Cinematography           6342
# Release date             7001
# Running time             6894
# Country                  6797
# Language                 6789
# Budget                   4738
# Box office               5485
# Director                 7033
# Distributor              6676
# Editor(s)                6485
# Composer(s)              6515
# Producer(s)              6831
# Production company(s)    5355
# Writer(s)                6834
# imdb_id                  7033
# dtype: int64

# %%
wiki_movies_df.dtypes
# Out:
# url                      object
# year                      int64
# imdb_link                object
# title                    object
# Based on                 object
# Starring                 object
# Cinematography           object
# Release date             object
# Running time             object
# Country                  object
# Language                 object
# Budget                   object
# Box office               object
# Director                 object
# Distributor              object
# Editor(s)                object
# Composer(s)              object
# Producer(s)              object
# Production company(s)    object
# Writer(s)                object
# imdb_id                  object
# dtype: object

# %%
box_office = wiki_movies_df['Box office'].dropna()

# %%
box_office.count
# Out:
# <bound method Series.count of 0          $21.4 million
# 1           $2.7 million
# 2            $57,718,089
# 3             $7,331,647
# 4       $6,939,946 (USA)
#               ...
# 7070       $19.4 million
# 7071       $41.9 million
# 7072       $76.1 million
# 7073       $38.4 million
# 7074        $5.5 million
# Name: Box office, Length: 5485, dtype: object>

# %%
def is_not_a_string(x):
    return type(x) != str
box_office[box_office.map(is_not_a_string)]
# Out:
# 34                           [US$, 4,212,828]
# 54      [$6,698,361 (, United States, ), [2]]
# 74                    [$6,488,144, (US), [1]]
# 126                [US$1,531,489, (domestic)]
# 130                          [US$, 4,803,039]
#                         ...
# 6980               [$99.6, million, [4], [5]]
# 6994                   [$365.6, million, [1]]
# 6995                         [$53.8, million]
# 7015                     [$435, million, [7]]
# 7048                   [$529.3, million, [4]]
# Name: Box office, Length: 135, dtype: object

# %%
box_office[box_office.map(lambda x: type(x) != str)]
# Out:
# 34                           [US$, 4,212,828]
# 54      [$6,698,361 (, United States, ), [2]]
# 74                    [$6,488,144, (US), [1]]
# 126                [US$1,531,489, (domestic)]
# 130                          [US$, 4,803,039]
#                         ...
# 6980               [$99.6, million, [4], [5]]
# 6994                   [$365.6, million, [1]]
# 6995                         [$53.8, million]
# 7015                     [$435, million, [7]]
# 7048                   [$529.3, million, [4]]
# Name: Box office, Length: 135, dtype: object

# %%
box_office = box_office.apply(lambda x: ' '.join(x) if type(x) == list else x)

# %%
box_office
# Out:
# 0          $21.4 million
# 1           $2.7 million
# 2            $57,718,089
# 3             $7,331,647
# 4       $6,939,946 (USA)
#               ...
# 7070       $19.4 million
# 7071       $41.9 million
# 7072       $76.1 million
# 7073       $38.4 million
# 7074        $5.5 million
# Name: Box office, Length: 5485, dtype: object

# %%
form_one = r'\$\d+\.?\d*\s*[mb]illion'
box_office.str.contains(form_one, flags=re.IGNORECASE).sum()
# Out:
# 3896

# %%
form_two = r'\$\d{1,3}(?:,\d{3})+'
box_office.str.contains(form_two, flags=re.IGNORECASE).sum()
# Out:
# 1544

# %%
matches_form_one = box_office.str.contains(form_one, flags=re.IGNORECASE)
matches_form_two = box_office.str.contains(form_two, flags=re.IGNORECASE)

# %%
box_office[~matches_form_one & ~matches_form_two]
# Out:
# 34                         US$ 4,212,828
# 79                              $335.000
# 110                   $4.35-4.37 million
# 130                        US$ 4,803,039
# 600                           $5000 (US)
# 731                         $ 11,146,270
# 957                             $ 50,004
# 1070                          35,254,617
# 1147    $ 407,618 (U.S.) (sub-total) [1]
# 1446                        $ 11,829,959
# 1480                          £3 million
# 1611                            $520.000
# 1865                        ¥1.1 billion
# 2032                                 N/A
# 2091                                $309
# 2130               US$ 171.8 million [9]
# 2257                   US$ 3,395,581 [1]
# 2263            $ 1,223,034 ( domestic )
# 2347                            $282.175
# 2638            $ 104,883 (US sub-total)
# 2665         926,423 admissions (France)
# 2697      $ 1.7 million (US) (sub-total)
# 2823                            $414.000
# 2924                            $621.000
# 3088           $32 [2] –33.1 million [1]
# 3631                                 TBA
# 3859                  $38.9–40.3 million
# 3879            CN¥3.650 million (China)
# 4116                          £7,385,434
# 4123                            $161.000
# 4261                  $20.7–23.9 million
# 4306                              $20-30
# 4492                        $47.7 millon
# 4561             $45.2k (only in Turkey)
# 4662                USD$ 8.2 million [2]
# 5362                   $ 142 million [3]
# 5447                               £2.56
# 5784                            413 733$
# 6013                             Unknown
# 6145                  $17.5–18.4 million
# 6234                  $41.8–41.9 million
# 6369                               $111k
# 6370                                $588
# 6593                      less than $372
# 6829                    $ 41 million [3]
# 6843                             8 crore
# 6904                         $6.9 millon
# Name: Box office, dtype: object

# %%
#fix values that have spaces between dollar sign and the number and that use a period as a thousands seperator
# fix million is sometimes misspelled
form_one = r'\$\s*\d+\.?\d*\s*[mb]illi?on'
form_two = r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)'

# %%
box_office = box_office.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)

# %%
box_office.str.extract(f'({form_one}|{form_two})')
# Out:
#                   0
# 0     $21.4 million
# 1      $2.7 million
# 2       $57,718,089
# 3        $7,331,647
# 4        $6,939,946
# ...             ...
# 7070  $19.4 million
# 7071  $41.9 million
# 7072  $76.1 million
# 7073  $38.4 million
# 7074   $5.5 million
#
# [5485 rows x 1 columns]

# %%
def parse_dollars(s):
    # if s is not a string, return NaN
    if type(s) != str:
        return np.nan

    # if input is of the form $###.# million
    if re.match(r'\$\s*\d+\.?\d*\s*milli?on', s, flags=re.IGNORECASE):

        # remove dollar sign and " million"
        s = re.sub('\$|\s|[a-zA-Z]','', s)

        # convert to float and multiply by a million
        value = float(s) * 10**6

        # return value
        return value

    # if input is of the form $###.# billion
    elif re.match(r'\$\s*\d+\.?\d*\s*billi?on', s, flags=re.IGNORECASE):

        # remove dollar sign and " billion"
        s = re.sub('\$|\s|[a-zA-Z]','', s)

        # convert to float and multiply by a billion
        value = float(s) * 10**9

        # return value
        return value

    # if input is of the form $###,###,###
    elif re.match(r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)', s, flags=re.IGNORECASE):

        # remove dollar sign and commas
        s = re.sub('\$|,','', s)

        # convert to float
        value = float(s)

        # return value
        return value

    # otherwise, return NaN
    else:
        return np.nan

# %%
wiki_movies_df['box_office'] = box_office.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)

# %%
wiki_movies_df.sample(n=10)
# Out:
#                                                     url  year  \
# 4007  https://en.wikipedia.org/wiki/The_Darwin_Award...  2006
# 1818   https://en.wikipedia.org/wiki/The_Best_Bad_Thing  1997
# 273     https://en.wikipedia.org/wiki/Bingo_(1991_film)  1991
# 6619              https://en.wikipedia.org/wiki/Get_Out  2017
# 2252             https://en.wikipedia.org/wiki/My_Giant  1998
# 2619      https://en.wikipedia.org/wiki/Dinosaur_(film)  2000
# 3287           https://en.wikipedia.org/wiki/Le_Divorce  2003
# 4672        https://en.wikipedia.org/wiki/Harold_(film)  2008
# 1285  https://en.wikipedia.org/wiki/The_Jerky_Boys:_...  1995
# 6635         https://en.wikipedia.org/wiki/Song_to_Song  2017
#
#                                   imdb_link                      title  \
# 4007  https://www.imdb.com/title/tt0428446/          The Darwin Awards
# 1818  https://www.imdb.com/title/tt0156022/         The Best Bad Thing
# 273   https://www.imdb.com/title/tt0101455/                      Bingo
# 6619  https://www.imdb.com/title/tt5052448/                    Get Out
# 2252  https://www.imdb.com/title/tt0120765/                   My Giant
# 2619  https://www.imdb.com/title/tt0130623/                   Dinosaur
# 3287  https://www.imdb.com/title/tt0306734/                 Le Divorce
# 4672  https://www.imdb.com/title/tt1041753/                     Harold
# 1285  https://www.imdb.com/title/tt0110189/  The Jerky Boys: The Movie
# 6635  https://www.imdb.com/title/tt2062700/               Song to Song
#
#                              Based on  \
# 4007                              NaN
# 1818                              NaN
# 273                               NaN
# 6619                              NaN
# 2252                              NaN
# 2619                              NaN
# 3287  [Le Divorce, by, Diane Johnson]
# 4672                              NaN
# 1285                              NaN
# 6635                              NaN
#
#                                                Starring  \
# 4007  [Joseph Fiennes, Winona Ryder, David Arquette,...
# 1818                                                NaN
# 273   [Cindy Williams, David Rasche, Robert J. Stein...
# 6619  [Daniel Kaluuya, Allison Williams, Bradley Whi...
# 2252  [Billy Crystal, Kathleen Quinlan, Joanna Pacuł...
# 2619  [D. B. Sweeney, Alfre Woodard, Ossie Davis, Ma...
# 3287  [Kate Hudson, Naomi Watts, Glenn Close, Leslie...
# 4672  [Spencer Breslin, Cuba Gooding Jr., Nikki Blon...
# 1285          [Johnny Brennan, Kamal Ahmed, Alan Arkin]
# 6635  [Michael Fassbender, Ryan Gosling, Rooney Mara...
#
#                             Cinematography  \
# 4007                           Hiro Narita
# 1818                                   NaN
# 273                         John McPherson
# 6619                           Toby Oliver
# 2252                       Michael Coulter
# 2619  [David Hardberger, S. Douglas Smith]
# 3287                         Pierre Lhomme
# 4672                 Christopher LaVasseur
# 1285                          Ueli Steiger
# 6635                      Emmanuel Lubezki
#
#                                            Release date Running time  \
# 4007  [January 25, 2006, (, 2006-01-25, ), (, Sundan...   94 minutes
# 1818                                 [1997, (, 1997, )]          NaN
# 273                  [August 9, 1991, (, 1991-08-09, )]   89 minutes
# 6619  [January 23, 2017, (, 2017-01-23, ), (, Sundan...  104 minutes
# 2252    [April 10, 1998, (US), February 12, 1999, (UK)]  103 minutes
# 2619  [May 19, 2000, (, 2000-05-19, ), (United States)]   82 minutes
# 3287                 [August 8, 2003, (, 2003-08-08, )]  117 minutes
# 4672                  [July 11, 2008, (, 2008-07-11, )]  105 minutes
# 1285       [February 3, 1995, (, 1995-02-03, ), (U.S.)]   81 minutes
# 6635  [March 10, 2017, (, 2017-03-10, ), (, SXSW, ),...  129 minutes
#
#             Country  ...      Box office                       Director  \
# 4007  United States  ...             NaN                    Finn Taylor
# 1818         Canada  ...             NaN                     Peter Rowe
# 273   United States  ...      $8,667,684                Matthew Robbins
# 6619  United States  ...  $255.4 million                   Jordan Peele
# 2252  United States  ...      $8,072,007                Michael Lehmann
# 2619  United States  ...  $349.8 million  [Ralph Zondag, Eric Leighton]
# 3287  United States  ...     $13 million                    James Ivory
# 4672  United States  ...         $13,229                T. Sean Shannon
# 1285  United States  ...    $7.6 million                James Melkonian
# 6635  United States  ...      $1,027,769                Terrence Malick
#
#                                     Distributor  \
# 4007  [Metro-Goldwyn-Mayer, Icon Entertainment]
# 1818                                      CiNAR
# 273                            TriStar Pictures
# 6619                         Universal Pictures
# 2252                          Columbia Pictures
# 2619                       Buena Vista Pictures
# 3287                   Fox Searchlight Pictures
# 4672                       City Lights Pictures
# 1285                       Buena Vista Pictures
# 6635                       Broad Green Pictures
#
#                                           Editor(s)          Composer(s)  \
# 4007                                  Rick LeCompte          David Kitay
# 1818                                            NaN         Jimmy Tanaka
# 273                                 Maryann Brandon        Richard Gibbs
# 6619                                Gregory Plotkin        Michael Abels
# 2252                                  Stephen Semel         Marc Shaiman
# 2619                                H. Lee Peterson  James Newton Howard
# 3287                               John David Allen      Richard Robbins
# 4672                                  Colleen Sharp                  NaN
# 1285                                 Dennis M. Hill          Ira Newborn
# 6635  [Rehman Nizar Ali, Hank Corwin, Keith Fraase]                  NaN
#
#                                             Producer(s)  \
# 4007  [Jason Blum, Debbie Brubaker, Dieter Busch, Fr...
# 1818                                                NaN
# 273                                         Thomas Baer
# 6619  [Sean McKittrick, Jason Blum, Edward H. Hamm J...
# 2252                                      Billy Crystal
# 2619                                        Pam Marsden
# 3287                [Ismail Merchant, Michael Schiffer]
# 4672                 [Cuba Gooding Jr., Morris S. Levy]
# 1285                         [Roger Birnbaum, Joe Roth]
# 6635              [Nicolas Gonda, Sarah Green, Ken Kao]
#
#                                   Production company(s)  \
# 4007  [Blumhouse Productions, WOW Films, Tavistock P...
# 1818                                                NaN
# 273         [TriStar Pictures, Thomas Baer Productions]
# 6619  [Blumhouse Productions, QC Entertainment, Monk...
# 2252                          Castle Rock Entertainment
# 2619  [Walt Disney Pictures, Walt Disney Feature Ani...
# 3287                         Merchant Ivory Productions
# 4672  [Blue Star Pictures, City Lights Pictures, M.E...
# 1285            [Touchstone Pictures, Caravan Pictures]
# 6635  [Buckeye Pictures, Waypoint Entertainment, Fil...
#
#                                               Writer(s)    imdb_id  \
# 4007                                        Finn Taylor  tt0428446
# 1818                                      David Preston  tt0156022
# 273                                          Jim Strain  tt0101455
# 6619                                       Jordan Peele  tt5052448
# 2252                     [Billy Crystal, David Seltzer]  tt0120765
# 2619  [John Harrison, Robert Nelson Jacobs, Thom Enr...  tt0130623
# 3287                [Ruth Prawer Jhabvala, James Ivory]  tt0306734
# 4672                     [Greg Fields, T. Sean Shannon]  tt1041753
# 1285  [James Melkonian, Rich Wilkes, John G. Brennan...  tt0110189
# 6635                                    Terrence Malick  tt2062700
#
#        box_office
# 4007          NaN
# 1818          NaN
# 273     8667684.0
# 6619  255400000.0
# 2252    8072007.0
# 2619  349800000.0
# 3287   13000000.0
# 4672      13229.0
# 1285    7600000.0
# 6635    1027769.0
#
# [10 rows x 22 columns]

# %%
wiki_movies_df.drop('Box office', axis=1, inplace=True)

# %%
wiki_movies_df.sample(n=10)
# Out:
#                                                     url  year  \
# 850      https://en.wikipedia.org/wiki/Undercover_Blues  1993
# 2102        https://en.wikipedia.org/wiki/Velocity_Trap  1997
# 5128  https://en.wikipedia.org/wiki/The_Kids_Are_All...  2010
# 1413         https://en.wikipedia.org/wiki/Tom_and_Huck  1995
# 4472        https://en.wikipedia.org/wiki/Martian_Child  2007
# 5435  https://en.wikipedia.org/wiki/2-Headed_Shark_A...  2012
# 1090  https://en.wikipedia.org/wiki/The_Shadow_(1994...  1994
# 6503         https://en.wikipedia.org/wiki/Keanu_(film)  2016
# 1389      https://en.wikipedia.org/wiki/Slave_of_Dreams  1995
# 3479  https://en.wikipedia.org/wiki/The_Butterfly_Ef...  2004
#
#                                   imdb_link                   title  \
# 850   https://www.imdb.com/title/tt0108442/        Undercover Blues
# 2102  https://www.imdb.com/title/tt0120435/           Velocity Trap
# 5128  https://www.imdb.com/title/tt0842926/  The Kids Are All Right
# 1413  https://www.imdb.com/title/tt0112302/            Tom and Huck
# 4472  https://www.imdb.com/title/tt0415965/           Martian Child
# 5435  https://www.imdb.com/title/tt2043757/   2-Headed Shark Attack
# 1090  https://www.imdb.com/title/tt0111143/              The Shadow
# 6503  https://www.imdb.com/title/tt4139124/                   Keanu
# 1389  https://www.imdb.com/title/tt0114470/         Slave of Dreams
# 3479  https://www.imdb.com/title/tt0289879/    The Butterfly Effect
#
#                                    Based on  \
# 850                                     NaN
# 2102                                    NaN
# 5128                                    NaN
# 1413                                    NaN
# 4472  [The Martian Child, by David Gerrold]
# 5435                                    NaN
# 1090     [The Shadow, by, Walter B. Gibson]
# 6503                                    NaN
# 1389                                    NaN
# 3479                                    NaN
#
#                                                Starring       Cinematography  \
# 850   [Kathleen Turner, Dennis Quaid, Fiona Shaw, St...     Donald E. Thorin
# 2102       [Olivier Gruner, Alicia Coppola, Ken Olandt]   Philip D. Schwartz
# 5128  [Annette Bening, Julianne Moore, Mark Ruffalo,...     Igor Jadue-Lillo
# 1413              [Jonathan Taylor Thomas, Brad Renfro]       Bobby Bukowski
# 4472  [John Cusack, Bobby Coleman, Amanda Peet, Soph...     Robert D. Yeoman
# 5435  [Carmen Electra, Charlie O'Connell, Brooke Hogan]      Stuart Brereton
# 1090  [Alec Baldwin, John Lone, Penelope Ann Miller,...     Stephen H. Burum
# 6503  [Jordan Peele, Keegan-Michael Key, Tiffany Had...          Jas Shelton
# 1389  [Edward James Olmos, Sherilyn Fenn, Adrian Pas...     Giuseppe Maccari
# 3479  [Ashton Kutcher, Melora Walters, Amy Smart, El...  Matthew F. Leonetti
#
#                                            Release date Running time  \
# 850              [September 10, 1993, (, 1993-09-10, )]   89 minutes
# 2102                                                NaN   89 minutes
# 5128  [January 25, 2010, (, 2010-01-25, ), (Sundance...  107 minutes
# 1413              [December 22, 1995, (, 1995-12-22, )]   92 minutes
# 4472               [November 2, 2007, (, 2007-11-02, )]  106 minutes
# 5435               [January 31, 2012, (, 2012-01-31, )]   88 minutes
# 1090                   [July 1, 1994, (, 1994-07-01, )]  108 minutes
# 6503  [March 13, 2016, (, 2016-03-13, ), (, SXSW, ),...  100 minutes
# 1389              [December 10, 1995, (, 1995-12-10, )]   95 minutes
# 3479               [January 23, 2004, (, 2004-01-23, )]  119 minutes
#
#             Country  ...       Budget                        Director  \
# 850   United States  ...  $25 million                    Herbert Ross
# 2102  United States  ...          NaN                 Phillip J. Roth
# 5128  United States  ...   $4 million                 Lisa Cholodenko
# 1413  United States  ...          NaN                    Peter Hewitt
# 4472  United States  ...  $27 million                    Menno Meyjes
# 5435  United States  ...   $1 million                 Christopher Ray
# 1090  United States  ...  $40 million                 Russell Mulcahy
# 6503  United States  ...  $15 million                   Peter Atencio
# 1389  United States  ...          NaN                 Robert M. Young
# 3479  United States  ...  $13 million  [Eric Bress, J. Mackye Gruber]
#
#                 Distributor                               Editor(s)  \
# 850     Metro Goldwyn Mayer                 Priscilla Nedd-Friendly
# 2102     New City Releasing                      Christian McIntire
# 5128         Focus Features                       Jeffrey M. Werner
# 1413   Buena Vista Pictures                           David Freeman
# 4472        New Line Cinema                             Bruce Green
# 5435             The Asylum                           Rob Pallatina
# 1090     Universal Pictures  [Peter Honess, Beth Jochem Besterveld]
# 6503  Warner Bros. Pictures                        Nicholas Monsour
# 1389                    NaN                          Norman Buckley
# 3479        New Line Cinema                          Peter Amundson
#
#                                      Composer(s)  \
# 850                                 David Newman
# 2102  [Jim Goodwin, Richard McHugh, Mike Slamer]
# 5128                              Carter Burwell
# 1413                            Stephen Endelman
# 4472                                Aaron Zigman
# 5435                             Chris Ridenhour
# 1090                             Jerry Goldsmith
# 6503         [Steve Jablonsky, Nathan Whitehead]
# 1389                            Christopher Tyng
# 3479                                Michael Suby
#
#                                             Producer(s)  \
# 850                                         Mike Lobell
# 2102  [Christian McIntire, Ken Olandt, Phillip J. Ro...
# 5128  [Gary Gilbert, Jeffrey Levy-Hinte, Celine Ratt...
# 1413                   [Laurence Mark, Stephen Sommers]
# 4472  [Ed Elbert, Drew Barrymore, David Kirschner, T...
# 5435                                 David Michael Latt
# 1090   [Martin Bregman, Willi Baer, Michael S. Bregman]
# 6503  [Jordan Peele, Keegan-Michael Key, Peter Princ...
# 1389         [Dino De Laurentiis, Martha De Laurentiis]
# 3479  [Anthony Rhulen, Chris Bender, Ashton Kutcher,...
#
#                                   Production company(s)  \
# 850                                                 NaN
# 2102                                                NaN
# 5128  [Gilbert Films, Saint Aire Productions, Artist...
# 1413                               Walt Disney Pictures
# 4472         [Flower Films, MERADIN Zweite Productions]
# 5435                                                NaN
# 1090                     Bregman/Baer Productions, inc.
# 6503  [New Line Cinema, RatPac-Dune Entertainment, M...
# 1389                                                NaN
# 3479                [FilmEngine, BenderSpink, Katalyst]
#
#                                            Writer(s)    imdb_id  box_office
# 850                                       Ian Abrams  tt0108442  12324660.0
# 2102             [Patrick Phillips, Phillip J. Roth]  tt0120435         NaN
# 5128              [Lisa Cholodenko, Stuart Blumberg]  tt0842926  34700000.0
# 1413  [The Adventures of Tom Sawyer, by, Mark Twain]  tt0112302  23900000.0
# 4472                  Seth E. Bass & Jonathan Tolins  tt0415965   9400000.0
# 5435              [Edward DeRuiter, H. Perry Horton]  tt2043757         NaN
# 1090                                     David Koepp  tt0111143  48000000.0
# 6503                     [Jordan Peele, Alex Rubens]  tt4139124  20600000.0
# 1389                                  Ron Hutchinson  tt0114470         NaN
# 3479                  [Eric Bress, J. Mackye Gruber]  tt0289879  96100000.0
#
# [10 rows x 21 columns]

# %%
budget = wiki_movies_df['Budget'].dropna()

# %%
budget = budget.map(lambda x: ' '.join(x) if type(x) == list else x)

# %%
budget = budget.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)

# %%
matches_form_one = budget.str.contains(form_one, flags=re.IGNORECASE)
matches_form_two = budget.str.contains(form_two, flags=re.IGNORECASE)
budget[~matches_form_one & ~matches_form_two]
# Out:
# 136                         Unknown
# 204     60 million Norwegian Kroner
# 478                         Unknown
# 973             $34 [3] [4] million
# 1126               $120 [4] million
# 1226                        Unknown
# 1278                            HBO
# 1374                     £6,000,000
# 1397                     13 million
# 1480                   £2.8 million
# 1734                   CAD2,000,000
# 1913     PHP 85 million (estimated)
# 1948                    102,888,900
# 1953                   3,500,000 DM
# 1973                     ₤2,300,874
# 2281                     $14 milion
# 2451                     ₤6,350,000
# 3144                   € 40 million
# 3360               $150 [6] million
# 3418                        $218.32
# 3802                   £4.2 million
# 3906                            N/A
# 3959                    760,000 USD
# 4470                       19 crore
# 4641                    £17 million
# 5034              $$200 [4] million
# 5055           $155 [2] [3] million
# 5419                $40 [4] million
# 5424                            N/A
# 5447                     £4 million
# 5671                    €14 million
# 5687                   $ dead link]
# 6385               £ 12 million [3]
# 6593                     £3 million
# 6821                  £12.9 million
# 6843                      3.5 crore
# 6895                        919,000
# 7070                   €4.3 million
# Name: Budget, dtype: object

# %%
budget = budget.str.replace(r'\[\d+\]\s*', '')
budget[~matches_form_one & ~matches_form_two]
# Out:
# 136                         Unknown
# 204     60 million Norwegian Kroner
# 478                         Unknown
# 973                     $34 million
# 1126                   $120 million
# 1226                        Unknown
# 1278                            HBO
# 1374                     £6,000,000
# 1397                     13 million
# 1480                   £2.8 million
# 1734                   CAD2,000,000
# 1913     PHP 85 million (estimated)
# 1948                    102,888,900
# 1953                   3,500,000 DM
# 1973                     ₤2,300,874
# 2281                     $14 milion
# 2451                     ₤6,350,000
# 3144                   € 40 million
# 3360                   $150 million
# 3418                        $218.32
# 3802                   £4.2 million
# 3906                            N/A
# 3959                    760,000 USD
# 4470                       19 crore
# 4641                    £17 million
# 5034                  $$200 million
# 5055                   $155 million
# 5419                    $40 million
# 5424                            N/A
# 5447                     £4 million
# 5671                    €14 million
# 5687                   $ dead link]
# 6385                  £ 12 million
# 6593                     £3 million
# 6821                  £12.9 million
# 6843                      3.5 crore
# 6895                        919,000
# 7070                   €4.3 million
# Name: Budget, dtype: object

# %%
wiki_movies_df['budget'] = budget.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)

# %%
wiki_movies_df.drop('Budget', axis=1, inplace=True)

# %%
release_date = wiki_movies_df['Release date'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)

# %%
date_form_one = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s[123]\d,\s\d{4}'
date_form_two = r'\d{4}.[01]\d.[123]\d'
date_form_three = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s\d{4}'
date_form_four = r'\d{4}'
release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})', flags=re.IGNORECASE)
# Out:
#                       0
# 0         July 11, 1990
# 1          May 17, 1990
# 2       August 10, 1990
# 3     December 25, 1990
# 4     December 19, 1990
# ...                 ...
# 7071  December 25, 2018
# 7072  December 11, 2018
# 7073               2018
# 7074    August 31, 2018
# 7075      December 2018
#
# [7001 rows x 1 columns]

# %%
wiki_movies_df['release_date'] = pd.to_datetime(release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})')[0], infer_datetime_format=True)

# %%
running_time = wiki_movies_df['Running time'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)
running_time.str.contains(r'^\d*\s*minutes$', flags=re.IGNORECASE).sum()
# Out:
# 6528

# %%
running_time[running_time.str.contains(r'^\d*\s*minutes$', flags=re.IGNORECASE) != True]
# Out:
# 9                                                 102 min
# 26                                                 93 min
# 28                                                32 min.
# 34                                                101 min
# 35                                                 97 min
#                               ...
# 6500       114 minutes [1] 120 minutes (extended edition)
# 6643                                             104 mins
# 6709    90 minutes (theatrical) [1] 91 minutes (unrate...
# 7057    108 minutes (Original cut) 98 minutes (UK cut)...
# 7075                Variable; 90 minutes for default path
# Name: Running time, Length: 366, dtype: object

# %%
running_time.str.contains(r'^\d*\s*m', flags=re.IGNORECASE).sum()
# Out:
# 6877

# %%
running_time[running_time.str.contains(r'^\d*\s*m', flags=re.IGNORECASE) != True]
# Out:
# 668                     UK:84 min (DVD version) US:86 min
# 727                         78-102 min (depending on cut)
# 840                       Varies (79 [3] –84 [1] minutes)
# 1347                                              25 : 03
# 1443    United States: 77 minutes Argentina: 94 minute...
# 1499                                            1hr 35min
# 1551                                               varies
# 1774                    Netherlands:96 min, Canada:95 min
# 1777                                       approx. 14 min
# 2273                                           1 h 43 min
# 2993                                               1h 48m
# 3925                                              4 hours
# 4425    US domestic version: 86 minutes Original versi...
# 4967    Theatrical cut: 97 minutes Unrated cut: 107 mi...
# 5424                    115 [1] /123 [2] /128 [3] minutes
# 5447                                    1 hour 32 minutes
# 7075                Variable; 90 minutes for default path
# Name: Running time, dtype: object

# %%
running_time[running_time.str.contains(r'\d*\s*m', flags=re.IGNORECASE) != True]
# Out:
# 1347    25 : 03
# 1551     varies
# 3925    4 hours
# Name: Running time, dtype: object

# %%
running_time.str.contains(r'\d*\s*m', flags=re.IGNORECASE).sum()
# Out:
# 6891

# %%
running_time_extract = running_time.str.extract(r'(\d+)\s*ho?u?r?s?\s*(\d*)|(\d+)\s*m')
running_time_extract = running_time_extract.apply(lambda col: pd.to_numeric(col, errors='coerce')).fillna(0)
wiki_movies_df['running_time'] = running_time_extract.apply(lambda row: row[0]*60 + row[1] if row[2] == 0 else row[2], axis=1)

# %%
wiki_movies_df.drop('Running time', axis=1, inplace=True)

# %%
wiki_movies_df.sample(n=5)
# Out:
#                                                     url  year  \
# 5715  https://en.wikipedia.org/wiki/The_Unspeakable_Act  2012
# 5290  https://en.wikipedia.org/wiki/Dylan_Dog:_Dead_...  2011
# 1931  https://en.wikipedia.org/wiki/I_Married_a_Stra...  1997
# 3215    https://en.wikipedia.org/wiki/Waking_Up_in_Reno  2002
# 4814  https://en.wikipedia.org/wiki/Alvin_and_the_Ch...  2009
#
#                                   imdb_link  \
# 5715  https://www.imdb.com/title/tt2023765/
# 5290  https://www.imdb.com/title/tt1013860/
# 1931  https://www.imdb.com/title/tt0119346/
# 3215  https://www.imdb.com/title/tt0219400/
# 4814  https://www.imdb.com/title/tt1231580/
#
#                                        title  \
# 5715                     The Unspeakable Act
# 5290                Dylan Dog: Dead of Night
# 1931             I Married a Strange Person!
# 3215                       Waking Up in Reno
# 4814  Alvin and the Chipmunks:The Squeakquel
#
#                                                Based on  \
# 5715                                                NaN
# 5290                    [Dylan Dog, by, Tiziano Sclavi]
# 1931                                                NaN
# 3215                                                NaN
# 4814  [Alvin and the Chipmunks, by, Ross Bagdasarian...
#
#                                                Starring       Cinematography  \
# 5715  [Tallie Medel, Sky Hirschkron, Aundrea Fares, ...       Duraid Munajim
# 5290  [Brandon Routh, Sam Huntington, Anita Briem, P...        Geoffrey Hall
# 1931      [Charis Michelsen, Tom Larson, Richard Spore]        John Donnelly
# 3215  [Natasha Richardson, Billy Bob Thornton, Patri...    William A. Fraker
# 4814  [Justin Long, Matthew Gray Gubler, Jesse McCar...  Anthony B. Richmond
#
#                                            Release date        Country  \
# 5715  [April 19, 2012, (, 2012-04-19, ), (, Sarasota...  United States
# 5290  [March 16, 2011, (, 2011-03-16, ), (Italy), Ap...  United States
# 1931  [September 8, 1997, (, 1997-09-08, ), (, TIFF,...  United States
# 3215               [October 25, 2002, (, 2002-10-25, )]  United States
# 4814              [December 23, 2009, (, 2009-12-23, )]  United States
#
#                 Language  ...          Editor(s)  \
# 5715             English  ...        Dan Sallitt
# 5290  [English, Italian]  ...        Paul Hirsch
# 1931    English language  ...     Anthony Arcidi
# 3215             English  ...  Lisa Zeno Churgin
# 4814             English  ...   Matthew Friedman
#
#                             Composer(s)  \
# 5715                                NaN
# 5290                       Klaus Badelt
# 1931                  Maureen McElheron
# 3215  [Christopher Young, Marty Stuart]
# 4814                       David Newman
#
#                                             Producer(s)  \
# 5715  [Shari Berman, Jaime Christley, Mark J. Parker...
# 5290          [Gilbert Adler, Scott Mitchell Rosenberg]
# 1931                                      Bill Plympton
# 3215         [Ben Myron, Robert Salerno, Dwight Yoakam]
# 4814                  [Janice Karman, Ross Bagdasarian]
#
#                                   Production company(s)  \
# 5715                                      Static Prods.
# 5290  [Hyde Park Entertainment, Long Distance Films,...
# 1931                                          Italtoons
# 3215                                                NaN
# 4814  [Fox 2000 Pictures, Regency Enterprises, Bagda...
#
#                                         Writer(s)    imdb_id   box_office  \
# 5715                                  Dan Sallitt  tt2023765          NaN
# 5290  Thomas Dean Donnelly and Joshua Oppenheimer  tt1013860    4634062.0
# 1931                    [Bill Plympton, P.C. Vey]  tt0119346     467272.0
# 3215                 [Brent Briscoe, Mark Fauser]  tt0219400     267109.0
# 4814    [Jon Vitti, Jonathan Aibel, Glenn Berger]  tt1231580  443100000.0
#
#           budget  release_date  running_time
# 5715         NaN    2012-04-19          91.0
# 5290  20000000.0    2011-03-16         108.0
# 1931    250000.0    1997-01-01          73.0
# 3215         NaN    2002-10-25          91.0
# 4814  70000000.0    2009-12-23          88.0
#
# [5 rows x 22 columns]

# %%
kaggle_metadata.dtypes
# Out:
# adult                     object
# belongs_to_collection     object
# budget                    object
# genres                    object
# homepage                  object
# id                        object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity                object
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                     object
# vote_average             float64
# vote_count               float64
# dtype: object

# %%
kaggle_metadata['adult'].value_counts()
# Out:
# False                                                                                                                             45454
# True                                                                                                                                  9
#  Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.                        1
#  - Written by Ørnås                                                                                                                   1
#  Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.        1
# Name: adult, dtype: int64

# %%
kaggle_metadata[~kaggle_metadata['adult'].isin(['True','False'])]
# Out:
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 29503   Rune Balot goes to a casino connected to the ...
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#       belongs_to_collection                            budget  \
# 19730              0.065736  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503              1.931659  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587              2.185485  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                   genres  \
# 19730  [{'name': 'Carousel Productions', 'id': 11176}...
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...
# 35587  [{'name': 'Odyssey Media', 'id': 17161}, {'nam...
#
#                                                 homepage          id imdb_id  \
# 19730  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  1997-08-20       0
# 29503  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29       0
# 35587           [{'iso_3166_1': 'CA', 'name': 'Canada'}]  2014-01-01       0
#
#       original_language                            original_title  overview  \
# 19730             104.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 29503              68.0      [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 35587              82.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#        ... release_date revenue runtime spoken_languages status  tagline  \
# 19730  ...            1     NaN     NaN              NaN    NaN      NaN
# 29503  ...           12     NaN     NaN              NaN    NaN      NaN
# 35587  ...           22     NaN     NaN              NaN    NaN      NaN
#
#        title video vote_average vote_count
# 19730    NaN   NaN          NaN        NaN
# 29503    NaN   NaN          NaN        NaN
# 35587    NaN   NaN          NaN        NaN
#
# [3 rows x 24 columns]

# %%
kaggle_metadata = kaggle_metadata[kaggle_metadata['adult'] == 'False'].drop('adult',axis='columns')

# %%
kaggle_metadata['video'].value_counts()
# Out:
# False    45358
# True        93
# Name: video, dtype: int64

# %%
kaggle_metadata['video'] == 'True'
kaggle_metadata['video'] = kaggle_metadata['video'] == 'True'

# %%
kaggle_metadata['budget'] = kaggle_metadata['budget'].astype(int)
kaggle_metadata['id'] = pd.to_numeric(kaggle_metadata['id'], errors='raise')
kaggle_metadata['popularity'] = pd.to_numeric(kaggle_metadata['popularity'], errors='raise')

# %%
kaggle_metadata['release_date'] = pd.to_datetime(kaggle_metadata['release_date'])

# %%
kaggle_metadata.dtypes
# Out:
# belongs_to_collection            object
# budget                            int32
# genres                           object
# homepage                         object
# id                                int64
# imdb_id                          object
# original_language                object
# original_title                   object
# overview                         object
# popularity                      float64
# poster_path                      object
# production_companies             object
# production_countries             object
# release_date             datetime64[ns]
# revenue                         float64
# runtime                         float64
# spoken_languages                 object
# status                           object
# tagline                          object
# title                            object
# video                              bool
# vote_average                    float64
# vote_count                      float64
# dtype: object

# %%
ratings.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26024289 entries, 0 to 26024288
# Data columns (total 4 columns):
#  #   Column     Non-Null Count     Dtype
# ---  ------     --------------     -----
#  0   userId     26024289 non-null  int64
#  1   movieId    26024289 non-null  int64
#  2   rating     26024289 non-null  float64
#  3   timestamp  26024289 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 794.2 MB

# %%
pd.to_datetime(ratings['timestamp'], unit='s')
# Out:
# 0          2015-03-09 22:52:09
# 1          2015-03-09 23:07:15
# 2          2015-03-09 22:52:03
# 3          2015-03-09 22:52:26
# 4          2015-03-09 22:52:36
#                    ...
# 26024284   2009-10-31 23:26:04
# 26024285   2009-10-31 23:33:52
# 26024286   2009-10-31 23:29:24
# 26024287   2009-11-01 00:06:30
# 26024288   2009-10-31 23:30:58
# Name: timestamp, Length: 26024289, dtype: datetime64[ns]

# %%
ratings['timestamp'] = pd.to_datetime(ratings['timestamp'], unit='s')

# %%
ratings['rating'].plot(kind='hist')
ratings['rating'].describe()
# Out:
# count    2.602429e+07
# mean     3.528090e+00
# std      1.065443e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
wiki_movies_df.columns
# Out:
# Index(['url', 'year', 'imdb_link', 'title', 'Based on', 'Starring',
#        'Cinematography', 'Release date', 'Country', 'Language', 'Director',
#        'Distributor', 'Editor(s)', 'Composer(s)', 'Producer(s)',
#        'Production company(s)', 'Writer(s)', 'imdb_id', 'box_office', 'budget',
#        'release_date', 'running_time'],
#       dtype='object')

# %%
kaggle_metadata.columns
# Out:
# Index(['belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
movies_df = pd.merge(wiki_movies_df, kaggle_metadata, on='imdb_id', suffixes=['_wiki','_kaggle'])
print(movies_df.columns)
# Out:
# Index(['url', 'year', 'imdb_link', 'title_wiki', 'Based on', 'Starring',
#        'Cinematography', 'Release date', 'Country', 'Language', 'Director',
#        'Distributor', 'Editor(s)', 'Composer(s)', 'Producer(s)',
#        'Production company(s)', 'Writer(s)', 'imdb_id', 'box_office',
#        'budget_wiki', 'release_date_wiki', 'running_time',
#        'belongs_to_collection', 'budget_kaggle', 'genres', 'homepage', 'id',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'poster_path', 'production_companies', 'production_countries',
#        'release_date_kaggle', 'revenue', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title_kaggle', 'video', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
# Competing data:
# Wiki                     Movielens                Resolution
#--------------------------------------------------------------------------
# title_wiki               title_kaggle
# running_time             runtime
# budget_wiki              budget_kaggle
# box_office               revenue
# release_date_wiki        release_date_kaggle
# Language                 original_language
# Production company(s)    production_companies

# %%
movies_df[['title_wiki','title_kaggle']]
# Out:
#                            title_wiki                     title_kaggle
# 0     The Adventures of Ford Fairlane  The Adventures of Ford Fairlane
# 1                After Dark, My Sweet             After Dark, My Sweet
# 2                         Air America                      Air America
# 3                               Alice                            Alice
# 4                     Almost an Angel                  Almost an Angel
# ...                               ...                              ...
# 6047                A Fantastic Woman                A Fantastic Woman
# 6048                       Permission                       Permission
# 6049                         Loveless                         Loveless
# 6050                           Gemini                           Gemini
# 6051  How to Talk to Girls at Parties  How to Talk to Girls at Parties
#
# [6052 rows x 2 columns]

# %%
#rows where titles don't match
movies_df[movies_df['title_wiki'] != movies_df['title_kaggle']][['title_wiki','title_kaggle']]
# Out:
#                                            title_wiki  \
# 27                                          China Cry
# 36               Daddy's Dyin' ...Who's Got the Will?
# 38                          The Dark Side of the Moon
# 42                                      Delta Force 2
# 48      DuckTales the Movie:Treasure of the Lost Lamp
# ...                                               ...
# 5956                                            Chips
# 5971                                            Spark
# 5994  Pirates of the Caribbean:Dead Men Tell No Tales
# 6023       Valerian and the Cityof a Thousand Planets
# 6028            An Inconvenient Sequel:Truth to Power
#
#                                           title_kaggle
# 27                             China Cry: A True Story
# 36                Daddy's Dyin'... Who's Got the Will?
# 38                           The Dark Side of The Moon
# 42             Delta Force 2: The Colombian Connection
# 48    DuckTales: The Movie - Treasure of the Lost Lamp
# ...                                                ...
# 5956                                             CHiPS
# 5971                               Spark: A Space Tail
# 5994  Pirates of the Caribbean: Dead Men Tell No Tales
# 6023       Valerian and the City of a Thousand Planets
# 6028            An Inconvenient Sequel: Truth to Power
#
# [438 rows x 2 columns]

# %%
# confirm no missing titles in Kaggle
movies_df[(movies_df['title_kaggle'] == '') | (movies_df['title_kaggle'].isnull())]
# Out:
# Empty DataFrame
# Columns: [url, year, imdb_link, title_wiki, Based on, Starring, Cinematography, Release date, Country, Language, Director, Distributor, Editor(s), Composer(s), Producer(s), Production company(s), Writer(s), imdb_id, box_office, budget_wiki, release_date_wiki, running_time, belongs_to_collection, budget_kaggle, genres, homepage, id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date_kaggle, revenue, runtime, spoken_languages, status, tagline, title_kaggle, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 44 columns]

# %%
# Competing data:
# Wiki                     Movielens                Resolution
#--------------------------------------------------------------------------
# title_wiki               title_kaggle             Drop title_wiki
# running_time             runtime
# budget_wiki              budget_kaggle
# box_office               revenue
# release_date_wiki        release_date_kaggle
# Language                 original_language
# Production company(s)    production_companies

# %%
movies_df.fillna(0).plot(x='running_time', y='runtime', kind='scatter')

# %%
# Competing data:
# Wiki                     Movielens                Resolution
#--------------------------------------------------------------------------
# title_wiki               title_kaggle             Drop title_wiki
# running_time             runtime                  Keep runtime, fill in 0s with runtime
# budget_wiki              budget_kaggle
# box_office               revenue
# release_date_wiki        release_date_kaggle
# Language                 original_language
# Production company(s)    production_companies

# %%
movies_df.fillna(0).plot(x='budget_wiki',y='budget_kaggle', kind='scatter')

# %%
# Competing data:
# Wiki                     Movielens                Resolution
#--------------------------------------------------------------------------
# title_wiki               title_kaggle             Drop title_wiki
# running_time             runtime                  Keep runtime, fill in 0s with runtime
# budget_wiki              budget_kaggle            Keep budget_kaggle, fill in 0s with budget_wiki
# box_office               revenue
# release_date_wiki        release_date_kaggle
# Language                 original_language
# Production company(s)    production_companies

# %%
movies_df.fillna(0).plot(x='box_office', y='revenue', kind='scatter')

# %%
movies_df.fillna(0)[movies_df['box_office'] < 10**9].plot(x='box_office', y='revenue', kind='scatter')

# %%
# Competing data:
# Wiki                     Movielens                Resolution
#--------------------------------------------------------------------------
# title_wiki               title_kaggle             Drop title_wiki
# running_time             runtime                  Keep runtime, fill in 0s with runtime
# budget_wiki              budget_kaggle            Keep budget_kaggle, fill in 0s with budget_wiki
# box_office               revenue                  Keep revenue, fill in 0s with box_office
# release_date_wiki        release_date_kaggle
# Language                 original_language
# Production company(s)    production_companies

# %%
movies_df[['release_date_wiki','release_date_kaggle']].plot(x='release_date_wiki', y='release_date_kaggle', style='.')

# %%
movies_df[(movies_df['release_date_wiki'] > '1996-01-01') & (movies_df['release_date_kaggle'] < '1965-01-01')]
# Out:
#                                             url  year  \
# 3607  https://en.wikipedia.org/wiki/The_Holiday  2006
#
#                                    imdb_link   title_wiki Based on  \
# 3607  https://www.imdb.com/title/tt00457939/  The Holiday      NaN
#
#                                                Starring Cinematography  \
# 3607  [Kate Winslet, Cameron Diaz, Jude Law, Jack Bl...    Dean Cundey
#
#                               Release date        Country Language  ...  \
# 3607  [December 8, 2006, (, 2006-12-08, )]  United States  English  ...
#
#      release_date_kaggle     revenue runtime  \
# 3607          1953-08-28  30500000.0   118.0
#
#                               spoken_languages    status  \
# 3607  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 3607  Pouring out of impassioned pages...brawling th...
#
#                title_kaggle  video  vote_average  vote_count
# 3607  From Here to Eternity  False           7.2       137.0
#
# [1 rows x 44 columns]

# %%
movies_df = movies_df.drop(movies_df[(movies_df['release_date_wiki'] > '1996-01-01') & (movies_df['release_date_kaggle'] < '1965-01-01')].index)

# %%
movies_df[movies_df['release_date_wiki'].isnull()]
# Out:
#                                                     url  year  \
# 1008  https://en.wikipedia.org/wiki/Black_Scorpion_(...  1995
# 1061    https://en.wikipedia.org/wiki/Flirt_(1995_film)  1995
# 1121  https://en.wikipedia.org/wiki/Let_It_Be_Me_(19...  1995
# 1564  https://en.wikipedia.org/wiki/A_Brooklyn_State...  1997
# 1633      https://en.wikipedia.org/wiki/Highball_(film)  1997
# 1775        https://en.wikipedia.org/wiki/Velocity_Trap  1997
# 2386  https://en.wikipedia.org/wiki/The_Visit_(2000_...  2000
# 2786   https://en.wikipedia.org/wiki/Stevie_(2002_film)  2002
# 3174  https://en.wikipedia.org/wiki/Return_to_Sender...  2004
# 3651  https://en.wikipedia.org/wiki/Live_Free_or_Die...  2006
# 4967  https://en.wikipedia.org/wiki/For_the_Love_of_...  2012
#
#                                   imdb_link                title_wiki  \
# 1008  https://www.imdb.com/title/tt0112519/            Black Scorpion
# 1061  https://www.imdb.com/title/tt0113080/                     Flirt
# 1121  https://www.imdb.com/title/tt0113638/              Let It Be Me
# 1564  https://www.imdb.com/title/tt0118782/  A Brooklyn State of Mind
# 1633  https://www.imdb.com/title/tt0119291/                  Highball
# 1775  https://www.imdb.com/title/tt0120435/             Velocity Trap
# 2386  https://www.imdb.com/title/tt0199129/                 The Visit
# 2786  https://www.imdb.com/title/tt0334416/                    Stevie
# 3174  https://www.imdb.com/title/tt0396190/          Return to Sender
# 3651  https://www.imdb.com/title/tt0432318/          Live Free or Die
# 4967  https://www.imdb.com/title/tt1730294/     For the Love of Money
#
#      Based on                                           Starring  \
# 1008      NaN     [Joan Severance, Bruce Abbott, Garrett Morris]
# 1061      NaN            [Bill Sage, Dwight Ewell, Miho Nikaido]
# 1121      NaN                                                NaN
# 1564      NaN                                                NaN
# 1633      NaN  [Justine Bateman, Peter Bogdanovich, Chris Eig...
# 1775      NaN       [Olivier Gruner, Alicia Coppola, Ken Olandt]
# 2386      NaN  [Hill Harper, Billy Dee Williams, Obba Babatun...
# 2786      NaN                                                NaN
# 3174      NaN         [Aidan Quinn, Connie Nielsen, Mark Holton]
# 3651      NaN  [Aaron Stanford, Paul Schneider, Ebon Moss-Bac...
# 4967      NaN  [Yehuda Levi, Edward Furlong, James Caan, Jeff...
#
#                                   Cinematography Release date  \
# 1008                                Geoff George          NaN
# 1061                             Michael Spiller          NaN
# 1121                           Miroslav Ondrícek          NaN
# 1564                                  Ken Kelsch          NaN
# 1633                            Steven Bernstein          NaN
# 1775                          Philip D. Schwartz          NaN
# 2386                           John L. Demps Jr.          NaN
# 2786  [Dana Kupper, Gordon Quinn, Peter Gilbert]          NaN
# 3174                                         NaN          NaN
# 3651                                         NaN          NaN
# 4967                              Andrzej Sekuła          NaN
#
#                                    Country        Language  ...  \
# 1008                         United States             NaN  ...
# 1061  [United States, Germany, Japan, [1]]             NaN  ...
# 1121                                   NaN             NaN  ...
# 1564                                   NaN             NaN  ...
# 1633                         United States         English  ...
# 1775                         United States             NaN  ...
# 2386                                   NaN         English  ...
# 2786                         United States         English  ...
# 3174                    [Denmark, USA, UK]             NaN  ...
# 3651                         United States         English  ...
# 4967                         United States  English/Hebrew  ...
#
#      release_date_kaggle  revenue runtime  \
# 1008          1995-08-22      0.0    92.0
# 1061          1995-09-14      0.0    85.0
# 1121          1995-11-17      0.0    95.0
# 1564          1998-01-01      0.0    89.0
# 1633          1997-01-01      0.0   110.0
# 1775          1999-02-22      0.0    86.0
# 2386          2000-01-01      0.0   107.0
# 2786          2002-09-09  97000.0   140.0
# 3174          2004-09-17      0.0   109.0
# 3651          2006-03-11      0.0    89.0
# 4967          2012-06-08      0.0    93.0
#
#                                        spoken_languages    status  \
# 1008           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1061  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 1121                                                 []  Released
# 1564           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1633           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1775           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2386  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...   Rumored
# 2786                                                 []       NaN
# 3174           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3651           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4967  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                                 tagline  \
# 1008                         Justice has a nasty sting.
# 1061                                                NaN
# 1121                                                NaN
# 1564                                                NaN
# 1633                                                NaN
# 1775                        Crime at the Speed of Light
# 2386                                                NaN
# 2786                                                NaN
# 3174  How can you save someone, who won't save herself?
# 3651                                                NaN
# 4967     For the love of money is the root of all evil.
#
#                   title_kaggle  video  vote_average  vote_count
# 1008            Black Scorpion  False           6.1         7.0
# 1061                     Flirt  False           7.5         4.0
# 1121              Let It Be Me  False           8.0         2.0
# 1564  A Brooklyn State of Mind  False           5.0         1.0
# 1633                  Highball  False           4.5         4.0
# 1775             Velocity Trap  False           4.7         6.0
# 2386                 The Visit  False           0.0         0.0
# 2786                    Stevie  False           6.7        13.0
# 3174          Return to Sender  False           5.9        13.0
# 3651          Live Free or Die  False           5.5         8.0
# 4967     For the Love of Money  False           5.6         9.0
#
# [11 rows x 44 columns]

# %%
# Competing data:
# Wiki                     Movielens                Resolution
#--------------------------------------------------------------------------
# title_wiki               title_kaggle             Drop title_wiki
# running_time             runtime                  Keep runtime, fill in 0s with runtime
# budget_wiki              budget_kaggle            Keep budget_kaggle, fill in 0s with budget_wiki
# box_office               revenue                  Keep revenue, fill in 0s with box_office
# release_date_wiki        release_date_kaggle      Drop release_date_wiki
# Language                 original_language
# Production company(s)    production_companies

# %%
movies_df['Language'].apply(lambda x: tuple(x) if type(x) == list else x).value_counts(dropna=False)
# Out:
# English                                       5479
# NaN                                            134
# (English, Spanish)                              68
# (English, French)                               35
# (English, Japanese)                             25
#                                               ...
# (English, French, Arabic)                        1
# (English, French, Kinyarwanda)                   1
# (English, Scottish Gaelic)                       1
# (English, German, Italian)                       1
# (English, Mandarin Chinese, Thai, Russian)       1
# Name: Language, Length: 198, dtype: int64

# %%
movies_df['original_language'].value_counts(dropna=False)
# Out:
# en    5987
# fr      16
# es      10
# it       8
# de       6
# zh       4
# pt       4
# ja       4
# hi       2
# da       2
# ab       1
# ar       1
# cn       1
# he       1
# sv       1
# ru       1
# tr       1
# ko       1
# Name: original_language, dtype: int64

# %%
# Competing data:
# Wiki                     Movielens                Resolution
#--------------------------------------------------------------------------
# title_wiki               title_kaggle             Drop title_wiki
# running_time             runtime                  Keep runtime, fill in 0s with runtime
# budget_wiki              budget_kaggle            Keep budget_kaggle, fill in 0s with budget_wiki
# box_office               revenue                  Keep revenue, fill in 0s with box_office
# release_date_wiki        release_date_kaggle      Drop release_date_wiki
# Language                 original_language        Drop Language
# Production company(s)    production_companies

# %%
movies_df[['Production company(s)','production_companies']]
# Out:
#                                   Production company(s)  \
# 0                                       Silver Pictures
# 1                                       Avenue Pictures
# 2                 [Carolco Pictures, IndieProd Company]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6047                           [Fabula, Komplizen Film]
# 6048                           Ball & Chain Productions
# 6049          [Arte France Cinéma, Why Not Productions]
# 6050  [Film Science, Rough House Pictures, Syncopate...
# 6051         [HanWay Films, Little Punk, See-Saw Films]
#
#                                    production_companies
# 0     [{'name': 'Twentieth Century Fox Film Corporat...
# 1     [{'name': 'Avenue Pictures Productions', 'id':...
# 2     [{'name': 'IndieProd Company Productions', 'id...
# 3                [{'name': 'Orion Pictures', 'id': 41}]
# 4             [{'name': 'Paramount Pictures', 'id': 4}]
# ...                                                 ...
# 6047  [{'name': 'Komplizen Film', 'id': 1618}, {'nam...
# 6048  [{'name': 'Ball & Chain Productions', 'id': 74...
# 6049  [{'name': 'ARTE France Cinéma', 'id': 94}, {'n...
# 6050  [{'name': 'Film Science', 'id': 1976}, {'name'...
# 6051  [{'name': 'HanWay Films', 'id': 2395}, {'name'...
#
# [6051 rows x 2 columns]

# %%
# Competing data:
# Wiki                     Movielens                Resolution
#--------------------------------------------------------------------------
# title_wiki               title_kaggle             Drop title_wiki
# running_time             runtime                  Keep runtime, fill in 0s with runtime
# budget_wiki              budget_kaggle            Keep budget_kaggle, fill in 0s with budget_wiki
# box_office               revenue                  Keep revenue, fill in 0s with box_office
# release_date_wiki        release_date_kaggle      Drop release_date_wiki
# Language                 original_language        Drop Language
# Production company(s)    production_companies     Drop Production Company(s)

# %%
# drop the title_wiki, release_date_wiki, Language, and Production company(s) columns.
movies_df.drop(columns=['title_wiki','release_date_wiki','Language','Production company(s)'], inplace=True)

# %%
#make a function that fills in missing data for a column pair and then drops the redundant column.
def fill_missing_kaggle_data(df, kaggle_column, wiki_column):
    df[kaggle_column] = df.apply(
        lambda row: row[wiki_column] if row[kaggle_column] == 0 else row[kaggle_column]
        , axis=1)
    df.drop(columns=wiki_column, inplace=True)

# %%
fill_missing_kaggle_data(movies_df, 'runtime', 'running_time')
fill_missing_kaggle_data(movies_df, 'budget_kaggle', 'budget_wiki')
fill_missing_kaggle_data(movies_df, 'revenue', 'box_office')
movies_df
# Out:
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...                                                 ...   ...
# 6047    https://en.wikipedia.org/wiki/A_Fantastic_Woman  2018
# 6048    https://en.wikipedia.org/wiki/Permission_(film)  2018
# 6049      https://en.wikipedia.org/wiki/Loveless_(film)  2018
# 6050   https://en.wikipedia.org/wiki/Gemini_(2017_film)  2018
# 6051  https://en.wikipedia.org/wiki/How_to_Talk_to_G...  2018
#
#                                   imdb_link  \
# 0     https://www.imdb.com/title/tt0098987/
# 1     https://www.imdb.com/title/tt0098994/
# 2     https://www.imdb.com/title/tt0099005/
# 3     https://www.imdb.com/title/tt0099012/
# 4     https://www.imdb.com/title/tt0099018/
# ...                                     ...
# 6047  https://www.imdb.com/title/tt5639354/
# 6048  https://www.imdb.com/title/tt5390066/
# 6049  https://www.imdb.com/title/tt6304162/
# 6050  https://www.imdb.com/title/tt5795086/
# 6051  https://www.imdb.com/title/tt3859310/
#
#                                                Based on  \
# 0                           [Characters, by Rex Weiner]
# 1     [the novel, After Dark, My Sweet, by, Jim Thom...
# 2                [Air America, by, Christopher Robbins]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6047                                                NaN
# 6048                                                NaN
# 6049                                                NaN
# 6050                                                NaN
# 6051  [", How to Talk to Girls at Parties, ", by, Ne...
#
#                                                Starring        Cinematography  \
# 0     [Andrew Dice Clay, Wayne Newton, Priscilla Pre...           Oliver Wood
# 1     [Jason Patric, Rachel Ward, Bruce Dern, George...          Mark Plummer
# 2     [Mel Gibson, Robert Downey Jr., Nancy Travis, ...         Roger Deakins
# 3     [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...        Carlo Di Palma
# 4           [Paul Hogan, Elias Koteas, Linda Kozlowski]          Russell Boyd
# ...                                                 ...                   ...
# 6047                    [Daniela Vega, Francisco Reyes]  Benjamín Echazarreta
# 6048  [Rebecca Hall, Dan Stevens, Morgan Spector, Fr...          Adam Bricker
# 6049  [Maryana Spivak, Aleksey Rozin, Matvey Novikov...      Mikhail Krichman
# 6050  [Lola Kirke, Zoë Kravitz, Greta Lee, Michelle ...           Andrew Reed
# 6051  [Elle Fanning, Alex Sharp, Nicole Kidman, Ruth...      Frank G. DeMarco
#
#                                            Release date  \
# 0                     [July 11, 1990, (, 1990-07-11, )]
# 1     [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...
# 2                   [August 10, 1990, (, 1990-08-10, )]
# 3                 [December 25, 1990, (, 1990-12-25, )]
# 4                                     December 19, 1990
# ...                                                 ...
# 6047  [12 February 2017, (, 2017-02-12, ), (, Berlin...
# 6048  [April 22, 2017, (, 2017-04-22, ), (, Tribeca ...
# 6049  [18 May 2017, (, 2017-05-18, ), (, Cannes, ), ...
# 6050  [March 12, 2017, (, 2017-03-12, ), (, SXSW, ),...
# 6051  [May 21, 2017, (, 2017-05-21, ), (, Cannes, ),...
#
#                                           Country               Director  \
# 0                                   United States           Renny Harlin
# 1                                   United States            James Foley
# 2                                   United States     Roger Spottiswoode
# 3                                   United States            Woody Allen
# 4                                              US           John Cornell
# ...                                           ...                    ...
# 6047  [Chile, Germany, Spain, United States, [2]]        Sebastián Lelio
# 6048                                United States            Brian Crano
# 6049      [Russia, France, Belgium, Germany, [3]]     Andrey Zvyagintsev
# 6050                                United States             Aaron Katz
# 6051              [United Kingdom, United States]  John Cameron Mitchell
#
#                                             Distributor  ...  \
# 0                                      20th Century Fox  ...
# 1                                       Avenue Pictures  ...
# 2                                      TriStar Pictures  ...
# 3                                        Orion Pictures  ...
# 4                                    Paramount Pictures  ...
# ...                                                 ...  ...
# 6047  [Participant Media (Chile), Piffl Medien (Germ...  ...
# 6048                            Good Deed Entertainment  ...
# 6049           [Sony Pictures Releasing, (Russia), [1]]  ...
# 6050                                               Neon  ...
# 6051                              [A24, StudioCanal UK]  ...
#
#      release_date_kaggle     revenue runtime  \
# 0             1990-07-11  20423389.0   104.0
# 1             1990-08-24   2700000.0   114.0
# 2             1990-08-10  33461269.0   112.0
# 3             1990-12-25   7331647.0   102.0
# 4             1990-12-21   6939946.0    95.0
# ...                  ...         ...     ...
# 6047          2017-04-06   3700000.0   104.0
# 6048          2017-04-22         NaN    96.0
# 6049          2017-06-01   4800000.0   128.0
# 6050          2017-03-12    200340.0    92.0
# 6051          2017-12-27    382053.0   102.0
#
#                                        spoken_languages           status  \
# 0              [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 1              [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 2     [{'iso_639_1': 'en', 'name': 'English'}, {'iso...         Released
# 3              [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 4              [{'iso_639_1': 'en', 'name': 'English'}]         Released
# ...                                                 ...              ...
# 6047           [{'iso_639_1': 'es', 'name': 'Español'}]         Released
# 6048           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 6049           [{'iso_639_1': 'ru', 'name': 'Pусский'}]         Released
# 6050           [{'iso_639_1': 'en', 'name': 'English'}]  Post Production
# 6051           [{'iso_639_1': 'en', 'name': 'English'}]         Released
#
#                                       tagline  \
# 0         Kojak. Columbo. Dirty Harry. Wimps.
# 1             All they risked was everything.
# 2     The few. The proud. The totally insane.
# 3                                         NaN
# 4                    Who does he think he is?
# ...                                       ...
# 6047                                      NaN
# 6048                                      NaN
# 6049                                      NaN
# 6050                                      NaN
# 6051        Some girls are out of this world.
#
#                          title_kaggle  video vote_average  vote_count
# 0     The Adventures of Ford Fairlane  False          6.2        72.0
# 1                After Dark, My Sweet  False          6.5        17.0
# 2                         Air America  False          5.3       146.0
# 3                               Alice  False          6.3        57.0
# 4                     Almost an Angel  False          5.6        23.0
# ...                               ...    ...          ...         ...
# 6047                A Fantastic Woman  False          7.2        13.0
# 6048                       Permission  False          0.0         1.0
# 6049                         Loveless  False          7.8        26.0
# 6050                           Gemini  False          0.0         0.0
# 6051  How to Talk to Girls at Parties  False          0.0        10.0
#
# [6051 rows x 37 columns]

# %%
for col in movies_df.columns:
    lists_to_tuples = lambda x: tuple(x) if type(x) == list else x
    value_counts = movies_df[col].apply(lists_to_tuples).value_counts(dropna=False)
    num_values = len(value_counts)
    if num_values == 1:
        print(col)
# Out:
# video

# %%
movies_df['video'].value_counts(dropna=False)
# Out:
# False    6051
# Name: video, dtype: int64

# %%
# drop the title_wiki, release_date_wiki, Language, and Production company(s) columns.
movies_df.drop(columns=['video'], inplace=True)

# %%
movies_df = movies_df.loc[:, ['imdb_id','id','title_kaggle','original_title','tagline','belongs_to_collection','url','imdb_link',
                       'runtime','budget_kaggle','revenue','release_date_kaggle','popularity','vote_average','vote_count',
                       'genres','original_language','overview','spoken_languages','Country',
                       'production_companies','production_countries','Distributor',
                       'Producer(s)','Director','Starring','Cinematography','Editor(s)','Writer(s)','Composer(s)','Based on'
                      ]]

# %%
movies_df.rename({'id':'kaggle_id',
                  'title_kaggle':'title',
                  'url':'wikipedia_url',
                  'budget_kaggle':'budget',
                  'release_date_kaggle':'release_date',
                  'Country':'country',
                  'Distributor':'distributor',
                  'Producer(s)':'producers',
                  'Director':'director',
                  'Starring':'starring',
                  'Cinematography':'cinematography',
                  'Editor(s)':'editors',
                  'Writer(s)':'writers',
                  'Composer(s)':'composers',
                  'Based on':'based_on'
                 }, axis='columns', inplace=True)

# %%
movies_df.sample(n=10)
# Out:
#         imdb_id  kaggle_id                                 title  \
# 1292  tt0112844      47449                       Denise Calls Up
# 5478  tt2223990     200505                             Draft Day
# 4751  tt1547230      60062  Judy Moody and the Not Bummer Summer
# 5460  tt3210686     235260                            Son of God
# 2233  tt0186894      10862                                Bounce
# 3991  tt0386032       2359                                 Sicko
# 2557  tt0200027      11091              Riding in Cars with Boys
# 5557  tt2639344     244268                       Love Is Strange
# 1816  tt0149964     125263                        Broken Vessels
# 1114  tt0113539     142150                             Kidnapped
#
#                             original_title  \
# 1292                       Denise Calls Up
# 5478                             Draft Day
# 4751  Judy Moody and the Not Bummer Summer
# 5460                            Son of God
# 2233                                Bounce
# 3991                                 Sicko
# 2557              Riding in Cars with Boys
# 5557                       Love Is Strange
# 1816                        Broken Vessels
# 1114                             Kidnapped
#
#                                                 tagline belongs_to_collection  \
# 1292  A hilarious heart-ringing fable about life, lo...                   NaN
# 5478  The greatest victories don't always happen on ...                   NaN
# 4751                      Supermegatotally thrilladelic                   NaN
# 5460                         Their Empire. His Kingdom.                   NaN
# 2233  Two strangers fell in love. One knew it wasn't...                   NaN
# 3991                          This might hurt a little.                   NaN
# 2557  One day can make your life; one day can ruin y...                   NaN
# 5557                                                NaN                   NaN
# 1816                  Over the edge and out of control.                   NaN
# 1114                                                NaN                   NaN
#
#                                           wikipedia_url  \
# 1292      https://en.wikipedia.org/wiki/Denise_Calls_Up
# 5478            https://en.wikipedia.org/wiki/Draft_Day
# 4751  https://en.wikipedia.org/wiki/Judy_Moody_and_t...
# 5460    https://en.wikipedia.org/wiki/Son_of_God_(film)
# 2233        https://en.wikipedia.org/wiki/Bounce_(film)
# 3991                https://en.wikipedia.org/wiki/Sicko
# 2557  https://en.wikipedia.org/wiki/Riding_in_Cars_w...
# 5557  https://en.wikipedia.org/wiki/Love_Is_Strange_...
# 1816       https://en.wikipedia.org/wiki/Broken_Vessels
# 1114  https://en.wikipedia.org/wiki/Kidnapped_(1995_...
#
#                                   imdb_link  runtime      budget  ...  \
# 1292  https://www.imdb.com/title/tt0112844/     80.0         NaN  ...
# 5478  https://www.imdb.com/title/tt2223990/    109.0  25000000.0  ...
# 4751  https://www.imdb.com/title/tt1547230/     91.0  20000000.0  ...
# 5460  https://www.imdb.com/title/tt3210686/    138.0  22000000.0  ...
# 2233  https://www.imdb.com/title/tt0186894/    106.0  35000000.0  ...
# 3991  https://www.imdb.com/title/tt0386032/    123.0   9000000.0  ...
# 2557  https://www.imdb.com/title/tt0200027/    132.0  48000000.0  ...
# 5557  https://www.imdb.com/title/tt2639344/     98.0         NaN  ...
# 1816  https://www.imdb.com/title/tt0149964/     90.0    600000.0  ...
# 1114  https://www.imdb.com/title/tt0113539/    155.0         NaN  ...
#
#                                    production_countries  \
# 1292  [{'iso_3166_1': 'US', 'name': 'United States o...
# 5478  [{'iso_3166_1': 'US', 'name': 'United States o...
# 4751  [{'iso_3166_1': 'US', 'name': 'United States o...
# 5460  [{'iso_3166_1': 'US', 'name': 'United States o...
# 2233  [{'iso_3166_1': 'US', 'name': 'United States o...
# 3991  [{'iso_3166_1': 'US', 'name': 'United States o...
# 2557  [{'iso_3166_1': 'US', 'name': 'United States o...
# 5557  [{'iso_3166_1': 'BR', 'name': 'Brazil'}, {'iso...
# 1816                                                 []
# 1114  [{'iso_3166_1': 'US', 'name': 'United States o...
#
#                                         distributor  \
# 1292  [Davis Entertainment, Sony Pictures Classics]
# 5478              [Summit Entertainment, Lionsgate]
# 4751                               Relativity Media
# 5460                               20th Century Fox
# 2233                                  Miramax Films
# 3991             [Lionsgate, The Weinstein Company]
# 2557                              Columbia Pictures
# 5557                         Sony Pictures Classics
# 1816               Unapix Entertainment Productions
# 1114                                            NaN
#
#                                               producers             director  \
# 1292                                     J. Todd Harris           Hal Salwen
# 5478  [Ivan Reitman, Ali Bell, Joe Medjuck, Gigi Pri...         Ivan Reitman
# 4751  [Sara Siegel-Magness, Gary Magness, Bobbi Sue ...         John Schultz
# 5460                        [Roma Downey, Mark Burnett]  Christopher Spencer
# 2233                      [Michael Besman, Steve Golin]             Don Roos
# 3991                [Michael Moore, Meegan O'Hara, [1]]        Michael Moore
# 2557  [James L. Brooks, Laurence Mark, Sara Colleton...       Penny Marshall
# 5557  [Lucas Joaquin, Lars Knudsen, Ira Sachs, Jayne...            Ira Sachs
# 1816                          [Scott Ziehl, Roxana Zal]          Scott Ziehl
# 1114                                         John Davis          Ivan Passer
#
#                                                starring  \
# 1292  [Tim Daly, Caroleen Feeney, Dan Gunther, Dana ...
# 5478  [Kevin Costner, Jennifer Garner, Denis Leary, ...
# 4751  [Jordana Beatty, Heather Graham, Parris Mostel...
# 5460                       [Diogo Morgado, Roma Downey]
# 2233  [Ben Affleck, Gwyneth Paltrow, Joe Morton, Nat...
# 3991                                      Michael Moore
# 2557  [Drew Barrymore, Steve Zahn, Brittany Murphy, ...
# 5557        [Alfred Molina, John Lithgow, Marisa Tomei]
# 1816  [Todd Field, Jason London, Roxana Zal, Susan T...
# 1114  [Armand Assante, Brian McCardie, Michael Kitch...
#
#                                          cinematography  \
# 1292                                                NaN
# 5478                                     Eric Steelberg
# 4751                                       Shawn Maurer
# 5460                                         Rob Goldie
# 2233                                      Robert Elswit
# 3991                                                NaN
# 2557                                  Miroslav Ondříček
# 5557                                 Christos Voudouris
# 1816                                   Antonio Calvache
# 1114  [Dennis C. Lewiston, [1], Floyd Crosby, ASC, w...
#
#                                   editors  \
# 1292                                  NaN
# 5478   [Sheldon Kahn, Dana E. Glauberman]
# 4751                        John Pace III
# 5460                          Robert Hall
# 2233                         David Codron
# 3991                                  NaN
# 2557                        Richard Marks
# 5557  [Affonso Gonçalves, Michael Taylor]
# 1816         [Chris Figler, David Moritz]
# 1114                      Bernard Gribble
#
#                                                 writers  \
# 1292                                         Hal Salwen
# 5478                      [Rajiv Joseph, Scott Rothman]
# 4751                      [Megan McDonald, Kathy Waugh]
# 5460  [Richard Bedser, Christopher Spencer, Colin Sw...
# 2233                                           Don Roos
# 3991                                      Michael Moore
# 2557                                  Morgan Upton Ward
# 5557                    [Ira Sachs, Mauricio Zacharias]
# 1816            [Scott Ziehl, David Baer, John McMahon]
# 1114               [Robert Louis Stevenson, Rob Hedden]
#
#                                               composers  \
# 1292                                                NaN
# 5478                                        John Debney
# 4751                                      Richard Gibbs
# 5460           [Lorne Balfe, Lisa Gerrard, Hans Zimmer]
# 2233                                      Mychael Danna
# 3991                                                NaN
# 2557                                        Hans Zimmer
# 5557                                                NaN
# 1816  [Martin Blasick, Todd Field, Brent David Frase...
# 1114                                 Stanislaw Syrewicz
#
#                                               based_on
# 1292                                               NaN
# 5478                                               NaN
# 4751                   [Judy Moody, by Megan McDonald]
# 5460                                     New Testament
# 2233                                               NaN
# 3991                                               NaN
# 2557  [Riding in Cars with Boys, by, Beverly Donofrio]
# 5557                                               NaN
# 1816                                               NaN
# 1114                                               NaN
#
# [10 rows x 31 columns]
